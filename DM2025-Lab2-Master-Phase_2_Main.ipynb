# %% [markdown]
# **Table of contents**<a id='toc0_'></a>
# - [Data Mining Lab 2 - Phase 2](#toc1_)
#   - [Before Starting](#toc1_1_)
#   - [Introduction](#toc1_2_)
#   - [**1. Data Preparation**](#toc1_3_)
#   - [**1.1 Load data**](#toc1_4_)
#     - [**1.2 Save data**](#toc1_4_1_)
#   - [**2. Large Language Models (LLMs)**](#toc1_5_)
#     - [Open-Source vs. Proprietary LLMs](#toc1_5_1_)
#     - [Why Use Code (API) for Data Mining?](#toc1_5_2_)
#     - [The Gemini API](#toc1_5_3_)
#     - [Interacting with the Gemini API](#toc1_5_4_)
#     - [**2.1 Text Prompting**](#toc1_5_5_)
#         - [**>>> Exercise 1 (Take home):**](#toc1_5_5_1_1_)
#     - [**2.2 Structured Output**](#toc1_5_6_)
#         - [**>>> Exercise 2 (Take home):**](#toc1_5_6_1_1_)
#     - [**2.3 Information Extraction and Grounding:**](#toc1_5_7_)
#       - [**`langextract`: A Library for Grounded Extraction**](#toc1_5_7_1_)
#         - [**2.3.1 Using PDF Documents:**](#toc1_5_7_1_1_)
#         - [**>>> Bonus Exercise 3 (Take home):**](#toc1_5_7_1_2_)
#     - [**2.4 Generating LLM Embeddings:**](#toc1_5_8_)
#         - [**>>> Exercise 4 (Take home):**](#toc1_5_8_1_1_)
#     - [**2.5 Retrieval-Augmented Generation (RAG)**](#toc1_5_9_)
#         - [**Actual answer in the URL:**](#toc1_5_9_1_1_)
#         - [**Content in the URL that might get into the generated answer because of similar semantic meaning:**](#toc1_5_9_1_2_)
#         - [**>>> Bonus Exercise 5 (Take home):**](#toc1_5_9_1_3_)
#     - [**2.6 Few-Shot Prompting Classification:**](#toc1_5_10_)
#         - [**>>> Exercise 6 (Take home):**](#toc1_5_10_1_1_)
#         - [**>>> Exercise 7 (Take home):**](#toc1_5_10_1_2_)
#     - [**2.7 Extra LLM Related Materials:**](#toc1_5_11_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=false
# 	anchor=true
# 	flat=false
# 	minLevel=1
# 	maxLevel=6
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %% [markdown]
# # <a id='toc1_'></a>[Data Mining Lab 2 - Phase 2](#toc0_)
# In this lab's phase 2 session we will focus on exploring some basic LLMs' applications with data.

# %% [markdown]
# ## <a id='toc1_1_'></a>[Before Starting](#toc0_)
#
# **Make sure you have installed all the required libraries and you have the environment ready to run this lab.**

# %% [markdown]
# ---
# ## <a id='toc1_2_'></a>[Introduction](#toc0_)

# %% [markdown]
# **Dataset:** [SemEval 2017 Task](https://competitions.codalab.org/competitions/16380)
#
# **Task:** Classify text data into 4 different emotions using word embeddings and other deep information retrieval approaches.
#
# ![pic0.png](./pics/pic0.png)

# %% [markdown]
# ---
# ## <a id='toc1_3_'></a>[**1. Data Preparation**](#toc0_)

# %% [markdown]
# ---
# ## <a id='toc1_4_'></a>[**1.1 Load data**](#toc0_)
#
# We start by loading the csv files into a single pandas dataframe for training and one for testing.

# %%
import pandas as pd

### training data
anger_train = pd.read_csv("data/semeval/train/anger-ratings-0to1.train.txt",
                         sep="\t", header=None,names=["id", "text", "emotion", "intensity"])
sadness_train = pd.read_csv("data/semeval/train/sadness-ratings-0to1.train.txt",
                         sep="\t", header=None, names=["id", "text", "emotion", "intensity"])
fear_train = pd.read_csv("data/semeval/train/fear-ratings-0to1.train.txt",
                         sep="\t", header=None, names=["id", "text", "emotion", "intensity"])
joy_train = pd.read_csv("data/semeval/train/joy-ratings-0to1.train.txt",
                         sep="\t", header=None, names=["id", "text", "emotion", "intensity"])

# %%
# combine 4 sub-dataset
train_df = pd.concat([anger_train, fear_train, joy_train, sadness_train], ignore_index=True)

# %%
### testing data
anger_test = pd.read_csv("data/semeval/dev/anger-ratings-0to1.dev.gold.txt",
                         sep="\t", header=None, names=["id", "text", "emotion", "intensity"])
sadness_test = pd.read_csv("data/semeval/dev/sadness-ratings-0to1.dev.gold.txt",
                         sep="\t", header=None, names=["id", "text", "emotion", "intensity"])
fear_test = pd.read_csv("data/semeval/dev/fear-ratings-0to1.dev.gold.txt",
                         sep="\t", header=None, names=["id", "text", "emotion", "intensity"])
joy_test = pd.read_csv("data/semeval/dev/joy-ratings-0to1.dev.gold.txt",
                         sep="\t", header=None, names=["id", "text", "emotion", "intensity"])

# combine 4 sub-dataset
test_df = pd.concat([anger_test, fear_test, joy_test, sadness_test], ignore_index=True)
train_df.head()
# Out:
#       id                                               text emotion  intensity
# 0  10000  How the fu*k! Who the heck! moved my fridge!.....   anger      0.938
# 1  10001  So my Indian Uber driver just called someone t...   anger      0.896
# 2  10002  @DPD_UK I asked for my parcel to be delivered ...   anger      0.896
# 3  10003  so ef whichever butt wipe pulled the fire alar...   anger      0.896
# 4  10004  Don't join @BTCare they put the phone down on ...   anger      0.896

# %%
# shuffle dataset
train_df = train_df.sample(frac=1)
test_df = test_df.sample(frac=1)

# %%
print("Shape of Training df: ", train_df.shape)
print("Shape of Testing df: ", test_df.shape)
# Out:
# Shape of Training df:  (3613, 4)
# Shape of Testing df:  (347, 4)

# %% [markdown]
# ---
# ### <a id='toc1_4_1_'></a>[**1.2 Save data**](#toc0_)

# %%
# save to pickle file
train_df.to_pickle("./data/train_df.pkl") 
test_df.to_pickle("./data/test_df.pkl")

# %%
import pandas as pd

# load a pickle file
train_df = pd.read_pickle("./data/train_df.pkl")
test_df = pd.read_pickle("./data/test_df.pkl")

# %% [markdown]
# For more information: https://reurl.cc/0Dzqx

# %% [markdown]
# ---
# ## <a id='toc1_5_'></a>[**2. Large Language Models (LLMs)**](#toc0_)
#
# Before we start we strongly suggest that you watch the following video explanations so you can understand the concepts that we are gonna discuss about LLMs:
#
# 1. [How Large Language Models Work](https://www.youtube.com/watch?v=5sLYAQS9sWQ)
# 2. [Large Language Models explained briefly](https://www.youtube.com/watch?v=LPZh9BOjkQs)
# 3. [What is Prompt Tuning?](https://www.youtube.com/watch?v=yu27PWzJI_Y)
# 4. [Why Large Language Models Hallucinate](https://www.youtube.com/watch?v=cfqtFvWOfg0)
# 5. [What are LLM Embeddings?](https://www.youtube.com/watch?v=UShw_1NbpCw&t=182s)
# 6. [What is Retrieval-Augmented Generation (RAG)?](https://www.youtube.com/watch?v=T-D1OfcDW1M)
# 7. [RAG vs Fine-Tuning vs Prompt Engineering: Optimizing AI Models](https://www.youtube.com/watch?v=zYGDpG-pTho)
# 8. [Discover Few-Shot Prompting | Google AI Essentials](https://www.youtube.com/watch?v=9qdgEBVkWR4)
# 9. [What is Zero-Shot Learning?](https://www.youtube.com/watch?v=pVpr4GYLzAo)
# 10. [Zero-shot, One-shot and Few-shot Prompting Explained | Prompt Engineering 101](https://www.youtube.com/watch?v=sW5xoicq5TY)
#
# `These videos can help you get a better grasp on the core concepts of LLMs if you were not familiar before.`
#
# **So now let's start with the main content of Lab 2 Phase 2.**
#
# Large Language Models (LLMs) are AI systems trained on vast amounts of text to understand and generate human language for tasks like summarization and translation.
#
# ### <a id='toc1_5_1_'></a>[Open-Source vs. Proprietary LLMs](#toc0_)
# *   **Open-Source Models** (e.g., Llama, Gemma) are customizable and cost-effective but require technical skill to manage and may be less powerful.
# *   **Proprietary Models** (e.g., Gemini, ChatGPT) offer top performance and ease of use but are more costly and less flexible.
#
# For students interested in running models locally, the optional notebook `DM2025-Lab2-Optional-Ollama.ipynb` explores using Ollama ([Ollama GitHub Link](https://github.com/ollama/ollama)). It needs a capable GPU to run models (**at least 4GB VRAM**).
#
# You can explore the variety of models available through Ollama here:
#
# ![pic10.png](./pics/pic10.png)
#
# ### <a id='toc1_5_2_'></a>[Why Use Code (API) for Data Mining?](#toc0_)
#
# For data analysis, accessing LLMs programmatically is superior to using web chatbots because it allows for:
# *   **Automation:** Easily process entire datasets with loops.
# *   **Structured Output:** Receive data in usable formats like **JSON**, ready for analysis in tools like pandas.
# *   **Reproducibility:** Ensure consistent results by setting fixed parameters.
# *   **Privacy:** Maintain data security, especially when running models locally.
#
# For the main exercises in this lab, we will use **the Gemini API**. This approach offers several advantages over running local open-source models, such as access to state-of-the-art model performance without needing specialized hardware. While the API has usage limits (rate limits and token quotas), it provides a generous **free tier** that is more than sufficient for our exercises.
#
# ![pic13.png](./pics/pic13.png)
#
# ![pic14.png](./pics/pic14.png)
#
# ### <a id='toc1_5_3_'></a>[The Gemini API](#toc0_)
#
# We will primarily use the **Gemini 2.5 Flash-Lite** (`gemini-2.5-flash-lite`) model. As shown in the rate limit table, this model is optimized for high-frequency tasks and offers a high request-per-day limit of 1,000, making it ideal for completing the lab exercises without interruption.
#
# Students are encouraged to explore other models available through the API but should remain mindful of their respective usage limits. For instance:
# *   **Gemini 2.5 Pro** is a more powerful model but has a lower daily request limit of 100.
# *   The **Gemma 3** model available via the API offers an impressive 14,400 requests per day, providing another excellent alternative for experimentation.
#
# Please be aware of your usage limits as you work through the exercises to ensure you do not get rate-limited.
#
# [Gemini Documentation](https://ai.google.dev/gemini-api/docs)
#
# [Gemini Rate Limits](https://ai.google.dev/gemini-api/docs/rate-limits)
#
# [Description of Gemini Models](https://ai.google.dev/gemini-api/docs/models)

# %% [markdown]
# ---
#
# ### <a id='toc1_5_4_'></a>[Interacting with the Gemini API](#toc0_)
#
# The code cell below contains the primary function, `prompt_gemini`, that we will use throughout this lab to communicate with the Gemini API. It's designed to be a flexible wrapper that handles the details of sending a request and receiving a response.
#
# Before you run the exercises, here are the key things you need to understand in this setup:
#
# *   **API Key Configuration**: The script loads your API key from a `.env` file located in the `./config/` directory. **You must create this file and add your API key** like this: `GOOGLE_API_KEY='YOUR_API_KEY_HERE'`. This is a security best practice to keep your credentials out of the code.
#
# *   **Global Settings**: At the top of the script, you can find and modify several important defaults:
#     *   `MODEL_NAME`: We've set this to `"gemini-2.5-flash-lite"`, but you can easily switch to other models like `"gemini-2.5-pro"` to experiment.
#     *   `SYSTEM_INSTRUCTION`: This sets the model's default behavior or persona (e.g., "You are a helpful assistant"). You can customize this for different tasks.
#     *   `SAFETY_SETTINGS`: For our academic exercises, these are turned off to prevent interference. In real-world applications, you would configure these carefully.
#
# *   **The `prompt_gemini` function**: This is the main tool you will use. Here are its most important parameters:
#     *   `input_prompt`: The list of contents (text, images, etc.) you want to send to the model.
#     *   `temperature`: Controls the randomness of the output. `0.0` makes the output deterministic and less creative, while a higher value (e.g., `0.7`) makes it more varied.
#     *   `schema`: A powerful feature that allows you to specify a JSON format for the model's output. This is extremely useful for structured data extraction.
#     *   `with_tokens_info`: If set to `True`, the function will also return the number of input and output tokens used, which is helpful for monitoring your usage against the free tier limits.
#
# In the following exercises, you will call this function with different prompts and configurations to solve various tasks.
#
# If needed, you can also check some tutorials on how a python function works: [Python Functions Tutorial](https://realpython.com/defining-your-own-python-function/)

# %%
import os
from dotenv import load_dotenv
from google import genai
from google.genai import types

env_path = "./config/.env"
load_dotenv(dotenv_path=env_path)

# System instruction that can dictate how the model behaves in the output, can be customized as needed
SYSTEM_INSTRUCTION = (
        "You are a helpful assistant"
    )

# Max amount of tokens that the model can output, the Gemini 2.5 Models have this maximum amount
# For other models need to check their documentation 
MAX_OUTPUT_TOKENS = 65535
MODEL_NAME = "gemini-2.5-flash-lite" # Other models: "gemini-2.5-pro", "gemini-2.5-flash"; Check different max output tokens: "gemini-2.0-flash" , "gemini-2.0-flash-lite" 

# We disable the safety settings, as no moderation is needed in our tasks
SAFETY_SETTINGS = [
    types.SafetySetting(
        category="HARM_CATEGORY_HATE_SPEECH", threshold="OFF"),
    types.SafetySetting(
        category="HARM_CATEGORY_DANGEROUS_CONTENT", threshold="OFF"),
    types.SafetySetting(
        category="HARM_CATEGORY_SEXUALLY_EXPLICIT", threshold="OFF"),
    types.SafetySetting(
        category="HARM_CATEGORY_HARASSMENT", threshold="OFF")
]

#IMPORTANT: The script loads your API key from a `.env` file located in the `./config/` directory. 
# You must create this file and add your API key like this: `GOOGLE_API_KEY='YOUR_API_KEY_HERE'`

# We input the API Key to be able to use the Gemini models
api_key = os.getenv("GOOGLE_API_KEY")
os.environ["GOOGLE_API_KEY"] = api_key
client = genai.Client(api_key=api_key)

# We also set LangExtract to use the API key as well:
if 'GEMINI_API_KEY' not in os.environ:
    os.environ['GEMINI_API_KEY'] = api_key

def prompt_gemini(
        input_prompt: list,
        schema = None,
        temperature: float = 0.0,
        system_instruction: str = SYSTEM_INSTRUCTION,
        max_output_tokens: int = MAX_OUTPUT_TOKENS,
        client: genai.Client = client,
        model_name: str = MODEL_NAME,
        new_config: types.GenerateContentConfig = None,
        with_tools: bool = False,
        with_parts: bool = False,
        with_tokens_info: bool = False
    ):
        try:
            # If we need a JSON schema we set up the following
            if schema:
                generate_content_config = types.GenerateContentConfig(
                    temperature=temperature,
                    system_instruction=system_instruction,
                    max_output_tokens=max_output_tokens,
                    response_modalities=["TEXT"],
                    response_mime_type="application/json",
                    response_schema=schema,
                    safety_settings=SAFETY_SETTINGS
                )
            # If there is no need we leave it unstructured
            else:
                generate_content_config = types.GenerateContentConfig(
                    temperature=temperature,
                    system_instruction=system_instruction,
                    max_output_tokens=max_output_tokens,
                    response_modalities=["TEXT"],
                    safety_settings=SAFETY_SETTINGS
                )
            
            # We add a different custom configuration if we need it
            if new_config:
                generate_content_config = new_config
            
            # For some tasks we need a more specific way to add the contents when prompting the model
            # So we need custom parts for it sometimes from the "types" objects
            if with_parts:
                response = client.models.generate_content(
                    model=model_name,
                    contents=types.Content(parts=input_prompt),
                    config=generate_content_config,
                )
            # In the simplest form the contents can be expressed as a list [] of simple objects like str and Pillow images
            else:
                response = client.models.generate_content(
                    model=model_name,
                    contents=input_prompt,
                    config=generate_content_config,
                )

            if with_tools:
                # print(response)
                # Include raw response when function calling
                completion = response
                if with_tokens_info:
                    log = {
                        "model": model_name,
                        "input_tokens": response.usage_metadata.prompt_token_count,
                        "output_tokens": response.usage_metadata.candidates_token_count,
                    }
                    return completion, log
                return completion
            else:
                completion = response.text
                if with_tokens_info:
                    log = {
                        "model": model_name,
                        "input_tokens": response.usage_metadata.prompt_token_count,
                        "output_tokens": response.usage_metadata.candidates_token_count,
                    }
                    # Return the text response and logs (if selected)
                    return completion, log
                return completion
        except Exception as e:
             print(f"Error occurred when generating response, error: {e}")
             return None

# %% [markdown]
# ---
# ### <a id='toc1_5_5_'></a>[**2.1 Text Prompting**](#toc0_)
#
# In the same way as with ChatGPT we can use the Gemini models to ask about anything. Here we are going to ask a question requesting the response to be in markdown format, this is to make it have a better display afterwards.
#
# For more information visit:
# [Gemini's Text Generation Documentation](https://ai.google.dev/gemini-api/docs/text-generation)

# %%
input_prompt = ["What is Data Mining?"]
text_response, logs = prompt_gemini(input_prompt = input_prompt, with_tokens_info = True)
print(text_response)
# Out:
# Data mining is the process of **discovering patterns, insights, and knowledge from large datasets**. It's essentially about extracting valuable information that isn't immediately obvious from raw data. Think of it as sifting through a mountain of information to find hidden gems.
#
# Here's a breakdown of what that means:
#
# **Key Concepts:**
#
# *   **Large Datasets:** Data mining is typically applied to datasets that are too large and complex for manual analysis. This can include customer transaction records, website logs, sensor data, social media feeds, scientific experiment results, and much more.
# *   **Patterns and Insights:** The goal is to identify recurring trends, correlations, anomalies, and relationships within the data. These patterns can reveal underlying structures, predict future behavior, or explain observed phenomena.
# *   **Knowledge Discovery:** The ultimate aim is to transform raw data into actionable knowledge that can be used for decision-making, problem-solving, and strategic planning.
#
# **How it Works (The Process):**
#
# Data mining is usually an iterative process that involves several stages:
#
# 1.  **Business Understanding:** Defining the problem or objective you want to achieve with data mining. What questions are you trying to answer? What business goals are you trying to meet?
# 2.  **Data Understanding:** Exploring and getting familiar with the data. This involves collecting, cleaning, and understanding the data's structure, quality, and meaning.
# 3.  **Data Preparation (Preprocessing):** This is often the most time-consuming stage. It involves:
#     *   **Cleaning:** Handling missing values, noisy data, and inconsistencies.
#     *   **Integration:** Combining data from multiple sources.
#     *   **Transformation:** Normalizing or aggregating data to make it suitable for mining.
#     *   **Reduction:** Reducing the size of the dataset while preserving important information.
# 4.  **Modeling:** Selecting and applying appropriate data mining techniques (algorithms) to discover patterns. This is where the "mining" happens.
# 5.  **Evaluation:** Assessing the quality and usefulness of the discovered patterns. Do they make sense? Are they statistically significant? Do they meet the business objectives?
# 6.  **Deployment:** Putting the discovered knowledge into practice. This could involve integrating it into business processes, creating reports, or building predictive models.
#
# **Common Data Mining Techniques:**
#
# Data mining employs a variety of techniques, often drawing from statistics, machine learning, and database systems. Some of the most common include:
#
# *   **Classification:** Categorizing data into predefined classes (e.g., predicting whether a customer will churn or not).
# *   **Clustering:** Grouping similar data points together without predefined classes (e.g., segmenting customers into different groups based on their purchasing behavior).
# *   **Association Rule Mining:** Discovering relationships between items in a dataset (e.g., "customers who buy bread also tend to buy milk"). This is often used in market basket analysis.
# *   **Regression:** Predicting a continuous numerical value (e.g., predicting the price of a house based on its features).
# *   **Anomaly Detection (Outlier Detection):** Identifying data points that deviate significantly from the norm (e.g., detecting fraudulent transactions).
# *   **Sequential Pattern Mining:** Discovering patterns that occur in a sequence over time (e.g., identifying common user navigation paths on a website).
#
# **Why is Data Mining Important?**
#
# Data mining is crucial for businesses and organizations because it enables them to:
#
# *   **Make Better Decisions:** By understanding customer behavior, market trends, and operational efficiencies, organizations can make more informed and strategic decisions.
# *   **Improve Customer Relationships:** Identifying customer preferences and predicting their needs allows for personalized marketing, better customer service, and increased loyalty.
# *   **Detect Fraud and Risk:** Anomaly detection can help identify fraudulent activities, security breaches, and potential risks.
# *   **Optimize Operations:** Understanding patterns in operational data can lead to improved efficiency, reduced costs, and better resource allocation.
# *   **Drive Innovation:** Discovering new insights can spark new product development, service offerings, and business models.
# *   **Gain a Competitive Advantage:** Organizations that effectively leverage data mining can outperform their competitors by understanding their market and customers better.
#
# In essence, data mining is a powerful tool for transforming raw data into valuable intelligence, driving progress and innovation across various fields.

# %% [markdown]
# We can also check the logs of the usage with our model that we defined in our previous function. We can observe the model we used, how many tokens where in the prompt in the input, and the output text response tokens of our model.

# %%
print(logs)
# Out:
# {'model': 'gemini-2.5-flash-lite', 'input_tokens': 12, 'output_tokens': 911}

# %% [markdown]
# **We can use the IPython library to make the response look better:**

# %%
from IPython.display import display, Markdown
display(Markdown(text_response))
# Out:
# Data mining is the process of **discovering patterns, insights, and knowledge from large datasets**. It's essentially about extracting valuable information that isn't immediately obvious from raw data. Think of it as sifting through a mountain of information to find hidden gems.
#
# Here's a breakdown of what that means:
#
# **Key Concepts:**
#
# *   **Large Datasets:** Data mining is typically applied to datasets that are too large and complex for manual analysis. This can include customer transaction records, website logs, sensor data, social media feeds, scientific experiment results, and much more.
# *   **Patterns and Insights:** The goal is to identify recurring trends, correlations, anomalies, and relationships within the data. These patterns can reveal underlying structures, predict future behavior, or explain observed phenomena.
# *   **Knowledge Discovery:** The ultimate aim is to transform raw data into actionable knowledge that can be used for decision-making, problem-solving, and strategic planning.
#
# **How it Works (The Process):**
#
# Data mining is usually an iterative process that involves several stages:
#
# 1.  **Business Understanding:** Defining the problem or objective you want to achieve with data mining. What questions are you trying to answer? What business goals are you trying to meet?
# 2.  **Data Understanding:** Exploring and getting familiar with the data. This involves collecting, cleaning, and understanding the data's structure, quality, and meaning.
# 3.  **Data Preparation (Preprocessing):** This is often the most time-consuming stage. It involves:
#     *   **Cleaning:** Handling missing values, noisy data, and inconsistencies.
#     *   **Integration:** Combining data from multiple sources.
#     *   **Transformation:** Normalizing or aggregating data to make it suitable for mining.
#     *   **Reduction:** Reducing the size of the dataset while preserving important information.
# 4.  **Modeling:** Selecting and applying appropriate data mining techniques (algorithms) to discover patterns. This is where the "mining" happens.
# 5.  **Evaluation:** Assessing the quality and usefulness of the discovered patterns. Do they make sense? Are they statistically significant? Do they meet the business objectives?
# 6.  **Deployment:** Putting the discovered knowledge into practice. This could involve integrating it into business processes, creating reports, or building predictive models.
#
# **Common Data Mining Techniques:**
#
# Data mining employs a variety of techniques, often drawing from statistics, machine learning, and database systems. Some of the most common include:
#
# *   **Classification:** Categorizing data into predefined classes (e.g., predicting whether a customer will churn or not).
# *   **Clustering:** Grouping similar data points together without predefined classes (e.g., segmenting customers into different groups based on their purchasing behavior).
# *   **Association Rule Mining:** Discovering relationships between items in a dataset (e.g., "customers who buy bread also tend to buy milk"). This is often used in market basket analysis.
# *   **Regression:** Predicting a continuous numerical value (e.g., predicting the price of a house based on its features).
# *   **Anomaly Detection (Outlier Detection):** Identifying data points that deviate significantly from the norm (e.g., detecting fraudulent transactions).
# *   **Sequential Pattern Mining:** Discovering patterns that occur in a sequence over time (e.g., identifying common user navigation paths on a website).
#
# **Why is Data Mining Important?**
#
# Data mining is crucial for businesses and organizations because it enables them to:
#
# *   **Make Better Decisions:** By understanding customer behavior, market trends, and operational efficiencies, organizations can make more informed and strategic decisions.
# *   **Improve Customer Relationships:** Identifying customer preferences and predicting their needs allows for personalized marketing, better customer service, and increased loyalty.
# *   **Detect Fraud and Risk:** Anomaly detection can help identify fraudulent activities, security breaches, and potential risks.
# *   **Optimize Operations:** Understanding patterns in operational data can lead to improved efficiency, reduced costs, and better resource allocation.
# *   **Drive Innovation:** Discovering new insights can spark new product development, service offerings, and business models.
# *   **Gain a Competitive Advantage:** Organizations that effectively leverage data mining can outperform their competitors by understanding their market and customers better.
#
# In essence, data mining is a powerful tool for transforming raw data into valuable intelligence, driving progress and innovation across various fields.

# %% [markdown]
# ---
# ##### <a id='toc1_5_5_1_1_'></a>[**>>> Exercise 1 (Take home):**](#toc0_)
#
# `With your own prompt`, run the previous example in the following way:
#
# 1. Run it with the same model as the example (gemini-2.5-flash-lite).
# 2. Run it with a different gemini model from the available options for the API.
# 3. Discuss the differences on the results with different models.
# 4. Discuss what would happen if you change the system prompt.

# %%
# Answer here
#Run with the same model (gemini-2.5-flash-lite)
from IPython.display import display, Markdown
input_prompt = ["Tell me the difference between neural network and convolution neural network"]
text_response, logs = prompt_gemini(input_prompt=input_prompt, with_tokens_info=True)
print(logs)
display(Markdown(text_response))
# Out:
# {'model': 'gemini-2.5-flash-lite', 'input_tokens': 18, 'output_tokens': 1195}
# Let's break down the difference between a **Neural Network (NN)** and a **Convolutional Neural Network (CNN)**. Think of it like this: a CNN is a specialized type of neural network, designed for a particular kind of task.
#
# Here's a detailed comparison:
#
# ## Neural Network (NN) - The Generalist
#
# A standard or **fully connected neural network** (often referred to as a Multi-Layer Perceptron or MLP) is a foundational type of artificial neural network.
#
# **Key Characteristics:**
#
# *   **Fully Connected Layers:** In a fully connected layer, every neuron in one layer is connected to every neuron in the next layer. This means each neuron receives input from all neurons in the previous layer.
# *   **Input Representation:** Typically, the input to a standard NN is a flattened vector of features. For example, if you have an image, you would flatten all its pixels into a single long list.
# *   **Parameter Count:** Due to the full connectivity, these networks can have a very large number of parameters (weights and biases), especially when dealing with high-dimensional data like images.
# *   **Spatial Hierarchy Ignored:** Standard NNs don't inherently understand the spatial relationships between data points. For an image, they treat each pixel independently, losing information about neighboring pixels.
# *   **Applications:** Good for tasks where the input features don't have a strong spatial or sequential structure, such as:
#     *   Tabular data classification/regression (e.g., predicting house prices based on features like size, location, etc.)
#     *   Simple pattern recognition on non-spatial data.
#     *   As a component within more complex architectures.
#
# **Analogy:** Imagine a student trying to learn about a complex object by looking at a list of its individual components without any context of how they are arranged.
#
# ## Convolutional Neural Network (CNN) - The Specialist for Spatial Data
#
# A **Convolutional Neural Network (CNN)** is a type of neural network specifically designed to process data that has a grid-like topology, such as images. They are inspired by the biological visual cortex.
#
# **Key Characteristics:**
#
# *   **Convolutional Layers:** This is the defining feature. Instead of full connectivity, convolutional layers use **filters (or kernels)** that slide over the input data. These filters detect specific local patterns (e.g., edges, corners, textures).
#     *   **Local Receptive Fields:** Each neuron in a convolutional layer is only connected to a small, localized region of the input.
#     *   **Weight Sharing:** The same filter (and its weights) is applied across the entire input. This significantly reduces the number of parameters compared to a fully connected network.
# *   **Pooling Layers:** These layers are often used after convolutional layers to reduce the spatial dimensions (width and height) of the feature maps. This helps to:
#     *   Reduce computational complexity.
#     *   Make the network more robust to small variations in the position of features (translation invariance).
#     *   Common pooling operations include max pooling and average pooling.
# *   **Hierarchical Feature Extraction:** CNNs learn a hierarchy of features. Early layers detect simple features (like edges), while deeper layers combine these to detect more complex features (like shapes, objects, or parts of objects).
# *   **Preserves Spatial Information:** By using convolutional filters, CNNs explicitly leverage the spatial relationships between pixels.
# *   **Applications:** Highly effective for tasks involving grid-like data, especially:
#     *   **Image Recognition and Classification:** Identifying objects in images.
#     *   **Object Detection:** Locating and classifying multiple objects within an image.
#     *   **Image Segmentation:** Classifying each pixel in an image.
#     *   **Video Analysis:** Processing sequences of images.
#     *   **Natural Language Processing (NLP):** Can be adapted for text, treating sentences as 1D grids.
#
# **Analogy:** Imagine a student learning about an object by systematically scanning it with a magnifying glass, focusing on small details and then combining those observations to understand the whole.
#
# ## Key Differences Summarized
#
# | Feature             | Standard Neural Network (NN)                               | Convolutional Neural Network (CNN)                               |
# | :------------------ | :--------------------------------------------------------- | :--------------------------------------------------------------- |
# | **Connectivity**    | Fully connected (each neuron connects to all in next layer) | Locally connected (neurons connect to small regions of input)    |
# | **Core Operation**  | Matrix multiplication                                      | Convolution (applying filters)                                   |
# | **Parameter Count** | High (especially for images)                               | Significantly lower (due to weight sharing)                      |
# | **Spatial Info**    | Ignored (input is flattened)                               | Preserved and leveraged                                          |
# | **Feature Learning**| Learns global patterns                                     | Learns hierarchical, local patterns                              |
# | **Primary Use Case**| Tabular data, general classification/regression            | Image and video processing, spatial data analysis                |
# | **Key Layers**      | Dense (fully connected) layers                             | Convolutional layers, Pooling layers, Dense layers (at the end) |
#
# ## In Essence:
#
# *   A **Neural Network** is the broader category.
# *   A **Convolutional Neural Network** is a specialized type of neural network that excels at tasks involving spatial data (like images) by using convolutional layers to efficiently learn hierarchical features.
#
# Think of it like this: all CNNs are NNs, but not all NNs are CNNs. CNNs are NNs that have been "enhanced" with specific architectural components (convolution and pooling) to make them particularly good at processing grid-like data.

# %%
#run with another model:gemini-2.5-pro
input_prompt = ["Tell me the difference between neural network and convolution neural network"]
text_response, logs = prompt_gemini(input_prompt=input_prompt, with_tokens_info=True)
print(logs)
display(Markdown(text_response))
# Out:
# {'model': 'gemini-2.5-pro', 'input_tokens': 18, 'output_tokens': 1395}
# Of course! This is a fundamental concept in deep learning. Here’s a detailed breakdown of the difference between a standard Neural Network and a Convolutional Neural Network.
#
# ### The High-Level Analogy
#
# *   **Standard Neural Network (NN):** Think of it as a **general-purpose problem solver**. It can learn from any kind of data you give it, but it doesn't have any built-in assumptions about that data. It's like a student who can learn any subject but starts with a blank slate for each one.
#
# *   **Convolutional Neural Network (CNN):** Think of it as a **specialist, specifically an expert in vision**. It's designed with the strong assumption that the input data has a spatial structure (like an image, where pixels close to each other are related). It's like a student who has already taken courses in optics and anatomy, making them perfectly suited to become an eye doctor.
#
# A CNN is a **type** of Neural Network, not a completely separate concept. It just has a specialized architecture for a specific kind of data.
#
# ---
#
# ### What is a Standard Neural Network (NN)?
# Also known as a **Fully Connected Network** or **Dense Network**.
#
# *   **Structure:** It's organized in layers of neurons (input, hidden, and output). The defining feature is that **every neuron in one layer is connected to *every* neuron in the next layer**.
#
#
#
# *   **How it sees data:** It takes a flat vector of numbers as input. If you give it an image, you first have to "unroll" or "flatten" the 2D image into a single, long 1D vector.
# *   **The Problem with Images:** When you flatten an image, you **lose all spatial information**. The network has no idea which pixels were originally next to each other. For a 100x100 pixel image, the first pixel and the second pixel are treated with the same relationship as the first pixel and the 500th pixel. This makes it very hard for the network to learn about features like edges, corners, or textures.
# *   **Parameter Inefficiency:** A 224x224 color image has 224 * 224 * 3 = 150,528 input values. If the first hidden layer has 1000 neurons, you would need over **150 million** weights (parameters) just for that first layer! This is computationally expensive and prone to overfitting.
#
# ---
#
# ### What is a Convolutional Neural Network (CNN)?
# A CNN is a neural network architecture specifically designed to process grid-like data, such as images. It uses special layers to preserve and learn from the spatial relationships in the data.
#
# *   **Structure:** Instead of being fully connected, a CNN uses three main types of layers:
#     1.  **Convolutional Layers:** The core building block.
#     2.  **Pooling Layers:** To downsample and reduce complexity.
#     3.  **Fully Connected Layers:** Used at the end for classification.
#
#
#
# *   **How it sees data:** It keeps the input as a 2D (or 3D for color) grid. It works directly on the image's structure.
#
# ---
#
# ### The Key Differences Explained
#
# | Feature | Standard Neural Network (NN) | Convolutional Neural Network (CNN) |
# | :--- | :--- | :--- |
# | **Architecture** | **Fully Connected.** Every neuron connects to every neuron in the next layer. | **Locally Connected.** Neurons are only connected to a small, local region of the layer before them. |
# | **Best Suited For** | Tabular data, text data (after processing), general-purpose classification and regression. | Grid-like data: images, video frames, audio spectrograms, time-series data. |
# | **Key Operation** | Matrix multiplication (dot product of inputs and weights). | **Convolution.** A small filter (kernel) slides over the input image to create feature maps. |
# | **Spatial Awareness** | **None.** It loses all spatial information when the input is flattened. | **Excellent.** The entire architecture is built to understand and preserve spatial hierarchies (pixels form edges, edges form shapes, shapes form objects). |
# | **Parameter Sharing** | **No.** Every connection has its own unique weight. This leads to a huge number of parameters. | **Yes.** The same filter (with the same set of weights) is used across the entire image. This drastically reduces the number of parameters and makes the network more efficient. |
# | **Invariance** | Not inherently good at it. If you shift an object in an image, the flattened input vector changes completely, and the network may fail to recognize it. | **Translation Invariant.** Due to convolutions and pooling, a CNN can recognize an object regardless of where it appears in the image. |
#
# ### A Deeper Dive into CNN's Special Layers
#
# 1.  **Convolutional Layer:** This is the magic. Instead of looking at the whole image at once, this layer uses a small "filter" or "kernel" (e.g., a 3x3 or 5x5 grid of weights) that slides over the image. This filter is designed to detect a specific feature, like a vertical edge, a corner, or a patch of color. The output is a "feature map" that shows where in the image that feature was detected.
#
# 2.  **Pooling Layer:** This layer's job is to simplify. It reduces the size of the feature maps, which makes the network faster and helps it generalize better. The most common type is "Max Pooling," which takes a small window (e.g., 2x2) and keeps only the maximum value, effectively summarizing the most prominent feature in that patch.
#
# ### Summary: When to Use Which?
#
# *   **Use a Standard Neural Network when:**
#     *   Your data is in tabular form (like an Excel spreadsheet).
#     *   You are working with non-spatial data, like customer information or sensor readings.
#     *   The order of the input features doesn't matter.
#
# *   **Use a Convolutional Neural Network when:**
#     *   You are working with **images** (the #1 use case: image classification, object detection).
#     *   You are working with **video** (a sequence of images).
#     *   Your data has a clear spatial or grid-like structure (e.g., audio converted to a spectrogram, some types of time-series data).

# %% [markdown]
# [**the difference between the two models**]
#
# The answer using the Gemini-2.5-Flash-lite model is basically like a course PowerPoint. It explains the main ideas of each concept and then summarizes
# the differences between these two concepts simply. The model focuses more on being simple and key points like core definitions and essential properties.
# Also, the description of this model is rather concise, and may require some prior background knowledge fully understand. In contrast, the Gemini-pro
# model explains the answers in detail and even describes them with analogies and what they can do in practice to help get a better understanding. It
# delivers a narrative, flowing explanation. To differentiate these two, I consider the Gemini-2.5-Flash-lite a technical and textbook-like anwer robot
# while Gemini-pro a conversational and explanatory teacher.

# %%
#if changing the system prompt into "You are a university professor from computer science deparment teaching machine learning" (with gemini-2,5-flash-lite)
input_prompt = ["Tell me the difference between neural network and convolution neural network"]
text_response, logs = prompt_gemini(input_prompt=input_prompt, with_tokens_info=True)
print(logs)
display(Markdown(text_response))
# Out:
# {'model': 'gemini-2.5-flash-lite', 'input_tokens': 27, 'output_tokens': 1562}
# Ah, an excellent question that gets to the heart of how we process information in machine learning! It's a common point of confusion, so let's break it down clearly.
#
# Think of it this way: **A Convolutional Neural Network (CNN) is a *specialized type* of Neural Network (NN).** All CNNs are NNs, but not all NNs are CNNs.
#
# Let's start with the broader concept:
#
# ## Neural Networks (NNs) - The Generalists
#
# Imagine a traditional Neural Network, often referred to as a **Fully Connected Neural Network (FCNN)** or a **Multilayer Perceptron (MLP)**.
#
# *   **Structure:** They are composed of layers of interconnected "neurons" (or nodes). Each neuron in one layer is connected to *every* neuron in the next layer.
# *   **How they learn:** They learn by adjusting the "weights" of these connections. During training, the network receives input data, makes a prediction, and then compares that prediction to the actual output. The difference (error) is used to update the weights through a process called **backpropagation**, aiming to minimize the error.
# *   **Input:** They typically take flattened, one-dimensional vectors of data as input. For example, if you have an image, you'd flatten all its pixels into a single long list.
# *   **Strengths:** Good for general-purpose pattern recognition, classification, and regression tasks where the spatial relationships between input features are not as critical or are already implicitly handled by the input representation.
# *   **Weaknesses:**
#     *   **Scalability with high-dimensional data:** For images, flattening them into a vector leads to an enormous number of connections. A 100x100 pixel grayscale image has 10,000 pixels. If the first hidden layer has 1000 neurons, that's 10,000 * 1000 = 10 million weights just for the first layer! This becomes computationally very expensive and prone to overfitting.
#     *   **Loss of spatial information:** Flattening an image destroys the inherent 2D (or 3D) structure. A pixel's relationship to its immediate neighbors is lost.
#
# ## Convolutional Neural Networks (CNNs) - The Specialists for Spatial Data
#
# Now, let's introduce CNNs. They were specifically designed to excel at processing data that has a grid-like topology, most famously **images**.
#
# *   **Key Innovation: Convolutional Layers:** This is the defining feature. Instead of connecting every neuron to every neuron in the next layer, CNNs use **convolutional filters (or kernels)**.
#     *   **What is a filter?** A small matrix of weights that slides (convolves) over the input data (e.g., an image).
#     *   **How it works:** The filter performs element-wise multiplication with the part of the input it's currently over, and then sums up the results. This produces a single value in the output "feature map."
#     *   **Purpose:** These filters are designed to detect specific local features, like edges, corners, textures, or simple shapes.
# *   **Other Important Layers in CNNs:**
#     *   **Pooling Layers (e.g., Max Pooling):** These layers downsample the feature maps, reducing their spatial dimensions. This helps to make the network more robust to small variations in the position of features and reduces computational cost.
#     *   **Activation Functions (e.g., ReLU):** Applied after convolutional and pooling layers to introduce non-linearity.
#     *   **Fully Connected Layers:** Typically, at the end of a CNN, after several convolutional and pooling layers, the extracted features are flattened and fed into one or more fully connected layers for final classification or regression.
# *   **How they learn:** Similar to NNs, they learn through backpropagation, but the weights being adjusted are primarily those within the convolutional filters.
# *   **Strengths:**
#     *   **Preserves spatial hierarchy:** By using filters that operate on local regions, CNNs maintain the spatial relationships between pixels.
#     *   **Parameter sharing:** The same filter is applied across the entire input. This drastically reduces the number of parameters compared to FCNNs, making them more efficient and less prone to overfitting, especially for image data.
#     *   **Translation invariance:** Due to parameter sharing and pooling, CNNs can recognize a feature regardless of where it appears in the image.
#     *   **Feature extraction:** They automatically learn hierarchical representations of features, starting from simple edges and building up to complex objects.
# *   **Weaknesses:**
#     *   **Less effective for non-spatial data:** While you *can* use CNNs for sequential data (like text) by treating it as a 1D grid, they are not as inherently suited as Recurrent Neural Networks (RNNs) for capturing long-range dependencies in sequences.
#     *   **Can be computationally intensive to train:** Despite parameter sharing, deep CNNs can still require significant computational resources.
#
# ## The Core Difference Summarized:
#
# | Feature             | Neural Network (Fully Connected)                               | Convolutional Neural Network (CNN)                                     |
# | :------------------ | :------------------------------------------------------------- | :--------------------------------------------------------------------- |
# | **Primary Purpose** | General pattern recognition, classification, regression.       | Processing grid-like data, especially images, for feature extraction.  |
# | **Key Operation**   | Matrix multiplication between input and weights.               | **Convolution** using learnable filters (kernels).                     |
# | **Connectivity**    | **Fully connected:** Each neuron connects to all neurons in the next layer. | **Locally connected:** Neurons connect to small local regions of the input. |
# | **Parameter Usage** | High number of parameters, especially for high-dimensional input. | **Parameter sharing:** Filters are reused across the input, reducing parameters. |
# | **Spatial Info**    | Loses spatial information when input is flattened.             | **Preserves spatial hierarchy** and relationships.                     |
# | **Input Type**      | Typically 1D vectors.                                          | Typically 2D or 3D grids (images, video, etc.).                        |
# | **Efficiency**      | Less efficient for images due to massive parameter count.      | More efficient for images due to parameter sharing and local connectivity. |
#
# **Analogy:**
#
# Imagine you're trying to identify a specific object in a large, complex scene.
#
# *   **A regular NN** would be like trying to describe the entire scene to someone by listing every single pixel's color and position. It's overwhelming and hard to pick out details.
# *   **A CNN** is like having a set of specialized magnifying glasses (the filters). One magnifying glass is good at spotting straight lines, another at curves, another at specific color combinations. You slide these magnifying glasses over the scene, and each one highlights where it finds its specific feature. Then, you combine these highlighted features to understand the bigger picture.
#
# In essence, CNNs are a brilliant architectural innovation that leverages the inherent structure of data like images to learn more efficiently and effectively. They are the workhorses behind much of modern computer vision.
#
# I hope this clarifies the distinction! Do you have any follow-up questions on specific aspects, like how convolution works or the role of pooling?

# %% [markdown]
# [**Observation of changing the system prompt while using Gemini-2.5-flash-lite**]
#
# The answer with the original system prompt is simpler, more practice-oriented, and more suitable for readers who are new to learn machine learning.
# It simply summarizes the key reasons of the two concepts and is more like a textbook answer. On the other hand, after we change the system prompt to
# university professor, the answer becomes more detailed, and the tone also turns into a professor's tone teaching a machine learning course. The answer
# also add some additional background concept, reasons, limitations, instances, strengths, and weaknesses which we might face in practice with analogies.
# To summarize, the content is deeper and is exactly what we would listen to in a professor's course.

# %% [markdown]
# ---
# ### <a id='toc1_5_6_'></a>[**2.2 Structured Output**](#toc0_)
#
# By default, an LLM responds with unstructured, free-form text. For data mining, this is often impractical, as we need data in a predictable format to load into tools like a pandas DataFrame for analysis. **Structured output** is a powerful feature that forces the model to return its response in a specific, machine-readable format, such as JSON.
#
# The key to enabling this is to provide the model with a **response schema**. This schema acts as a strict template or blueprint that the model's output must conform to. Instead of generating a paragraph, the model will fill in the fields defined in your schema with the relevant information it extracts from the prompt.
#
# In the following code, we define this schema using Python classes. Think of each class as defining a JSON object:
# *   The **attributes** of the class (e.g., `topic_name`, `sub_title`) become the keys in the final JSON object.
# *   The **type hints** for those attributes (e.g., `str`, `list`) tell the model what kind of data is expected for each key's value.
#
# We can even nest these classes inside one another to create complex, hierarchical JSON structures. This allows us to precisely control the format of the output, transforming the LLM from a simple text generator into a reliable tool for automated and structured data extraction.
#
# [Gemini's Structured Output Documentation](https://ai.google.dev/gemini-api/docs/structured-output)
#
# For data validation of schemas Gemini API uses the Pydantic library, for more documentation on it you can check: [Pydantic](https://docs.pydantic.dev/latest/)
#
# [JSON Format Documentation](https://docs.python.org/3/library/json.html)

# %%
from pydantic import BaseModel

# We define our structure schema that Gemini should follow for the output response

# Subsections on the topics we query
class Subsection(BaseModel):
    sub_title: str
    sub_explanation: str

# The top-level structure for the entire topic analysis
class Topic(BaseModel):
    topic_name: str
    subsections: list[Subsection]

# %%
input_prompt = ["Explain what are machine learning, data centers, llms and how do they relate to each other."]
text_response = prompt_gemini(input_prompt = input_prompt, schema = list[Topic])
print(text_response)
# Out:
# [
#   {
#     "topic_name": "Machine Learning",
#     "subsections": [
#       {
#         "sub_title": "Definition",
#         "sub_explanation": "Machine learning (ML) is a subset of artificial intelligence (AI) that focuses on building systems that can learn from and make decisions based on data. Instead of being explicitly programmed, ML algorithms use statistical techniques to enable systems to 'learn' from data, identify patterns, and make predictions or decisions without human intervention."
#       },
#       {
#         "sub_title": "Types of Machine Learning",
#         "sub_explanation": "Common types include supervised learning (learning from labeled data), unsupervised learning (finding patterns in unlabeled data), and reinforcement learning (learning through trial and error with rewards and penalties)."
#       },
#       {
#         "sub_title": "Applications",
#         "sub_explanation": "ML is used in a wide range of applications, such as image recognition, natural language processing, recommendation systems, fraud detection, and medical diagnosis."
#       }
#     ]
#   },
#   {
#     "topic_name": "Data Centers",
#     "subsections": [
#       {
#         "sub_title": "Definition",
#         "sub_explanation": "A data center is a dedicated physical facility that an organization uses to house its critical IT infrastructure, including servers, storage systems, networking equipment, and related components. These facilities are designed to provide a secure, reliable, and controlled environment for computing operations."
#       },
#       {
#         "sub_title": "Key Components",
#         "sub_explanation": "Essential components include servers, storage devices, network switches and routers, power supplies (including UPS and generators), cooling systems (HVAC), and physical security measures."
#       },
#       {
#         "sub_title": "Purpose",
#         "sub_explanation": "Data centers serve as the central hub for data storage, processing, and management, enabling businesses to run applications, host websites, and manage their digital operations."
#       }
#     ]
#   },
#   {
#     "topic_name": "Large Language Models (LLMs)",
#     "subsections": [
#       {
#         "sub_title": "Definition",
#         "sub_explanation": "Large Language Models (LLMs) are a type of artificial intelligence model that are trained on massive amounts of text data. They are designed to understand, generate, and manipulate human language. LLMs are characterized by their enormous size (billions or trillions of parameters) and their ability to perform a wide variety of natural language processing tasks."
#       },
#       {
#         "sub_title": "Capabilities",
#         "sub_explanation": "LLMs can perform tasks such as text generation, translation, summarization, question answering, code generation, and creative writing. They learn complex linguistic patterns, grammar, facts, and reasoning abilities from their training data."
#       },
#       {
#         "sub_title": "Underlying Technology",
#         "sub_explanation": "LLMs are typically built using deep learning architectures, most notably the Transformer architecture, which allows them to process sequential data like text very effectively."
#       }
#     ]
#   },
#   {
#     "topic_name": "Relationship Between Machine Learning, Data Centers, and LLMs",
#     "subsections": [
#       {
#         "sub_title": "LLMs as a Product of Machine Learning",
#         "sub_explanation": "LLMs are a sophisticated application and outcome of machine learning research and development. The techniques used to train LLMs, such as deep learning and neural networks, are core machine learning concepts. Therefore, LLMs are a specific, advanced type of machine learning model."
#       },
#       {
#         "sub_title": "Data Centers as the Foundation for LLMs and ML",
#         "sub_explanation": "Training and running LLMs, as well as many other complex machine learning models, requires immense computational power and vast amounts of data storage. Data centers provide the necessary infrastructure – high-performance servers, specialized hardware (like GPUs and TPUs), robust networking, and reliable power – to handle these computationally intensive tasks. Without data centers, it would be practically impossible to develop, train, and deploy LLMs at scale."
#       },
#       {
#         "sub_title": "Interdependence",
#         "sub_explanation": "In essence, machine learning is the field of study and the set of techniques. LLMs are a powerful manifestation of these techniques. Data centers are the physical environments and infrastructure that enable the training, deployment, and operation of both general machine learning models and highly demanding LLMs. LLMs rely on ML principles, and both ML and LLMs rely heavily on the resources provided by data centers."
#       }
#     ]
#   }
# ]

# %%
import json

# Now the response can be parsed to a python object using the JSON dictionary structure loading
structured_resp = json.loads(text_response)
print(structured_resp)
print(type(structured_resp))
# Out:
# [{'topic_name': 'Machine Learning', 'subsections': [{'sub_title': 'Definition', 'sub_explanation': "Machine learning (ML) is a subset of artificial intelligence (AI) that focuses on building systems that can learn from and make decisions based on data. Instead of being explicitly programmed, ML algorithms use statistical techniques to enable systems to 'learn' from data, identify patterns, and make predictions or decisions without human intervention."}, {'sub_title': 'Types of Machine Learning', 'sub_explanation': 'Common types include supervised learning (learning from labeled data), unsupervised learning (finding patterns in unlabeled data), and reinforcement learning (learning through trial and error with rewards and penalties).'}, {'sub_title': 'Applications', 'sub_explanation': 'ML is used in a wide range of applications, such as image recognition, natural language processing, recommendation systems, fraud detection, and medical diagnosis.'}]}, {'topic_name': 'Data Centers', 'subsections': [{'sub_title': 'Definition', 'sub_explanation': 'A data center is a dedicated physical facility that an organization uses to house its critical IT infrastructure, including servers, storage systems, networking equipment, and related components. These facilities are designed to provide a secure, reliable, and controlled environment for computing operations.'}, {'sub_title': 'Key Components', 'sub_explanation': 'Essential components include servers, storage devices, network switches and routers, power supplies (including UPS and generators), cooling systems (HVAC), and physical security measures.'}, {'sub_title': 'Purpose', 'sub_explanation': 'Data centers serve as the central hub for data storage, processing, and management, enabling businesses to run applications, host websites, and manage their digital operations.'}]}, {'topic_name': 'Large Language Models (LLMs)', 'subsections': [{'sub_title': 'Definition', 'sub_explanation': 'Large Language Models (LLMs) are a type of artificial intelligence model that are trained on massive amounts of text data. They are designed to understand, generate, and manipulate human language. LLMs are characterized by their enormous size (billions or trillions of parameters) and their ability to perform a wide variety of natural language processing tasks.'}, {'sub_title': 'Capabilities', 'sub_explanation': 'LLMs can perform tasks such as text generation, translation, summarization, question answering, code generation, and creative writing. They learn complex linguistic patterns, grammar, facts, and reasoning abilities from their training data.'}, {'sub_title': 'Underlying Technology', 'sub_explanation': 'LLMs are typically built using deep learning architectures, most notably the Transformer architecture, which allows them to process sequential data like text very effectively.'}]}, {'topic_name': 'Relationship Between Machine Learning, Data Centers, and LLMs', 'subsections': [{'sub_title': 'LLMs as a Product of Machine Learning', 'sub_explanation': 'LLMs are a sophisticated application and outcome of machine learning research and development. The techniques used to train LLMs, such as deep learning and neural networks, are core machine learning concepts. Therefore, LLMs are a specific, advanced type of machine learning model.'}, {'sub_title': 'Data Centers as the Foundation for LLMs and ML', 'sub_explanation': 'Training and running LLMs, as well as many other complex machine learning models, requires immense computational power and vast amounts of data storage. Data centers provide the necessary infrastructure – high-performance servers, specialized hardware (like GPUs and TPUs), robust networking, and reliable power – to handle these computationally intensive tasks. Without data centers, it would be practically impossible to develop, train, and deploy LLMs at scale.'}, {'sub_title': 'Interdependence', 'sub_explanation': 'In essence, machine learning is the field of study and the set of techniques. LLMs are ...
# <class 'list'>

# %%
# So now we have an object that we can explore/use in a pythonic way for our purposes
for topic in structured_resp:
    print(topic["topic_name"], "\n")
    # We can access each subsection as well
    for subsection in topic["subsections"]:
        print("\t", subsection["sub_title"], "\n")
        print("\t\t", subsection["sub_explanation"], "\n")
# Out:
# Machine Learning
#
# 	 Definition
#
# 		 Machine learning (ML) is a subset of artificial intelligence (AI) that focuses on building systems that can learn from and make decisions based on data. Instead of being explicitly programmed, ML algorithms use statistical techniques to enable systems to 'learn' from data, identify patterns, and make predictions or decisions without human intervention.
#
# 	 Types of Machine Learning
#
# 		 Common types include supervised learning (learning from labeled data), unsupervised learning (finding patterns in unlabeled data), and reinforcement learning (learning through trial and error with rewards and penalties).
#
# 	 Applications
#
# 		 ML is used in a wide range of applications, such as image recognition, natural language processing, recommendation systems, fraud detection, and medical diagnosis.
#
# Data Centers
#
# 	 Definition
#
# 		 A data center is a dedicated physical facility that an organization uses to house its critical IT infrastructure, including servers, storage systems, networking equipment, and related components. These facilities are designed to provide a secure, reliable, and controlled environment for computing operations.
#
# 	 Key Components
#
# 		 Essential components include servers, storage devices, network switches and routers, power supplies (including UPS and generators), cooling systems (HVAC), and physical security measures.
#
# 	 Purpose
#
# 		 Data centers serve as the central hub for data storage, processing, and management, enabling businesses to run applications, host websites, and manage their digital operations.
#
# Large Language Models (LLMs)
#
# 	 Definition
#
# 		 Large Language Models (LLMs) are a type of artificial intelligence model that are trained on massive amounts of text data. They are designed to understand, generate, and manipulate human language. LLMs are characterized by their enormous size (billions or trillions of parameters) and their ability to perform a wide variety of natural language processing tasks.
#
# 	 Capabilities
#
# 		 LLMs can perform tasks such as text generation, translation, summarization, question answering, code generation, and creative writing. They learn complex linguistic patterns, grammar, facts, and reasoning abilities from their training data.
#
# 	 Underlying Technology
#
# 		 LLMs are typically built using deep learning architectures, most notably the Transformer architecture, which allows them to process sequential data like text very effectively.
#
# Relationship Between Machine Learning, Data Centers, and LLMs
#
# 	 LLMs as a Product of Machine Learning
#
# 		 LLMs are a sophisticated application and outcome of machine learning research and development. The techniques used to train LLMs, such as deep learning and neural networks, are core machine learning concepts. Therefore, LLMs are a specific, advanced type of machine learning model.
#
# 	 Data Centers as the Foundation for LLMs and ML
#
# 		 Training and running LLMs, as well as many other complex machine learning models, requires immense computational power and vast amounts of data storage. Data centers provide the necessary infrastructure – high-performance servers, specialized hardware (like GPUs and TPUs), robust networking, and reliable power – to handle these computationally intensive tasks. Without data centers, it would be practically impossible to develop, train, and deploy LLMs at scale.
#
# 	 Interdependence
#
# 		 In essence, machine learning is the field of study and the set of techniques. LLMs are a powerful manifestation of these techniques. Data centers are the physical environments and infrastructure that enable the training, deployment, and operation of both general machine learning models and highly demanding LLMs. LLMs rely on ML principles, and both ML and LLMs rely heavily on the resources provided by data centers.

# %% [markdown]
# ##### <a id='toc1_5_6_1_1_'></a>[**>>> Exercise 2 (Take home):**](#toc0_)
#
# Try a prompt with your own schema structure, it needs to be completely different to the example. It should show an intuitive way to represent the text output of the model based on the prompt you chose. See the documentation for reference: https://ai.google.dev/gemini-api/docs/structured-output

# %%
# Answer here
from pydantic import BaseModel
import json

class AnalysisResult(BaseModel):
     industry: str
     net_gross: int
     outlook: str
class Respontopic(BaseModel):
    company_name: str
    subsections: list[AnalysisResult]
input_prompt = ["Tell me the ten companies with the highest net gross in Taiwan right now, their industry sectors, and explain detailly company outlook and advantage."]
analysis_response = prompt_gemini(input_prompt = input_prompt, schema = list[Respontopic])
structured_analy = json.loads(analysis_response)

for topic in structured_analy:
    print(topic["company_name"], "\n")
    for subsection in topic["subsections"]:
        print("\t", subsection["industry"], "\n")
        print("\t", subsection["net_gross"], "\n")
        print("\t", subsection["outlook"], "\n")
# Out:
# TSMC
#
# 	 Semiconductors
#
# 	 20000000000
#
# 	 Extremely positive. TSMC is the world's leading contract chip manufacturer, essential for the production of advanced semiconductors used in everything from smartphones to AI. Their technological leadership and massive production capacity give them a significant competitive advantage. The increasing demand for AI chips and the ongoing digitization of industries ensure a strong future. Their advantage lies in their advanced manufacturing processes, strong customer relationships with major tech companies, and significant R&D investment.
#
# Hon Hai Precision Industry (Foxconn)
#
# 	 Electronics Manufacturing Services
#
# 	 15000000000
#
# 	 Positive. As the world's largest contract electronics manufacturer, Foxconn is a critical supplier for many global tech giants, including Apple. While facing competition and the need to diversify beyond consumer electronics, their scale, efficiency, and established supply chain provide a strong foundation. The outlook is bolstered by expansion into areas like electric vehicles and semiconductor manufacturing. Their advantage is their unparalleled scale of operations, sophisticated supply chain management, and long-standing partnerships with major brands.
#
# MediaTek
#
# 	 Semiconductors
#
# 	 10000000000
#
# 	 Very positive. MediaTek has emerged as a major player in smartphone chipsets, particularly in the mid-range and high-end segments, challenging established competitors. Their focus on integrated solutions and competitive pricing has driven significant growth. The increasing demand for 5G devices and smart home products further strengthens their outlook. Their advantage lies in their strong R&D capabilities, cost-effective chip designs, and broad market penetration, especially in emerging markets.
#
# Qualcomm
#
# 	 Semiconductors
#
# 	 9000000000
#
# 	 Positive. While not headquartered in Taiwan, Qualcomm has significant operations and R&D presence, and its influence on the Taiwanese semiconductor ecosystem is immense. They are a leader in mobile chipsets and wireless communication technologies. The expansion into automotive, IoT, and 5G infrastructure presents substantial growth opportunities. Their advantage is their extensive patent portfolio in wireless technologies, strong relationships with mobile device manufacturers, and continuous innovation in connectivity.
#
# UMC (United Microelectronics Corporation)
#
# 	 Semiconductors
#
# 	 7000000000
#
# 	 Positive. UMC is a major foundry service provider, focusing on mature process technologies that are still in high demand for a wide range of applications, including automotive and IoT. While not at the forefront of leading-edge nodes, their specialization and capacity are crucial for the global chip supply chain. The ongoing global chip shortage and increased demand for specialized chips support their outlook. Their advantage is their focus on specialized manufacturing processes, significant production capacity, and strong customer base for mature nodes.
#
# Formosa Plastics Group
#
# 	 Petrochemicals and Diversified Industries
#
# 	 6000000000
#
# 	 Stable to positive. Formosa Plastics is a diversified conglomerate with significant interests in petrochemicals, plastics, textiles, and electronics. The petrochemical sector is cyclical, but demand for plastics and related materials remains robust globally. Their diversification across multiple industries provides resilience. The outlook is supported by global economic growth and demand for their products in construction, automotive, and consumer goods. Their advantage is their vertical integration, massive scale of operations, and diversified business portfolio.
#
# Nan Ya Plastics Corporation
#
# 	 Plastics and Chemicals
#
# 	 5500000000
#
# 	 Stable. As a key subsidiary of Formosa Plastics Group, Nan Ya Plastics is a major producer of plastic products, polyester fibers, and electronic materials. Demand is tied to global economic activity and specific end-markets like electronics and textiles. The company benefits from the group's integrated supply chain and economies of scale. Their advantage lies in their extensive product range, large production capacity, and strong position within the Formosa Plastics conglomerate.
#
# Chunghwa Telecom
#
# 	 Telecommunications
#
# 	 5000000000
#
# 	 Stable to positive. As Taiwan's largest telecommunications company, Chunghwa Telecom is a dominant player in fixed-line, mobile, and broadband services. The ongoing rollout and adoption of 5G, along with increasing demand for data services and cloud solutions, provide growth opportunities. Their extensive infrastructure and large customer base are key strengths. Their advantage is their market leadership, comprehensive network infrastructure, and strong brand recognition.
#
# ASE Technology Holding
#
# 	 Semiconductor Packaging and Testing
#
# 	 4500000000
#
# 	 Very positive. ASE is the world's largest provider of semiconductor packaging and testing services, a critical step in the chip manufacturing process. The increasing complexity of semiconductors and the demand for advanced packaging solutions (like 2.5D and 3D packaging) for AI, high-performance computing, and mobile devices drive their growth. Their advantage is their global leadership in advanced packaging technologies, extensive service offerings, and strong relationships with chip designers and foundries.
#
# Pegatron Corporation
#
# 	 Electronics Manufacturing Services
#
# 	 4000000000
#
# 	 Positive. Pegatron is a significant player in electronics manufacturing services, often seen as a competitor and partner to Foxconn, particularly in producing consumer electronics like iPhones and laptops. They are expanding their capabilities and customer base. The outlook is supported by continued demand for consumer electronics and their ability to secure new contracts. Their advantage is their strong manufacturing capabilities, competitive pricing, and growing client portfolio.

# %% [markdown]
# ---
# ### <a id='toc1_5_7_'></a>[**2.3 Information Extraction and Grounding:**](#toc0_)
#
# `NOTE: This whole section including the exercise is now considered a bonus section, not counted for the main grade.`
#
# When using LLMs to extract structured data from text, two main challenges arise:
#
# 1.  **Trust:** LLMs can "hallucinate" or invent information. We need to ensure the extracted data is accurate and comes directly from the source text.
# 2.  **Scalability:** We need a reliable way to extract complex information consistently from thousands of large, messy documents.
#
# The solution to these challenges is **grounding**—the process of linking every piece of extracted data back to its specific origin in the source document. This creates a verifiable audit trail, building trust in the output.

# %% [markdown]
# ---
# #### <a id='toc1_5_7_1_'></a>[**`langextract`: A Library for Grounded Extraction**](#toc0_)
#
# **`langextract`** is an open-source Python library from Google designed to create trustworthy data extraction pipelines. It uses LLMs to convert unstructured text into structured data with a focus on reliability and traceability.
#
# **Key Features:**
#
# *   **Precise Grounding:** Its core feature. It maps every extracted item to its exact character position in the original text, allowing for easy verification.
# *   **Reliable Structured Output:** Uses examples (few-shot prompting) to ensure the LLM's output consistently follows a predefined format.
# *   **Adaptable & No Fine-Tuning:** Can be adapted to any domain (e.g., legal, medical) simply by changing the examples and instructions, without needing to retrain a model.
# *   **Handles Long Documents:** Built to process lengthy texts that might exceed an LLM's standard context window.
# *   **Flexible LLM Support:** It is model-agnostic and works with various LLMs like Gemini, OpenAI models, and even local open-source models through Ollama.
#
# **`Github repository:`** [langextract](https://github.com/google/langextract)

# %% [markdown]
# ---
#
# ##### <a id='toc1_5_7_1_1_'></a>[**2.3.1 Using PDF Documents:**](#toc0_)
#
# For PDF Document information extraction we are going to use the `pymupdf` library. Documentation: [pymupdf](https://pymupdf.readthedocs.io/en/latest/)
#
# And then we are going to pass it on to langextract to get insights on the document's content.
#
# We can also process documents using Gemini, for more information you can check their documentation: [Document Understanding](https://ai.google.dev/gemini-api/docs/document-processing)

# %%
import pymupdf
# Extract text from the PDF and format it for the prompt
# This is a review from the movie interstellar
pdf_path = "./data/documents/doc_example_review_interstellar.pdf"
formatted_text = ""
try:
    doc = pymupdf.open(pdf_path)
    # In case the PDF documents have more than one page, in this example it only has one
    for i, page in enumerate(doc):
        text = page.get_text("text")
        # Format follows the prompt's requirement: **Page X** """document's text"""
        formatted_text += f'**Page {i + 1}**\n'
        formatted_text += f'"""\n{text.strip()}\n"""\n\n'
    doc.close()
    print(f"✓ Extracted text from '{pdf_path}'")
except Exception as e:
    print(f"Could not read PDF: {e}")
    formatted_text = "Error: Could not process PDF file."
# Out:
# ✓ Extracted text from './data/documents/doc_example_review_interstellar.pdf'

# %%
print(formatted_text)
# Out:
# **Page 1**
# """
# Dan Baldwin
# Group 4
# Auteur Review - Interstellar
# I believe Christopher Nolan: the director behind the 2014 sci-ﬁ/adventure cinematic ‘Interstellar,’
# to be a very intellectual and imaginative inventive talent.
# His style in his previous ﬁlms sets characters in epic unique locations, with gargantuan issues to
# face, and artistically impresses the audience with how the characters solve their problems. For
# example, in Nolan’s 2010 ﬁlm ‘Inception,’ he tackles the idea of dreams, and sets his characters
# diving through dreams within dreams within even more dreams to complete their goals. Because
# this idea is so farfetched, and dreams are a subject in which science has made little factual
# discovery in, Nolan is free to use his creativity to present ideas such as landscapes folding in on
# themselves and corridors spinning, without seeming unrealistic.
# This brain-racking epic theme is once again evident in ‘Interstellar,’ as Nolan sets his characters
# during a second American dust bowl on future Earth. The world is short of food, and will soon be
# uninhabitable. So, ex-NASA pilot ‘Cooper’ (Matthew McConaughey) is summoned back to space
# travel in a bid to ﬁnd a new planet for the species to inhabit. Luckily for Cooper and his team, a
# black hole orbiting Saturn can transport them further into space to land on these potential
# planets.
# Throughout the ﬂick, the crew explore multiple worlds - again feeding Nolan’s mind more
# opportunities to create crazy scenarios. For example, one planet that Cooper and his friends,
# ‘Brand,’ (Anne Hathaway) and ‘Romilly,’ (David Gyasi) visit initially seems like an inﬁnite sea of two
# feet deep water. Not threatening at all right? Well think again, because the crew suddenly ﬁnd out
# that a giant 100ft tidal wave is about to hit them, and they have minutes to ﬂy away. Nolan further
# increases the stakes in this scene as it is explained that every hour spent on this planet counts for
# seven years on earth, meaning the planet will be destroyed before they return if their ship sinks.
# At the climax of the ﬁlm, the crew end up sending themselves through a black hole into a
# tesseract (a 3D representation of a larger dimension) to ﬁnd the ‘secret to harnessing gravity’
# which will let the human race bend space-time in order to survive oﬀ earth. I know. Mental.
# The imagination that Nolan possesses and implicates into ‘Interstellar’ is farfetched and
# wonderful, not only impressing his audience with the appealing visuals he creates, but induces
# them to think and discuss what is going on due its scientiﬁc depth. Personally, as someone who is
# bamboozled by the idea of how big the universe is, I ﬁnd it unendingly entertaining to repeatedly
# watch this ﬁlm and understanding it more each time, and can only hope the technology portrayed
# will one day come true.
# Overall, ‘Interstellar’ is a clear example of Nolan’s auteur talent, as he once again ﬁgments yet
# another cluster of conditions for us to marvel at. With a fantastic score from world famous
# composer Hanz Zimmer, his epic, orchestral theme sets the audience in the palm of his hands as
# we stress over how we are all going to be saved once again.
# """

# %% [markdown]
# We define our prompt and examples based on our required type of data, in this case we are going to do it having `movie reviews` in mind.

# %%
import langextract as lx
import textwrap

# Defining the extraction prompt for "movie review" type of data
prompt = textwrap.dedent("""\
    Extract specific opinions and their impact on the audience from this movie review.
    Important: Use exact text verbatim from the input for extraction_text. Do not paraphrase.
    Extract entities in order of appearance with no overlapping text spans.

    Use the 'opinion_statement' class for direct judgments about film elements (like plot, score, or acting).
    - 'subject' should be the element being reviewed.
    - 'sentiment' should be Positive, Negative, or Neutral.
    - 'key_phrase' should be the core descriptive words.

    Use the 'audience_impact' class for phrases describing the effect on the viewer.
    - 'emotion_evoked' should be the feeling or reaction (e.g., stress, joy, confusion).
    - 'causal_element' is what part of the film caused the reaction.
    - 'target_audience' is who was affected (e.g., 'the audience', 'the reviewer').
    """)

# Providing high-quality examples to guide the model
# These examples show the model exactly how to differentiate between the two classes
examples = [
    # Example 1: Demonstrates a positive opinion on the plot and its direct impact on the reviewer
    lx.data.ExampleData(
        text="The film boasts a truly clever plot that kept me guessing until the very end.",
        extractions=[
            lx.data.Extraction(
                extraction_class="opinion_statement",
                extraction_text="a truly clever plot",
                attributes={
                    "subject": "The plot",
                    "sentiment": "Positive",
                    "key_phrase": "truly clever"
                }
            ),
            lx.data.Extraction(
                extraction_class="audience_impact",
                extraction_text="kept me guessing until the very end",
                attributes={
                    "emotion_evoked": ["engaged", "curious"],
                    "causal_element": "The plot",
                    "target_audience": "the reviewer"
                }
            ),
        ]
    ),
    # Example 2: Shows a negative opinion and a separate audience impact caused by the soundtrack
    lx.data.ExampleData(
        text="Unfortunately, the dialogue felt clunky and unnatural, and the jarring soundtrack made the audience jump.",
        extractions=[
            lx.data.Extraction(
                extraction_class="opinion_statement",
                extraction_text="the dialogue felt clunky and unnatural",
                attributes={
                    "subject": "The dialogue",
                    "sentiment": "Negative",
                    "key_phrase": "clunky and unnatural"
                }
            ),
            lx.data.Extraction(
                extraction_class="audience_impact",
                extraction_text="made the audience jump",
                attributes={
                    "emotion_evoked": ["startled", "on edge"],
                    "causal_element": "The soundtrack",
                    "target_audience": "the audience"
                }
            )
        ]
    )
]

# %% [markdown]
# Here we define our main function to call for langextract information extraction, note that there are some constants in the functions that we are not going to change for the example but it would be required to explore and understand in the exercise. In this function we obtain the resulting raw extracted information into a .jsonl file and the visualization into a .html file. Check the documentation for more information.
#
# The files will be saved in the following directory: `results/info_extractions`

# %%
import os
import langextract as lx

# We define our main langextract function 
def grounded_info_extraction(input_documents, prompt, examples, file_name, model_id ="gemini-2.5-flash-lite", extraction_passes = 1, max_workers = 5, max_char_buffer = 2000):
    result = lx.extract(
        text_or_documents=input_documents,
        prompt_description=prompt,
        examples=examples,
        model_id=model_id,
        extraction_passes=extraction_passes,    # Improves recall through multiple passes over the same text, needs temperature above 0.0
        max_workers=max_workers,         # Parallel processing for speed, remember there are API call rate limits, so do not abuse
        max_char_buffer=max_char_buffer    # Smaller contexts for better accuracy, currently: 1000 characters per batch
    )

    # Display results
    print(f"Extracted {len(result.extractions)} entities:\n")
    for extraction in result.extractions:
        print(f"• {extraction.extraction_class}: '{extraction.extraction_text}'")
        if extraction.attributes:
            for key, value in extraction.attributes.items():
                print(f"  - {key}: {value}")
    
    output_dir = "./results/info_extractions"
    os.makedirs(output_dir, exist_ok=True)
    # Save results to JSONL
    lx.io.save_annotated_documents([result], output_name=f"{file_name}.jsonl", output_dir=output_dir)

    # Generate interactive visualization
    html_content = lx.visualize(f"{output_dir}/{file_name}.jsonl")
    with open(f"{output_dir}/{file_name}_vis.html", "w") as f:
        if hasattr(html_content, 'data'):
            f.write(html_content.data)
        else:
            f.write(html_content)

    print(f"✓ Visualization saved to {output_dir}/{file_name}_vis.html")
    
    # returning html content for display
    return html_content

# %%
html_content = grounded_info_extraction(formatted_text, prompt, examples, "review_extraction_example")
# Out:
# WARNING:google_genai._api_client:Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# Extracted 13 entities:
#
# • opinion_statement: 'a very intellectual and imaginative inventive talent'
#   - subject: Christopher Nolan
#   - sentiment: Positive
#   - key_phrase: very intellectual and imaginative inventive talent
# • opinion_statement: 'artistically impresses the audience'
#   - subject: Nolan's style
#   - sentiment: Positive
#   - key_phrase: artistically impresses
# • opinion_statement: 'This brain-racking epic theme is once again evident in ‘Interstellar,’'
#   - subject: The theme
#   - sentiment: Positive
#   - key_phrase: brain-racking epic theme
# • opinion_statement: 'crazy scenarios'
#   - subject: Nolan's mind
#   - sentiment: Positive
#   - key_phrase: crazy
# • opinion_statement: 'Not threatening at all right?'
#   - subject: The planet
#   - sentiment: Neutral
#   - key_phrase: Not threatening at all
# • opinion_statement: 'a giant 100ft tidal wave is about to hit them'
#   - subject: The tidal wave
#   - sentiment: Negative
#   - key_phrase: giant 100ft tidal wave
# • audience_impact: 'minutes to ﬂy away'
#   - emotion_evoked: ['stress', 'urgency']
#   - causal_element: The tidal wave
#   - target_audience: the crew
# • opinion_statement: 'farfetched and wonderful'
#   - subject: The imagination that Nolan possesses and implicates into ‘Interstellar’
#   - sentiment: Positive
#   - key_phrase: farfetched and wonderful
# • audience_impact: 'not only impressing his audience with the appealing visuals he creates, but induces them to think and discuss what is going on due its scientiﬁc depth'
#   - emotion_evoked: ['impressed', 'thoughtful', 'engaged']
#   - causal_element: The appealing visuals and scientific depth
#   - target_audience: his audience
# • audience_impact: 'I ﬁnd it unendingly entertaining to repeatedly watch this ﬁlm and understanding it more each time'
#   - emotion_evoked: ['entertained', 'intellectually stimulated']
#   - causal_element: The film's complexity and depth
#   - target_audience: the reviewer
# • opinion_statement: 'a clear example of Nolan’s auteur talent'
#   - subject: ‘Interstellar’
#   - sentiment: Positive
#   - key_phrase: clear example of Nolan’s auteur talent
# • opinion_statement: 'fantastic score'
#   - subject: The score
#   - sentiment: Positive
#   - key_phrase: fantastic
# • audience_impact: 'sets the audience in the palm of his hands as we stress over how we are all going to be saved once again'
#   - emotion_evoked: ['captivated', 'stressed']
#   - causal_element: His epic, orchestral theme
#   - target_audience: the audience
# LangExtract: Saving to results\info_extractions\review_extraction_example.jsonl: 1 docs [00:00, 340.64 docs/s]
# ✓ Saved 1 documents to results\info_extractions\review_extraction_example.jsonl
# LangExtract: Loading results\info_extractions\review_extraction_example.jsonl: 100%|█████████▉| 8.58k/8.58k [00:00<00:00, 8.93MB/s]
# ✓ Loaded 1 documents from results\info_extractions\review_extraction_example.jsonl
# ✓ Visualization saved to ./results/info_extractions/review_extraction_example_vis.html

# %%
import json
# We can also observe the structure of the raw extracted data
with open("./results/info_extractions/review_extraction_example.jsonl", "r") as f:
    content_extracted_raw = json.load(f)
content_extracted_raw
# Out:
# {'extractions': [{'extraction_class': 'opinion_statement',
#    'extraction_text': 'a very intellectual and imaginative inventive talent',
#    'char_interval': {'start_pos': 172, 'end_pos': 224},
#    'alignment_status': 'match_exact',
#    'extraction_index': 1,
#    'group_index': 0,
#    'description': None,
#    'attributes': {'subject': 'Christopher Nolan',
#     'sentiment': 'Positive',
#     'key_phrase': 'very intellectual and imaginative inventive talent'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'artistically impresses the audience',
#    'char_interval': {'start_pos': 338, 'end_pos': 373},
#    'alignment_status': 'match_exact',
#    'extraction_index': 2,
#    'group_index': 1,
#    'description': None,
#    'attributes': {'subject': "Nolan's style",
#     'sentiment': 'Positive',
#     'key_phrase': 'artistically impresses'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'This brain-racking epic theme is once again evident in ‘Interstellar,’',
#    'char_interval': {'start_pos': 878, 'end_pos': 948},
#    'alignment_status': 'match_exact',
#    'extraction_index': 3,
#    'group_index': 2,
#    'description': None,
#    'attributes': {'subject': 'The theme',
#     'sentiment': 'Positive',
#     'key_phrase': 'brain-racking epic theme'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'crazy scenarios',
#    'char_interval': {'start_pos': 1484, 'end_pos': 1499},
#    'alignment_status': 'match_exact',
#    'extraction_index': 4,
#    'group_index': 3,
#    'description': None,
#    'attributes': {'subject': "Nolan's mind",
#     'sentiment': 'Positive',
#     'key_phrase': 'crazy'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'Not threatening at all right?',
#    'char_interval': {'start_pos': 1676, 'end_pos': 1705},
#    'alignment_status': 'match_exact',
#    'extraction_index': 5,
#    'group_index': 4,
#    'description': None,
#    'attributes': {'subject': 'The planet',
#     'sentiment': 'Neutral',
#     'key_phrase': 'Not threatening at all'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'a giant 100ft tidal wave is about to hit them',
#    'char_interval': {'start_pos': 1764, 'end_pos': 1809},
#    'alignment_status': 'match_exact',
#    'extraction_index': 6,
#    'group_index': 5,
#    'description': None,
#    'attributes': {'subject': 'The tidal wave',
#     'sentiment': 'Negative',
#     'key_phrase': 'giant 100ft tidal wave'}},
#   {'extraction_class': 'audience_impact',
#    'extraction_text': 'minutes to ﬂy away',
#    'char_interval': {'start_pos': 1825, 'end_pos': 1843},
#    'alignment_status': 'match_exact',
#    'extraction_index': 7,
#    'group_index': 6,
#    'description': None,
#    'attributes': {'emotion_evoked': ['stress', 'urgency'],
#     'causal_element': 'The tidal wave',
#     'target_audience': 'the crew'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'farfetched and wonderful',
#    'char_interval': {'start_pos': 2418, 'end_pos': 2443},
#    'alignment_status': 'match_exact',
#    'extraction_index': 1,
#    'group_index': 0,
#    'description': None,
#    'attributes': {'subject': 'The imagination that Nolan possesses and implicates into ‘Interstellar’',
#     'sentiment': 'Positive',
#     'key_phrase': 'farfetched and wonderful'}},
#   {'extraction_class': 'audience_impact',
#    'extraction_text': 'not only impressing his audience with the appealing visuals he creates, but induces them to think and discuss what is going on due its scientiﬁc depth',
#    'char_interval': {'start_pos': 2445, 'end_pos': 2596},
#    'alignment_status': 'match_exact',
#    'extraction_index': 2,
#    'group_index': 1,
#    'description': None,
#    'attributes': {'emotion_evoked': ['impressed', 'thoughtful', 'engaged'],
#     'causal_element': 'The appealing visuals and scientific depth',
#     'target_audience': 'his audience'}},
#   {'extraction_class': 'audience_impact',
#    'extraction_text': 'I ﬁnd it unendingly entertaining to repeatedly watch this ﬁlm and understanding it more each time',
#    'char_interval': {'start_pos': 2680, 'end_pos': 2778},
#    'alignment_status': 'match_exact',
#    'extraction_index': 3,
#    'group_index': 2,
#    'description': None,
#    'attributes': {'emotion_evoked': ['entertained',
#      'intellectually stimulated'],
#     'causal_element': "The film's complexity and depth",
#     'target_audience': 'the reviewer'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'a clear example of Nolan’s auteur talent',
#    'char_interval': {'start_pos': 2876, 'end_pos': 2916},
#    'alignment_status': 'match_exact',
#    'extraction_index': 4,
#    'group_index': 3,
#    'description': None,
#    'attributes': {'subject': '‘Interstellar’',
#     'sentiment': 'Positive',
#     'key_phrase': 'clear example of Nolan’s auteur talent'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'fantastic score',
#    'char_interval': {'start_pos': 3006, 'end_pos': 3021},
#    'alignment_status': 'match_exact',
#    'extraction_index': 5,
#    'group_index': 4,
#    'description': None,
#    'attributes': {'subject': 'The score',
#     'sentiment': 'Positive',
#     'key_phrase': 'fantastic'}},
#   {'extraction_class': 'audience_impact',
#    'extraction_text': 'sets the audience in the palm of his hands as we stress over how we are all going to be saved once again',
#    'char_interval': {'start_pos': 3090, 'end_pos': 3195},
#    'alignment_status': 'match_exact',
#    'extraction_index': 6,
#    'group_index': 5,
#    'description': None,
#    'attributes': {'emotion_evoked': ['captivated', 'stressed'],
#     'causal_element': 'His epic, orchestral theme',
#     'target_audience': 'the audience'}}],
#  'text': '**Page 1**\n"""\nDan Baldwin\nGroup 4\nAuteur Review - Interstellar \nI believe Christopher Nolan: the director behind the 2014 sci-ﬁ/adventure cinematic ‘Interstellar,’ \nto be a very intellectual and imaginative inventive talent.  \nHis style in his previous ﬁlms sets characters in epic unique locations, with gargantuan issues to \nface, and artistically impresses the audience with how the characters solve their problems. For \nexample, in Nolan’s 2010 ﬁlm ‘Inception,’ he tackles the idea of dreams, and sets his characters \ndiving through dreams within dreams within even more dreams to complete their goals. Because \nthis idea is so farfetched, and dreams are a subject in which science has made little factual \ndiscovery in, Nolan is free to use his creativity to present ideas such as landscapes folding in on \nthemselves and corridors spinning, without seeming unrealistic. \nThis brain-racking epic theme is once again evident in ‘Interstellar,’ as Nolan sets his characters \nduring a second American dust bowl on future Earth. The world is short of food, and will soon be \nuninhabitable. So, ex-NASA pilot ‘Cooper’ (Matthew McConaughey) is summoned back to space \ntravel in a bid to ﬁnd a new planet for the species to inhabit. Luckily for Cooper and his team, a \nblack hole orbiting Saturn can transport them further into space to land on these potential \nplanets. \nThroughout the ﬂick, the crew explore multiple worlds - again feeding Nolan’s mind more \nopportunities to create crazy scenarios. For example, one planet that Cooper and his friends, \n‘Brand,’ (Anne Hathaway) and ‘Romilly,’ (David Gyasi) visit initially seems like an inﬁnite sea of two \nfeet deep water. Not threatening at all right? Well think again, because the crew suddenly ﬁnd out \nthat a giant 100ft tidal wave is about to hit them, and they have minutes to ﬂy away. Nolan further \nincreases the stakes in this scene as it is explained that every hour spent on this planet counts for \nseven years on earth, meaning the planet will be destroyed before they return if their ship sinks. \nAt the climax of the ﬁlm, the crew end up sending themselves through a black hole into a \ntesseract (a 3D representation of a larger dimension) to ﬁnd the ‘secret to harnessing gravity’ \nwhich will let the human race bend space-time in order to survive oﬀ earth. I know. Mental. \nThe imagination that Nolan possesses and implicates into ‘Interstellar’ is farfetched and \nwonderful, not only impressing his audience with the appealing visuals he creates, but induces \nthem to think and discuss what is going on due its scientiﬁc depth. Personally, as someone who is \nbamboozled by the idea of how big the universe is, I ﬁnd it unendingly entertaining to repeatedly \nwatch this ﬁlm and understanding it more each time, and can only hope the technology portrayed \nwill one day come true. \nOverall, ‘Interstellar’ is a clear example of Nolan’s auteur talent, as he once again ﬁgments yet \nanother cluster of conditions for us to marvel at. With a fantastic score from world famous \ncomposer Hanz Zimmer, his epic, orchestral theme sets the audience in the palm of his hands as \nwe stress over how we are all going to be saved once again.\n"""\n\n',
#  'document_id': 'doc_30bc5f79'}

# %%
html_content
# Out:
# <style>
# .lx-highlight { position: relative; border-radius:3px; padding:1px 2px;}
# .lx-highlight .lx-tooltip {
#   visibility: hidden;
#   opacity: 0;
#   transition: opacity 0.2s ease-in-out;
#   background: #333;
#   color: #fff;
#   text-align: left;
#   border-radius: 4px;
#   padding: 6px 8px;
#   position: absolute;
#   z-index: 1000;
#   bottom: 125%;
#   left: 50%;
#   transform: translateX(-50%);
#   font-size: 12px;
#   max-width: 240px;
#   white-space: normal;
#   box-shadow: 0 2px 6px rgba(0,0,0,0.3);
# }
# .lx-highlight:hover .lx-tooltip { visibility: visible; opacity:1; }
# .lx-animated-wrapper { max-width: 100%; font-family: Arial, sans-serif; }
# .lx-controls {
#   background: #fafafa; border: 1px solid #90caf9; border-radius: 8px;
#   padding: 12px; margin-bottom: 16px;
# }
# .lx-button-row {
#   display: flex; justify-content: center; gap: 8px; margin-bottom: 12px;
# }
# .lx-control-btn {
#   background: #4285f4; color: white; border: none; border-radius: 4px;
#   padding: 8px 16px; cursor: pointer; font-size: 13px; font-weight: 500;
#   transition: background-color 0.2s;
# }
# .lx-control-btn:hover { background: #3367d6; }
# .lx-progress-container {
#   margin-bottom: 8px;
# }
# .lx-progress-slider {
#   width: 100%; margin: 0; appearance: none; height: 6px;
#   background: #ddd; border-radius: 3px; outline: none;
# }
# .lx-progress-slider::-webkit-slider-thumb {
#   appearance: none; width: 18px; height: 18px; background: #4285f4;
#   border-radius: 50%; cursor: pointer;
# }
# .lx-progress-slider::-moz-range-thumb {
#   width: 18px; height: 18px; background: #4285f4; border-radius: 50%;
#   cursor: pointer; border: none;
# }
# .lx-status-text {
#   text-align: center; font-size: 12px; color: #666; margin-top: 4px;
# }
# .lx-text-window {
#   font-family: monospace; white-space: pre-wrap; border: 1px solid #90caf9;
#   padding: 12px; max-height: 260px; overflow-y: auto; margin-bottom: 12px;
#   line-height: 1.6;
# }
# .lx-attributes-panel {
#   background: #fafafa; border: 1px solid #90caf9; border-radius: 6px;
#   padding: 8px 10px; margin-top: 8px; font-size: 13px;
# }
# .lx-current-highlight {
#   border-bottom: 4px solid #ff4444;
#   font-weight: bold;
#   animation: lx-pulse 1s ease-in-out;
# }
# @keyframes lx-pulse {
#   0% { text-decoration-color: #ff4444; }
#   50% { text-decoration-color: #ff0000; }
#   100% { text-decoration-color: #ff4444; }
# }
# .lx-legend {
#   font-size: 12px; margin-bottom: 8px;
#   padding-bottom: 8px; border-bottom: 1px solid #e0e0e0;
# }
# .lx-label {
#   display: inline-block;
#   padding: 2px 4px;
#   border-radius: 3px;
#   margin-right: 4px;
#   color: #000;
# }
# .lx-attr-key {
#   font-weight: 600;
#   color: #1565c0;
#   letter-spacing: 0.3px;
# }
# .lx-attr-value {
#   font-weight: 400;
#   opacity: 0.85;
#   letter-spacing: 0.2px;
# }
#
# /* Add optimizations with larger fonts and better readability for GIFs */
# .lx-gif-optimized .lx-text-window { font-size: 16px; line-height: 1.8; }
# .lx-gif-optimized .lx-attributes-panel { font-size: 15px; }
# .lx-gif-optimized .lx-current-highlight { text-decoration-thickness: 4px; }
# </style>
#     <div class="lx-animated-wrapper lx-gif-optimized">
#       <div class="lx-attributes-panel">
#         <div class="lx-legend">Highlights Legend: <span class="lx-label" style="background-color:#D2E3FC;">audience_impact</span> <span class="lx-label" style="background-color:#C8E6C9;">opinion_statement</span></div>
#         <div id="attributesContainer"></div>
#       </div>
#       <div class="lx-text-window" id="textWindow">
#         **Page 1**
# &quot;&quot;&quot;
# Dan Baldwin
# Group 4
# Auteur Review - Interstellar
# I believe Christopher Nolan: the director behind the 2014 sci-ﬁ/adventure cinematic ‘Interstellar,’
# to be <span class="lx-highlight lx-current-highlight" data-idx="0" style="background-color:#C8E6C9;">a very intellectual and imaginative inventive talent</span>.
# His style in his previous ﬁlms sets characters in epic unique locations, with gargantuan issues to
# face, and <span class="lx-highlight" data-idx="1" style="background-color:#C8E6C9;">artistically impresses the audience</span> with how the characters solve their problems. For
# example, in Nolan’s 2010 ﬁlm ‘Inception,’ he tackles the idea of dreams, and sets his characters
# diving through dreams within dreams within even more dreams to complete their goals. Because
# this idea is so farfetched, and dreams are a subject in which science has made little factual
# discovery in, Nolan is free to use his creativity to present ideas such as landscapes folding in on
# themselves and corridors spinning, without seeming unrealistic.
# <span class="lx-highlight" data-idx="2" style="background-color:#C8E6C9;">This brain-racking epic theme is once again evident in ‘Interstellar,’</span> as Nolan sets his characters
# during a second American dust bowl on future Earth. The world is short of food, and will soon be
# uninhabitable. So, ex-NASA pilot ‘Cooper’ (Matthew McConaughey) is summoned back to space
# travel in a bid to ﬁnd a new planet for the species to inhabit. Luckily for Cooper and his team, a
# black hole orbiting Saturn can transport them further into space to land on these potential
# planets.
# Throughout the ﬂick, the crew explore multiple worlds - again feeding Nolan’s mind more
# opportunities to create <span class="lx-highlight" data-idx="3" style="background-color:#C8E6C9;">crazy scenarios</span>. For example, one planet that Cooper and his friends,
# ‘Brand,’ (Anne Hathaway) and ‘Romilly,’ (David Gyasi) visit initially seems like an inﬁnite sea of two
# feet deep water. <span class="lx-highlight" data-idx="4" style="background-color:#C8E6C9;">Not threatening at all right?</span> Well think again, because the crew suddenly ﬁnd out
# that <span class="lx-highlight" data-idx="5" style="background-color:#C8E6C9;">a giant 100ft tidal wave is about to hit them</span>, and they have <span class="lx-highlight" data-idx="6" style="background-color:#D2E3FC;">minutes to ﬂy away</span>. Nolan further
# increases the stakes in this scene as it is explained that every hour spent on this planet counts for
# seven years on earth, meaning the planet will be destroyed before they return if their ship sinks.
# At the climax of the ﬁlm, the crew end up sending themselves through a black hole into a
# tesseract (a 3D representation of a larger dimension) to ﬁnd the ‘secret to harnessing gravity’
# which will let the human race bend space-time in order to survive oﬀ earth. I know. Mental.
# The imagination that Nolan possesses and implicates into ‘Interstellar’ is <span class="lx-highlight" data-idx="7" style="background-color:#C8E6C9;">farfetched and
# wonderful</span>, <span class="lx-highlight" data-idx="8" style="background-color:#D2E3FC;">not only impressing his audience with the appealing visuals he creates, but induces
# them to think and discuss what is going on due its scientiﬁc depth</span>. Personally, as someone who is
# bamboozled by the idea of how big the universe is, <span class="lx-highlight" data-idx="9" style="background-color:#D2E3FC;">I ﬁnd it unendingly entertaining to repeatedly
# watch this ﬁlm and understanding it more each time</span>, and can only hope the technology portrayed
# will one day come true.
# Overall, ‘Interstellar’ is <span class="lx-highlight" data-idx="10" style="background-color:#C8E6C9;">a clear example of Nolan’s auteur talent</span>, as he once again ﬁgments yet
# another cluster of conditions for us to marvel at. With a <span class="lx-highlight" data-idx="11" style="background-color:#C8E6C9;">fantastic score</span> from world famous
# composer Hanz Zimmer, his epic, orchestral theme <span class="lx-highlight" data-idx="12" style="background-color:#D2E3FC;">sets the audience in the palm of his hands as
# we stress over how we are all going to be saved once again</span>.
# &quot;&quot;&quot;
#
#
#       </div>
#       <div class="lx-controls">
#         <div class="lx-button-row">
#           <button class="lx-control-btn" onclick="playPause()">▶️ Play</button>
#           <button class="lx-control-btn" onclick="prevExtraction()">⏮ Previous</button>
#           <button class="lx-control-btn" onclick="ne

# %% [markdown]
# ---
# ##### <a id='toc1_5_7_1_2_'></a>[**>>> Bonus Exercise 3 (Take home):**](#toc0_)
#
# `NOTE: This exercise is now considered a bonus one, not counted for the main grade, only as extra points.`
#
# Repeat the steps for information extraction using a different movie reviews.
# 1. Search for movie reviews online and save them in a PDF, we suggest **at least 1 page worth of reviews** like in the example.
# 2. Load the PDF and pass them to langextract to extract information from it.
# 3. Display html with the grounded extracted attributes.
# 4. Discuss about the quality of the extracted information with langextract, how could it be improved based on the options the documentation gives that we didn't try?
#
# **`Github repository for reference:`** [langextract](https://github.com/google/langextract)

# %%
# Answer here
import pymupdf

pdf_path = "./User reviews.pdf"
formatted_text = ""
try:
    doc = pymupdf.open(pdf_path)
    
    for i, page in enumerate(doc):
        text = page.get_text("text")

        formatted_text += f'**Page {i + 1}**\n'
        formatted_text += f'"""\n{text.strip()}\n"""\n\n'
    doc.close()
    print(f"✓ Extracted text from '{pdf_path}'")
except Exception as e:
    print(f"Could not read PDF: {e}")
    formatted_text = "Error: Could not process PDF file."
# Out:
# ✓ Extracted text from './User reviews.pdf'

# %%
print(formatted_text)
# Out:
# **Page 1**
# """
# 1,657 reviews
# Hide spoilers
# Ratings
# Sort by
# gary-szendzielarz-142-951616
# Jun 23, 2025
# Permalink
# Review
# Featured
# Show all
# Featured
# 8/10
# Been an F1 fan since the mid-80s
# ...and I went into this expecting a Hollywood movie and thrilling entertainment...it
# delivered.
# Look, even die-hard F1 fans have to admit that not every waking moment of a race is
# fun. This film took elements from race history and used it over the space of nine
# races. Whether it was Grosjean's fireball, or the moment Senna grabbed the fire
# extinguisher from the marshal, they took and they used. Yes there were some over the
# top elements, but what would you prefer? Track limit arguments?
# Helpful
# 451
# 86
# •
# 9/10
# F1: The Movie - A Review That Overshot the Pit Stop (But in Style)
# Back
# F1電影
# User reviews
# Sign in
# Use app
# 2025/11/24 晚上10:44
# F1電影 (2025) - User reviews - IMDb
# https://www.imdb.com/title/tt16311594/reviews/
# 1/18
# """
#
# **Page 2**
# """
# chetanpr2003
# Jul 1, 2025
# Permalink
# colinsmith-63124
# Jun 26, 2025
# Permalink
# Firstly, the music. Oh boy!
# I came expecting engine roars... and instead got Hans Zimmer blasting emotions at
# 300 km/h. I wasn't prepared for this concert. I came to the theatre for Formula 1, not
# to feel my feelings in Dolby Atmos. The guitars and drums were doing more laps than
# the cars.
# Cinematography? A thing to Marvel at!
# No, no - NOT that Marvel. This isn't a multiverse; this is motorsport. But I'll give it to
# Kosinski - the man knows how to shoot speed. The close-ups, the helmet cams, the pit
# lane drama - it's all smoother than Lewis on a soft compound.
# Kosinski pulls it off again As expected, the Top Gun: Maverick director brings his
# Helpful
# 574
# 117
# •
# 7/10
# Great action, silly story
# It's sort of fun,Brad pitt is his usual charismatic self, Damon iris is solid in support,
# kerry condon is always great and a very underated actress, but to.be honest if you are
# a fan of actual formula one the story is beyond ridiculous, not one part of it makes any
# sense, its all style and not much substance, the dialogue is very cheesy, nothing is in
# anyway surprising as a blind man could see what was going to happen All in all its a
# well shot film, the racing sequences are great, but again if you've ever watched actual
# formula 1, they are beyond ridiculous, the real team heads that are used for cameos
# Helpful
# 388
# 102
# •
# 8/10
# Decent Story, Great Cinematography
# 2025/11/24 晚上10:44
# F1電影 (2025) - User reviews - IMDb
# https://www.imdb.com/title/tt16311594/reviews/
# 2/18
# """
#
# **Page 3**
# """
# Hazadoors
# Jun 24, 2025
# Permalink
# daanceelen
# Jun 29, 2025
# Permalink
# Just got out of the theater. It was a full theater so I got my tickets weeks in advance.
# I've never watched anything F1 related in my life. I give it a 7.5/10. The IMAX scenes
# were fantastic. No shortage of those. The story was a classic underdog story. Still
# pretty good in my opinion. There was some pretty good comedy mixed in. The amount
# of advertising from companies was INSANE. There really was a lot.
# The music was fantastic. I wish we heard more, but the main songs were barely in the
# movie. Just bits of it mainly the start of the songs. I was most hyped to hear "Messy"
# and "Just Keep Watching" but it was only like 15 seconds of each song played back to
# back. I was really looking forward to hearing the full song in theater but oh well
# Worth a one time watch.
# Helpful
# 261
# 90
# •
# 8/10
# Top gun for race cars
# Reviews harping on about the story miss the point. Embrace the corn and enjoy
# yourself.
# The action is good, although unbelievable it's clear the team cared about F1 and did
# their best to make it exciting to watch. I personally love how corny the whole thing is,
# it helps you turn off and enjoy the ride. Brad Pitt plays his classic cool guy persona,
# the supporting crew is entertaining the nods to the real F1 drivers and team directors
# are nice but not overplayed.
# Helpful
# 164
# 53
# •
# 7/10
# from a lifetime f1 fan
# 2025/11/24 晚上10:44
# F1電影 (2025) - User reviews - IMDb
# https://www.imdb.com/title/tt16311594/reviews/
# 3/18
# """
#
# **Page 4**
# """
# stan710699366
# Jun 28, 2025
# Permalink
# andrewchristianjr
# Jun 25, 2025
# Permalink
# I'll keep if brief
# 9/10 visual. Very top gun.
# 7.5/10 racing accuracy. Overall good except the fact that sonny didn't see one black
# flag for any of the things he did, and, curbs don't launch f1 cars like that.
# 4/10 story. Same old individual heroism hollywood story that has been told 200 times.
# 6/10 characters. Only sonny's character motivation is established. Other characters
# have varying degrees of "why do they want to be here" syndrome, some worse than
# others. But the main characters have visible character development throughout the
# film nevertheless so overall not shockingly bad characters.
# Helpful
# 212
# 60
# •
# 9/10
# A FULL-THROTTLE CINEMATIC EXPERIENCE.
# As a longtime F1 fan, F1: The Movie completely blew me away. From the very first
# scene, you can tell this was made to be watched in a theater - it's loud, fast, emotional,
# and immersive in all the right ways.
# The cinematography is stunning - easily the best I've seen in a racing film since Rush,
# maybe even since Top Gun: Maverick. The sound design and musical score elevate
# every race scene to something visceral and epic. I genuinely got chills more than once.
# Sure, there are a few moments that feel a bit cliché or unrealistic, especially if you're
# deeply familiar with the world of Formula 1. But the film's technical brilliance and
# emotional punch more than make up for that.
# In short: this movie is a love letter to F1 and to cinema itself. Whether you're a
# hardcore motorsport fan or just looking for an intense, high-octane story - you'll be in
# Helpful
# 230
# 89
# •
# 6/10
# 2025/11/24 晚上10:44
# F1電影 (2025) - User reviews - IMDb
# https://www.imdb.com/title/tt16311594/reviews/
# 4/18
# """
#
# **Page 5**
# """
# lucca-07088
# Jun 28, 2025
# Permalink
# glennstandish
# Jun 24, 2025
# Permalink
# Great cinematography, horrible story
# Visually en auditory the race sequences are absolutely stunning, but the story, the plot
# and dialogue in general are just horrible and generic.
# It makes F1 look like an absolute joke, like just anyone can drive these cars. This
# supposedly 60 y/o guy can still beat these young athletes who have trained their
# whole lives for this sport. It just deminishes their accomplishments and hard work.
# Also, he can just break every rule when it comes to racing and get away with it. It
# makes F1 look like a clown show. Weird that f1 approved this.
# The only thing I liked were the racing and some funny F1 references. Although, the
# racing strategies were just utterly bizarre, it was still a decent watch.
# Disgraceful to the sport, wouldn't recommend if you're not into motorsport.
# Helpful
# 227
# 71
# •
# 8/10
# Incredible action and cinematography
# Okay let's start by saying I am not a fan of Formula 1. So I don't know anything about
# the rules etc. Yes there might be a lot rule-breqking in this movie but it is after all just
# that...a movie. It's purely for entertainment and not for realism. And boy is it
# entertaining. It's wonderful to see Brad Pitt back in the charismatic laid-back character
# role that he was born to play. The story is simple (class underdog story) but it js
# incredibly thrilling and fun.
# The action scenes are phenomenal as is the sound. I am a huge fan of Director Joseph
# Kosinski and his cinematographer partner Claudio Miranda. I met them both a few
# Helpful
# 129
# 59
# •
# 6/10
# Great cinematography frivolous story
# 2025/11/24 晚上10:44
# F1電影 (2025) - User reviews - IMDb
# https://www.imdb.com/title/tt16311594/reviews/
# 5/18
# """
#
# **Page 6**
# """
# drummerlaci
# Jun 26, 2025
# Permalink
# UniqueParticle
# Jun 24, 2025
# Permalink
# The way the movie was shot is magnificent. Brad Pitt is magnificent too. The problem
# is racing. The whole movie is like superb until they start racing. The endurance race at
# the beginning, the way Sonny is convinced to join to the APX team, the first test and
# the rivalry between the two drivers are all very well made. Unfortunately when they
# actively start to race the movie falls apart. Sonny constantly makes moves that you
# couldn't have ever seen ever from any driver before. Not to mention the car upgrades.
# One single update makes the worst car on the grid capable of winning. TBH if you
# Helpful
# 181
# 57
# •
# 10/10
# Masterful IMAX experience!
# I absolutely loved this so glad I got to see an early screening with a packed audience
# only annoying thing was thing was the guy to the left me was a little distracting bro
# went through a slushy and a large water; I guess a fast paced movie makes someone
# thirsty. The film is phenomenal though I'm shocked of the haters already there's soul
# involved.
# It's basically car version of Top Gun which is magnificent it's so fast paced in the bulk
# of it. I don't know much about Formula one, I love Brad Pitt, the director is brilliant and
# about cinematography! I also love that Kim Boden from Killing Eve was in this he's
# Helpful
# 276
# 147
# •
# 6/10
# Great Race Scenes / Weak Storyline
# The cinematographers should have received 30 million in salary for their incredible
# work. Unfortunately, the storyline is older than a Model T, but nothing classic about it.
# Pitt does a nice job playing his role, but the script is so mundane all I can say is he did
# a nice job with what he had to work with. Same for Javiar. Everyone else is forgetable.
# Pitt must be a screwd businessman to have scored 30 million to make this movie. Fun
# to watch, but lots of dead spots inbetween race scenes. If you like Formula 1 racing,
# see it. If you don't, nothing here to see. After you've seen this, you will leave the theatre
# Helpful
# 51
# 14
# •
# 2025/11/24 晚上10:44
# F1電影 (2025) - User reviews - IMDb
# https://www.imdb.com/title/tt16311594/reviews/
# 6/18
# """
#
# **Page 7**
# """
# icminindy
# Jun 30, 2025
# Permalink
# cherrylovergirl
# Jul 30, 2025
# Permalink
# Shubh0047
# Jul 1, 2025
# Permalink
# 5/10
# Bad Writing with Great Production Work
# As an F1 fan, I watched this movie when it first came out and I had no expectation
# whatsoever. When the movie finished, I had one thing in my mind. The movie doesn't
# make any sense. This movie feels like a 13-year-old boy imagination when he was
# bored in class. F1 is a sport and it has tons of rules in it. But this movie bend every
# single rules and regulations in the sport. It was very hard to watch. It was as if FIA (a
# motorsport association) doesn't exist anymore! The funny thing is the FIA do exist in
# this movie and they're so dumb that makes me wonder, who writes this movie? Don't
# they have consultants or experts during the development? They do. They have an F1
# driver as one of the producers of this movie. A driver! Yet, the writing still turns out to
# be a mess! At one point, even someone that don't watch F1 is going to think, how do
# they allow this in a sport? In terms of writing, this movie is disappointing. This movie
# is not a great representation of the sport.
# Contradict to the writing, the production in this movie are amazing. I do have to admit
# Helpful
# 114
# 20
# •
# 9/10
# An Experience of a Lifetime
# Just the way it was with "Top Gunn : Maverick", Joseph Kosinski has once again
# delivered something that pulls you back to cinemas. This is what I call an experience.
# This movie is what movies are all about. They made promises with this, and fulfilled
# every single one of them. It's got that story, young guy taught by the veteran, but
# everything is done so spectacularly well that, when you leave the theatre, you really
# feel like jumping into a Formula 1 car yourself. Brad Pitt, it had to be you, I'm
# convinced that this guy just doesn't do bad movies. In the movie, it feels like it's Brad
# just being Brad. And it's amazing. I'd pay to watch this again and again.
# Helpful
# 164
# 87
# •
# Awful
# 2025/11/24 晚上10:44
# F1電影 (2025) - User reviews - IMDb
# https://www.imdb.com/title/tt16311594/reviews/
# 7/18
# """
#
# **Page 8**
# """
# hgdckb
# Aug 25, 2025
# Permalink
# npkulakofski
# Jun 30, 2025
# Permalink
# qbmrntdks
# Aug 23, 2025
# Permalink
# What an awful film that I actually was looking forward to.
# The story line is so way out there in the fictional world it's unbelievable... Lewis
# Hamilton should be ashamed to put his name to it 🙄🤦
# I'm having to pan this out as you need 300 words apparently....... it's awful and I mean
# really awful and so far away from reality.
# Helpful
# 63
# 45
# •
# 9/10
# A nearly perfect film
# F1 has you on the edge of your seat 100% of the running time, which is long, but
# nobody cares. Live action incredibly filmed, great story, Def not cookie- cutter. Plus, I
# loved the program music. This is a go- see film!
# A pity there had to be a romance thrown into the mix, but it was tastefully and
# believably done.
# Additionally, moviegoers got a tremendous amount of behind- the- scenes techie and
# deal- making insider information.
# The most stunning part of F100was the camera work. I don't know how this was
# filmed, but it was incredibly realistic. And Brad Pitt shows that he still has it!
# You will thoroughly enjoy this film.
# Helpful
# 127
# 115
# •
# 6/10
# Overrated
# Spoiler
# Helpful
# 54
# 12
# •
# 2025/11/24 晚上10:44
# F1電影 (2025) - User reviews - IMDb
# https://www.imdb.com/title/tt16311594/reviews/
# 8/18
# """
#
# **Page 9**
# """
# ardenderi
# Jun 26, 2025
# Permalink
# 9/10
# Audio-visual experience mixed with good vibes and sincerity
# Obviously being a movie, it streamlines heaps of F1, but uses enough reality to feel
# convincing. The movie is done with sincerity and care, with lots of American and
# Hollywood glamour on top of it.
# The audio-visual aspect is the best part of the movie, but suffers from shot repetition
# and mix-match editing on fast paced stuff. Also some of the races should have
# utilized "space" and length bit more. F1 race weekend is long after all and the movie
# fast forwards to race day on each of them. This hurts slightly the credibility of the
# movie, but also seems missed opportunity story wise.
# The story is Hollywood magic, but crafted from reality, even real events and strategies
# from F1 history, not just technicalities that could happen. Story is solid blockbuster
# with bit of Hollywood magic and mandatory B or C subplot love story.
# Helpful
# 72
# 63
# •
# 6/10
# F1 captures the races in a unique way, but isn't fast enough to deliver
# a truly unique story.
# F1: The Movie is a new sports film directed, co-written, and produced by Joseph
# Kosinski, known for Tron: Legacy and Top Gun: Maverick.
# Promising Formula 1 driver Sonny Hayes (Brad Pitt) ended his career in the 1990s
# after a serious accident. Still, he continued to race as a hired driver.
# When team boss Ruben Cervantes (Javier Bardem) is in search of a new driver for his
# Formula 1 team, he turns to Sonny for help. Sonny agrees, but insists on racing in his
# own way.
# He is paired with Joshua Pearce (Damson Idris), the young talent on the team, and
# their styles and experiences clash. Still, the two must find a way to work together to
# give their team a shot at victory.
# Helpful
# 139
# 53
# •
# 2025/11/24 晚上10:44
# F1電影 (2025) - User reviews - IMDb
# https://www.imdb.com/title/tt16311594/reviews/
# 9/18
# """
#
# **Page 10**
# """
# movieman6-413-929510
# Jun 26, 2025
# Permalink
# RajaA-75
# Jun 24, 2025
# Permalink
# raianjose
# Jun 30, 2025
# Permalink
# 10/10
# Fast Cars, Big Twist, Epic Sounds
# If you're a hardcore F1 fan, the movie might feel a bit underwhelming. But if you're
# someone with a casual interest in cars and racing, you'll probably enjoy it. And if you
# know nothing about the sport at all, you're in for the best experience with stunning
# cinematography, a twist-filled story, and one of the best soundtracks produced for a
# film. The movie delivers some solid twists, with Brad Pitt stepping into the role of a
# leader and father figure for a struggling team. Watching it in IMAX is easily the best
# way to experience it's visually stunning and fully immersive. On the entertainment
# scale, it scores top marks. The characters are well-balanced, from seasoned veterans
# with firm convictions to hungry rookies fueled by adrenaline and eager to prove
# Helpful
# 99
# 95
# •
# 6/10
# Decent movie, nothing special though
# Coming from the director of Tron and Top Gun, I honestly was expecting an exciting or
# epic experience, but this was not even close.
# First off, i have to say I have a heavy technical background when it comes to
# motorsport and F1 particularly, but i'll ignore that being as the movie was pretty
# accurate when it came to lingo and shots.
# Other than that, the story is very VERY forgettable, the classic of a team in distress, a
# rookie that is way too much in his head and a hero that is "too old for that sht". The
# best part of the movie was the 24hs of daytona at the start, it honestly was the only
# part that gave me a sense of speed, action, stakes and some engine noise, but the rest
# was pretty sterile.
# I went to see it on IMAX, and I'll say, that was the only part that popped. Other than
# Helpful
# 63
# 23
# •
# 9/10
# 2025/11/24 晚上10:44
# F1電影 (2025) - User reviews - IMDb
# https://www.imdb.com/title/tt16311594/reviews/
# 10/18
# """
#
# **Page 11**
# """
# mcchengbh
# Jun 29, 2025
# Permalink
# leomessiculer
# Jul 25, 2025
# Permalink
# Enjoyed it, even not being a F1 fan at all
# Spoiler
# Helpful
# 43
# 39
# •
# 6/10
# Disappointed
# I was expecting a lot from this movie with the way people were talking about it. I left
# the theater disappointed.
# First off, amazing cinematography, color grading, and infrastructure. Joe Kosinski
# really knows how to shoot action. You can tell they spent a lot of money on this movie.
# Some good humor here and there, too.
# But it all quickly goes downhill. Absolutely no realism in terms of racing; one team
# getting 12-odd DNFs in 9 races, 'Plan C' should have received multiple black-and-white
# flags, physics just doesn't work, and penalties for rash driving don't exist. This seemed
# like more of a guide on how to crash your car than a movie worthy of its title.
# Worst of all is the story itself. By Hollywood standards, it's very, very average, maybe
# slightly above. The shallow attempt at actually creating a story... just no. This movie
# Helpful
# 54
# 18
# •
# 5/10
# Do we live in the Age of Mediocracy?
# 2025/11/24 晚上10:44
# F1電影 (2025) - User reviews - IMDb
# https://www.imdb.com/title/tt16311594/reviews/
# 11/18
# """
#
# **Page 12**
# """
# filipesonofjose
# Jun 29, 2025
# Permalink
# matthewdimarino
# Aug 30, 2025
# Permalink
# How can it be either "OMG, the best!!" Or "it was the worst thing ever?!" Being this
# radica in opinions is having a profound effect in the way we analyse art, in this case,
# movies. This movie is not the best movie about F1. It's not the best movie about cars.
# It's a movie that lacks depth, character fibre, plot and, overall, newness. We don't
# expect to be irreverent but it's very mundane. It won't be remembered. It doesn't give
# you the passion for F1. You won't see this movie more than once. If it came out in
# 1987 it would have been great but we're in a whole other level. Let's move on and like
# educate ourselves to appreciate something better. Taste can be learned.
# From the moment the movie started you knew how it's going to end so you think, "ok,
# maybe there's some cool stuff". Nope. It's as lame as it can be.
# I just find it mesmerising how people give 10/10 to this movie. Have we lost our
# minds? 10/10??
# Helpful
# 107
# 25
# •
# F1 racing movie with lazy writing, what could go wrong!
# I usually enjoy Brad Pitt movies but he was definitely flat in this one and didn't bring
# much to his character. The whole story was very lazy and nowhere close to racing
# movies such as Rush and Ford vs Ferrari. It had the bones to be good but everything
# was flat with silly storylines like Sonny basically driving illegally and the thin story of
# combat can beat speed on the race track, not going to happen but it helped the
# storyline so let's just bend reality and let Pitt smirk his way to a win. Too bad but it has
# Helpful
# 11
# 6
# •
# 25 more
# See all
# More from this title
# More to explore
# 2025/11/24 晚上10:44
# F1電影 (2025) - User reviews - IMDb
# https://www.imdb.com/title/tt16311594/reviews/
# 12/18
# """
#
# **Page 13**
# """
# Hollywood Power Couples
# See the gallery
# Editorial lists
# Related lists created by IMDb editors
# Theatrical Releases You Can Stream or Rent at Home
# updated 5 days ago
# 39 titles
# Brad Pitt's Biggest Box Office Hits
# updated 3 months ago
# 10 titles
# The Big List of Summer Movies 2025
# updated 4 months ago
# 39 titles
# Photos
# 2025/11/24 晚上10:44
# F1電影 (2025) - User reviews - IMDb
# https://www.imdb.com/title/tt16311594/reviews/
# 13/18
# """
#
# **Page 14**
# """
# Fantastical Physical Transformations
# See the full gallery
# User lists
# Related lists from IMDb users
# Create a list
# Movies
# created 9 months ago
# 42 titles
# 2025 seen
# created 10 months ago
# 41 titles
# 2025 Films Ranked
# created 10 months ago
# 30 titles
# .
# created 4 weeks ago
# 28 titles
# Photos
# 2025/11/24 晚上10:44
# F1電影 (2025) - User reviews - IMDb
# https://www.imdb.com/title/tt16311594/reviews/
# 14/18
# """
#
# **Page 15**
# """
# Automotive
# created 2 years ago
# 28 titles
# 2025
# created 3 months ago
# 26 titles
# User polls
# Related polls from IMDb users
# Face-Off: 'Top Gun: Maverick' vs. 'F1: The Movie'
# Most Anticipated Upcoming Movies in 2025
# Most Anticipated Summer 2025 Theatrical Movie Release
# IMDb Staff Picks to Watch in June 2025
# Best Brad Pitt Action Movie
# Best Joseph Kosinski Movie
# 2025/11/24 晚上10:44
# F1電影 (2025) - User reviews - IMDb
# https://www.imdb.com/title/tt16311594/reviews/
# 15/18
# """
#
# **Page 16**
# """
# 'Wicked: For Good' Stars Through the Years
# See the full gallery
# Recently viewed
# Clear all
# Photos
# 2025/11/24 晚上10:44
# F1電影 (2025) - User reviews - IMDb
# https://www.imdb.com/title/tt16311594/reviews/
# 16/18
# """
#
# **Page 17**
# """
# Help
# Site Index
# IMDbPro
# Box Office Mojo
# License IMDb Data
# Press Room
# Advertising
# Jobs
# Conditions of Use
# Privacy Policy
# Your Ads Privacy Choices
# F1電影
# Get the IMDb App
# Sign in for more access
# 2025/11/24 晚上10:44
# F1電影 (2025) - User reviews - IMDb
# https://www.imdb.com/title/tt16311594/reviews/
# 17/18
# """
#
# **Page 18**
# """
# © 1990-2025 by IMDb.com, Inc.
# 2025/11/24 晚上10:44
# F1電影 (2025) - User reviews - IMDb
# https://www.imdb.com/title/tt16311594/reviews/
# 18/18
# """

# %%
import langextract as lx
import textwrap

prompt = textwrap.dedent("""\
    Extract specific opinions and their impact on the audience from this movie review.
    Important: Use exact text verbatim from the input for extraction_text. Do not paraphrase.
    Extract entities in order of appearance with no overlapping text spans.

    Use the 'opinion_statement' class for direct judgments about film elements (like plot, score, or acting).
    - 'subject' should be the element being reviewed.
    - 'sentiment' should be Positive, Negative, or Neutral.
    - 'key_phrase' should be the core descriptive words.

    Use the 'audience_impact' class for phrases describing the effect on the viewer.
    - 'emotion_evoked' should be the feeling or reaction (e.g., stress, joy, confusion).
    - 'causal_element' is what part of the film caused the reaction.
    - 'target_audience' is who was affected (e.g., 'the audience', 'the reviewer').
    """)

examples = [
    
    lx.data.ExampleData(
        text="As a longtime F1 dan, F1: The Movie completely blew me away. I'd pay to watch this again and again.",
        extractions=[
            lx.data.Extraction(
                extraction_class="opinion_statement",
                extraction_text="",
                attributes={
                    "subject": "The movie",
                    "sentiment": "Positive",
                    "key_phrase": "blew me away"
                }
            ),
            lx.data.Extraction(
                extraction_class="audience_impact",
                extraction_text="watch this again and again",
                attributes={
                    "emotion_evoked": ["engaged", "satisfied"],
                    "causal_element": "watch this again",
                    "target_audience": "the reviewer"
                }
            ),
        ]
    ),
    # Example 2: Shows a negative opinion and a separate audience impact caused by the soundtrack
    lx.data.ExampleData(
        text="It's a movie that lacks depth, character fibre, plot and, overall, newness.",
        extractions=[
            lx.data.Extraction(
                extraction_class="opinion_statement",
                extraction_text="lacks depth, character fibre, plot and, overall, newness. the plot and dialogue in general are just horrible and generic",
                attributes={
                    "subject": "It's a movie",
                    "sentiment": "Negative",
                    "key_phrase": "lack newness and plot"
                }
            ),
            lx.data.Extraction(
                extraction_class="audience_impact",
                extraction_text="horrible and generic",
                attributes={
                    "emotion_evoked": ["dissatisfied", "dislike"],
                    "causal_element": "the plot and dialogue",
                    "target_audience": "the audience"
                }
            )
        ]
    )
]

# %%
import os
import langextract as lx

def grounded_info_extraction(input_documents, prompt, examples, file_name, model_id ="gemini-2.5-flash-lite", extraction_passes = 1, max_workers = 5, max_char_buffer = 2000):
    result = lx.extract(
        text_or_documents=input_documents,
        prompt_description=prompt,
        examples=examples,
        model_id=model_id,
        extraction_passes=extraction_passes,   
        max_workers=max_workers,         
        max_char_buffer=max_char_buffer   
    )

    print(f"Extracted {len(result.extractions)} entities:\n")
    for extraction in result.extractions:
        print(f"• {extraction.extraction_class}: '{extraction.extraction_text}'")
        if extraction.attributes:
            for key, value in extraction.attributes.items():
                print(f"  - {key}: {value}")
    
    output_dir = "./results/info_extractions"
    os.makedirs(output_dir, exist_ok=True)
    lx.io.save_annotated_documents([result], output_name=f"{file_name}.jsonl", output_dir=output_dir)

    html_content = lx.visualize(f"{output_dir}/{file_name}.jsonl")
    with open(f"{output_dir}/{file_name}_vis.html", "w", encoding='utf-8') as f:
        if hasattr(html_content, 'data'):
            f.write(html_content.data)
        else:
            f.write(html_content)

    print(f"✓ Visualization saved to {output_dir}/{file_name}_vis.html")
    
    return html_content

# %%
html_content_1 = grounded_info_extraction(formatted_text, prompt, examples, "review_extraction")
# Out:
# WARNING:absl:Prompt alignment: FAILED to align: [example#0] class='opinion_statement' status=None text=''
# WARNING:absl:Prompt alignment: non-exact match: [example#1] class='opinion_statement' status=AlignmentStatus.MATCH_LESSER text='lacks depth, character fibre, plot and, overall, newness. the plot and dialogue in general are just horrible and generic' char_span=(18, 75)
# WARNING:absl:Prompt alignment: FAILED to align: [example#1] class='audience_impact' status=None text='horrible and generic'
# WARNING:google_genai._api_client:Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# Extracted 145 entities:
#
# • opinion_statement: 'it delivered'
#   - subject: this
#   - sentiment: Positive
#   - key_phrase: delivered
# • opinion_statement: 'Yes there were some over the top elements'
#   - subject: elements
#   - sentiment: Negative
#   - key_phrase: over the top
# • opinion_statement: 'Hans Zimmer blasting emotions at 300 km/h'
#   - subject: the music
#   - sentiment: Negative
#   - key_phrase: blasting emotions
# • audience_impact: 'I wasn't prepared for this concert. I came to the theatre for Formula 1, not to feel my feelings in Dolby Atmos.'
#   - emotion_evoked: ['unprepared', 'disappointed']
#   - causal_element: Hans Zimmer blasting emotions
#   - target_audience: the reviewer
# • opinion_statement: 'Cinematography? A thing to Marvel at!'
#   - subject: Cinematography
#   - sentiment: Positive
#   - key_phrase: A thing to Marvel at
# • opinion_statement: 'the man knows how to shoot speed.'
#   - subject: Kosinski
#   - sentiment: Positive
#   - key_phrase: knows how to shoot speed
# • opinion_statement: 'it's all smoother than Lewis on a soft compound.'
#   - subject: The close-ups, the helmet cams, the pit lane drama
#   - sentiment: Positive
#   - key_phrase: smoother than Lewis on a soft compound
# • opinion_statement: 'Kosinski pulls it off again'
#   - subject: Kosinski
#   - sentiment: Positive
#   - key_phrase: pulls it off again
# • opinion_statement: 'Great action, silly story'
#   - subject: It
#   - sentiment: Negative
#   - key_phrase: silly story
# • opinion_statement: 'It's sort of fun'
#   - subject: It
#   - sentiment: Positive
#   - key_phrase: sort of fun
# • opinion_statement: 'Brad pitt is his usual charismatic self'
#   - subject: Brad pitt
#   - sentiment: Positive
#   - key_phrase: usual charismatic self
# • opinion_statement: 'Damon iris is solid in support'
#   - subject: Damon iris
#   - sentiment: Positive
#   - key_phrase: solid in support
# • opinion_statement: 'kerry condon is always great'
#   - subject: kerry condon
#   - sentiment: Positive
#   - key_phrase: always great
# • opinion_statement: 'a very underated actress'
#   - subject: kerry condon
#   - sentiment: Positive
#   - key_phrase: very underated
# • opinion_statement: 'IMAX scenes were fantastic'
#   - subject: The IMAX scenes
#   - sentiment: Positive
#   - key_phrase: fantastic
# • opinion_statement: 'The story was a classic underdog story. Still pretty good in my opinion.'
#   - subject: The story
#   - sentiment: Positive
#   - key_phrase: classic underdog story. Still pretty good
# • opinion_statement: 'There was some pretty good comedy mixed in.'
#   - subject: comedy
#   - sentiment: Positive
#   - key_phrase: pretty good
# • opinion_statement: 'The amount of advertising from companies was INSANE.'
#   - subject: The amount of advertising from companies
#   - sentiment: Negative
#   - key_phrase: INSANE
# • opinion_statement: 'The music was fantastic.'
#   - subject: The music
#   - sentiment: Positive
#   - key_phrase: fantastic
# • opinion_statement: 'Worth a one time watch.'
#   - subject: The movie
#   - sentiment: Neutral
#   - key_phrase: Worth a one time watch
# • opinion_statement: 'Reviews harping on about the story miss the point.'
#   - subject: Reviews harping on about the story
#   - sentiment: Negative
#   - key_phrase: miss the point
# • opinion_statement: 'Embrace the corn and enjoy yourself.'
#   - subject: the corn
#   - sentiment: Positive
#   - key_phrase: Embrace and enjoy
# • opinion_statement: 'The action is good, although unbelievable it's clear the team cared about F1 and did their best to make it exciting to watch.'
#   - subject: The action
#   - sentiment: Positive
#   - key_phrase: good, exciting to watch
# • opinion_statement: 'I personally love how corny the whole thing is, it helps you turn off and enjoy the ride.'
#   - subject: the whole thing
#   - sentiment: Positive
#   - key_phrase: love how corny
# • audience_impact: 'helps you turn off and enjoy the ride'
#   - emotion_evoked: ['relaxed', 'entertained']
#   - causal_element: how corny the whole thing is
#   - target_audience: you
# • opinion_statement: 'Brad Pitt plays his classic cool guy persona, the supporting crew is entertaining the nods to the real F1 drivers and team directors are nice but not overplayed.'
#   - subject: Brad Pitt and the supporting crew
#   - sentiment: Positive
#   - key_phrase: classic cool guy persona, entertaining, nice
# • opinion_statement: '9/10 visual. Very top gun.'
#   - subject: visual
#   - sentiment: Positive
#   - key_phrase: Very top gun
# • opinion_statement: '7.5/10 racing accuracy. Overall good except the fact that sonny didn't see one black flag for any of the things he did, and, curbs don't launch f1 cars like that.'
#   - subject: racing accuracy
#   - sentiment: Positive
#   - key_phrase: Overall good
# • opinion_statement: '4/10 story. Same old individual heroism hollywood story that has been told 200 times.'
#   - subject: story
#   - sentiment: Negative
#   - key_phrase: Same old individual heroism hollywood story
# • opinion_statement: '6/10 characters. Only sonny's character motivation is established. Other characters have varying degrees of "why do they want to be here" syndrome, some worse than others. But the main characters have visible character development throughout the film nevertheless so overall not shockingly bad characters.'
#   - subject: characters
#   - sentiment: Positive
#   - key_phrase: not shockingly bad characters
# • opinion_statement: 'A FULL-THROTTLE CINEMATIC EXPERIENCE.'
#   - subject: The movie
#   - sentiment: Positive
#   - key_phrase: FULL-THROTTLE CINEMATIC EXPERIENCE
# • opinion_statement: 'F1: The Movie completely blew me away.'
#   - subject: F1: The Movie
#   - sentiment: Positive
#   - key_phrase: blew me away
# • opinion_statement: 'it's loud, fast, emotional, and immersive in all the right ways.'
#   - subject: The movie
#   - sentiment: Positive
#   - key_phrase: loud, fast, emotional, and immersive
# • opinion_statement: 'The cinematography is stunning - easily the best I've seen in a racing film since Rush, maybe even since Top Gun: Maverick.'
#   - subject: The cinematography
#   - sentiment: Positive
#   - key_phrase: stunning - easily the best I've seen
# • opinion_statement: 'The sound design and musical score elevate every race scene to something visceral and epic.'
#   - subject: The sound design and musical score
#   - sentiment: Positive
#   - key_phrase: visceral and epic
# • opinion_statement: 'Sure, there are a few moments that feel a bit cliché or unrealistic, especially if you're deeply familiar with the world of Formula 1.'
#   - subject: moments
#   - sentiment: Negative
#   - key_phrase: cliché or unrealistic
# • opinion_statement: 'But the film's technical brilliance and emotional punch more than make up for that.'
#   - subject: the film's technical brilliance and emotional punch
#   - sentiment: Positive
#   - key_phrase: more than make up for that
# • opinion_statement: 'in short: this movie is a love letter to F1 and to cinema itself.'
#   - subject: this movie
#   - sentiment: Positive
#   - key_phrase: love letter to F1 and to cinema itself
# • opinion_statement: 'you'll be in'
#   - subject: you
#   - sentiment: Positive
#   - key_phrase: be in
# • opinion_statement: 'The way the movie was shot is magnificent.'
#   - subject: The movie
#   - sentiment: Positive
#   - key_phrase: magnificent
# • opinion_statement: 'Brad Pitt is magnificent too.'
#   - subject: Brad Pitt
#   - sentiment: Positive
#   - key_phrase: magnificent
# • opinion_statement: 'The problem is racing.'
#   - subject: racing
#   - sentiment: Negative
#   - key_phrase: problem
# • opinion_statement: 'The whole movie is like superb until they start racing.'
#   - subject: The whole movie
#   - sentiment: Positive
#   - key_phrase: superb until they start racing
# • opinion_statement: 'The endurance race at the beginning, the way Sonny is convinced to join to the APX team, the first test and the rivalry between the two drivers are all very well made.'
#   - subject: The endurance race, Sonny joining the APX team, the first test, and the rivalry between the two drivers
#   - sentiment: Positive
#   - key_phrase: very well made
# • opinion_statement: 'Unfortunately when they actively start to race the movie falls apart.'
#   - subject: the movie
#   - sentiment: Negative
#   - key_phrase: falls apart
# • opinion_statement: 'Sonny constantly makes moves that you couldn't have ever seen ever from any driver before.'
#   - subject: Sonny's moves
#   - sentiment: Negative
#   - key_phrase: couldn't have ever seen ever from any driver before
# • opinion_statement: 'One single update makes the worst car on the grid capable of winning.'
#   - subject: One single update
#   - sentiment: Negative
#   - key_phrase: makes the worst car on the grid capable of winning
# • opinion_statement: 'Masterful IMAX experience!'
#   - subject: IMAX experience
#   - sentiment: Positive
#   - key_phrase: Masterful
# • opinion_statement: 'I absolutely loved this so glad I got to see an early screening with a packed audience'
#   - subject: this
#   - sentiment: Positive
#   - key_phrase: absolutely loved
# • opinion_statement: 'The film is phenomenal though I'm shocked of the haters already there's soul involved.'
#   - subject: The film
#   - sentiment: Positive
#   - key_phrase: phenomenal
# • opinion_statement: 'It's basically car version of Top Gun which is magnificent it's so fast paced in the bulk of it.'
#   - subject: It
#   - sentiment: Positive
#   - key_phrase: magnificent
# • opinion_statement: 'the director is brilliant and about cinematography!'
#   - subject: the director and cinematography
#   - sentiment: Positive
#   - key_phrase: brilliant
# • opinion_statement: 'The cinematographers should have received 30 million in salary for their incredible work.'
#   - subject: The cinematographers
#   - sentiment: Positive
#   - key_phrase: incredible work
# • opinion_statement: 'Unfortunately the storyline is older than a Model T, but nothing classic about it.'
#   - subject: the storyline
#   - sentiment: Negative
#   - key_phrase: older than a Model T, but nothing classic about it
# • opinion_statement: 'Pitt does a nice job playing his role, but the script is so mundane all I can say is he did a nice job with what he had to work with.'
#   - subject: Pitt's role and the script
#   - sentiment: Neutral
#   - key_phrase: nice job with what he had to work with
# • opinion_statement: 'Same for Javiar.'
#   - subject: Javiar
#   - sentiment: Neutral
#   - key_phrase: Same
# • opinion_statement: 'Everyone else is forgetable.'
#   - subject: Everyone else
#   - sentiment: Negative
#   - key_phrase: forgettable
# • opinion_statement: 'Pitt must be a screwd businessman to have scored 30 million to make this movie.'
#   - subject: Pitt
#   - sentiment: Positive
#   - key_phrase: screwd businessman
# • opinion_statement: 'Fun to watch, but lots of dead spots inbetween race scenes.'
#   - subject: The movie
#   - sentiment: Neutral
#   - key_phrase: Fun to watch, but lots of dead spots
# • opinion_statement: 'If you like Formula 1 racing, see it.'
#   - subject: The movie
#   - sentiment: Positive
#   - key_phrase: see it
# • opinion_statement: 'If you don't, nothing here to see.'
#   - subject: The movie
#   - sentiment: Negative
#   - key_phrase: nothing here to see
# • audience_impact: 'packed audience'
#   - emotion_evoked: ['engaged', 'excited']
#   - causal_element: early screening
#   - target_audience: the audience
# • audience_impact: 'a little distracting'
#   - emotion_evoked: ['annoyed']
#   - causal_element: the guy to the left me
#   - target_audience: the reviewer
# • audience_impact: 'makes someone thirsty'
#   - emotion_evoked: ['thirsty']
#   - causal_element: a fast paced movie
#   - target_audience: someone
# • audience_impact: 'I'm shocked of the haters already'
#   - emotion_evoked: ['shocked']
#   - causal_element: the haters
#   - target_audience: the reviewer
# • audience_impact: 'so fast paced in the bulk of it'
#   - emotion_evoked: ['engaged', 'excited']
#   - causal_element: the bulk of it
#   - target_audience: the audience
# • audience_impact: 'leave the theatre'
#   - emotion_evoked: ['disappointed']
#   - causal_element: weak storyline
#   - target_audience: the audience
# • opinion_statement: 'The movie doesn't make any sense.'
#   - subject: The movie
#   - sentiment: Negative
#   - key_phrase: doesn't make any sense
# • opinion_statement: 'This movie feels like a 13-year-old boy imagination when he was bored in class.'
#   - subject: This movie
#   - sentiment: Negative
#   - key_phrase: like a 13-year-old boy imagination
# • opinion_statement: 'this movie bend every single rules and regulations in the sport.'
#   - subject: this movie
#   - sentiment: Negative
#   - key_phrase: bend every single rules and regulations
# • audience_impact: 'It was very hard to watch.'
#   - emotion_evoked: ['frustration', 'disappointment']
#   - causal_element: movie bend every single rules and regulations
#   - target_audience: the reviewer
# • opinion_statement: 'the writing still turns out to be a mess!'
#   - subject: the writing
#   - sentiment: Negative
#   - key_phrase: turns out to be a mess
# • opinion_statement: 'In terms of writing, this movie is disappointing.'
#   - subject: this movie
#   - sentiment: Negative
#   - key_phrase: disappointing
# • opinion_statement: 'This movie is not a great representation of the sport.'
#   - subject: This movie
#   - sentiment: Negative
#   - key_phrase: not a great representation
# • opinion_statement: 'the production in this movie are amazing.'
#   - subject: the production in this movie
#   - sentiment: Positive
#   - key_phrase: amazing
# • opinion_statement: 'Joseph Kosinski has once again delivered something that pulls you back to cinemas.'
#   - subject: Joseph Kosinski
#   - sentiment: Positive
#   - key_phrase: delivered something that pulls you back to cinemas
# • audience_impact: 'This is what I call an experience.'
#   - emotion_evoked: ['awe', 'excitement']
#   - causal_element: This
#   - target_audience: the reviewer
# • opinion_statement: 'This movie is what movies are all about.'
#   - subject: This movie
#   - sentiment: Positive
#   - key_phrase: what movies are all about
# • opinion_statement: 'They made promises with this, and fulfilled every single one of them.'
#   - subject: They
#   - sentiment: Positive
#   - key_phrase: fulfilled every single one of them
# • opinion_statement: 'everything is done so spectacularly well'
#   - subject: everything
#   - sentiment: Positive
#   - key_phrase: spectacularly well
# • audience_impact: 'when you leave the theatre, you really feel like jumping into a Formula 1 car yourself.'
#   - emotion_evoked: ['inspired', 'thrilled']
#   - causal_element: everything is done so spectacularly well
#   - target_audience: the audience
# • opinion_statement: 'I'm convinced that this guy just doesn't do bad movies.'
#   - subject: this guy
#   - sentiment: Positive
#   - key_phrase: doesn't do bad movies
# • opinion_statement: 'In the movie, it feels like it's Brad just being Brad.'
#   - subject: it
#   - sentiment: Positive
#   - key_phrase: feels like it's Brad just being Brad
# • opinion_statement: 'And it's amazing.'
#   - subject: it
#   - sentiment: Positive
#   - key_phrase: amazing
# • audience_impact: 'I'd pay to watch this again and again.'
#   - emotion_evoked: ['satisfied', 'engaged']
#   - causal_element: watch this again
#   - target_audience: the reviewer
# • opinion_statement: 'What an awful film that I actually was looking forward to.'
#   - subject: film
#   - sentiment: Negative
#   - key_phrase: awful film
# • opinion_statement: 'The story line is so way out there in the fictional world it's unbelievable'
#   - subject: The story line
#   - sentiment: Negative
#   - key_phrase: way out there in the fictional world
# • opinion_statement: 'Lewis Hamilton should be ashamed to put his name to it'
#   - subject: Lewis Hamilton
#   - sentiment: Negative
#   - key_phrase: ashamed to put his name to it
# • opinion_statement: 'it's awful and I mean really awful and so far away from reality.'
#   - subject: it
#   - sentiment: Negative
#   - key_phrase: awful and so far away from reality
# • opinion_statement: 'A nearly perfect film'
#   - subject: film
#   - sentiment: Positive
#   - key_phrase: nearly perfect
# • opinion_statement: 'F1 has you on the edge of your seat 100% of the running time, which is long, but nobody cares.'
#   - subject: F1
#   - sentiment: Positive
#   - key_phrase: on the edge of your seat
# • audience_impact: 'on the edge of your seat'
#   - emotion_evoked: ['engaged', 'thrilled']
#   - causal_element: F1
#   - target_audience: you
# • opinion_statement: 'Live action incredibly filmed, great story, Def not cookie- cutter.'
#   - subject: Live action
#   - sentiment: Positive
#   - key_phrase: incredibly filmed
# • opinion_statement: 'great story'
#   - subject: story
#   - sentiment: Positive
#   - key_phrase: great
# • opinion_statement: 'Def not cookie- cutter.'
#   - subject: it
#   - sentiment: Positive
#   - key_phrase: not cookie- cutter
# • opinion_statement: 'I loved the program music.'
#   - subject: program music
#   - sentiment: Positive
#   - key_phrase: loved
# • opinion_statement: 'This is a go- see film!'
#   - subject: film
#   - sentiment: Positive
#   - key_phrase: go- see
# • opinion_statement: 'A pity there had to be a romance thrown into the mix, but it was tastefully and believably done.'
#   - subject: romance
#   - sentiment: Positive
#   - key_phrase: tastefully and believably done
# • opinion_statement: 'Additionally, moviegoers got a tremendous amount of behind- the- scenes techie and deal- making insider information.'
#   - subject: moviegoers
#   - sentiment: Positive
#   - key_phrase: tremendous amount of behind- the- scenes techie and deal- making insider information
# • opinion_statement: 'The most stunning part of F100was the camera work.'
#   - subject: camera work
#   - sentiment: Positive
#   - key_phrase: most stunning part
# • opinion_statement: 'it was incredibly realistic.'
#   - subject: it
#   - sentiment: Positive
#   - key_phrase: incredibly realistic
# • opinion_statement: 'And Brad Pitt shows that he still has it!'
#   - subject: Brad Pitt
#   - sentiment: Positive
#   - key_phrase: still has it
# • opinion_statement: 'You will thoroughly enjoy this film.'
#   - subject: this film
#   - sentiment: Positive
#   - key_phrase: thoroughly enjoy
# • audience_impact: 'thoroughly enjoy this film'
#   - emotion_evoked: ['enjoyment', 'satisfaction']
#   - causal_element: this film
#   - target_audience: You
# • opinion_statement: 'Overrated'
#   - subject: it
#   - sentiment: Negative
#   - key_phrase: Overrated
# • opinion_statement: 'Obviously being a movie, it streamlines heaps of F1, but uses enough reality to feel convincing.'
#   - subject: movie
#   - sentiment: Positive
#   - key_phrase: uses enough reality to feel convincing
# • opinion_statement: 'The movie is done with sincerity and care, with lots of American and Hollywood glamour on top of it.'
#   - subject: The movie
#   - sentiment: Positive
#   - key_phrase: done with sincerity and care
# • opinion_statement: 'The audio-visual aspect is the best part of the movie, but suffers from shot repetition and mix-match editing on fast paced stuff.'
#   - subject: audio-visual aspect
#   - sentiment: Positive
#   - key_phrase: best part
# • opinion_statement: 'suffers from shot repetition and mix-match editing on fast paced stuff.'
#   - subject: it
#   - sentiment: Negative
#   - key_phrase: shot repetition and mix-match editing
# • opinion_statement: 'Also some of the races should have utilized "space" and length bit more.'
#   - subject: races
#   - sentiment: Negative
#   - key_phrase: should have utilized space and length bit more
# • opinion_statement: 'F1 race weekend is long after all and the movie fast forwards to race day on each of them.'
#   - subject: movie
#   - sentiment: Neutral
#   - key_phrase: fast forwards to race day
# • opinion_statement: 'might feel a bit underwhelming'
#   - subject: the movie
#   - sentiment: Negative
#   - key_phrase: underwhelming
# • audience_impact: 'you'll probably enjoy it'
#   - emotion_evoked: ['enjoyment']
#   - causal_element: casual interest in cars and racing
#   - target_audience: someone with a casual interest in cars and racing
# • audience_impact: 'you're in for the best experience'
#   - emotion_evoked: ['best experience']
#   - causal_element: stunning cinematography, a twist-filled story, and one of the best soundtracks produced for a film
#   - target_audience: someone who knows nothing about the sport
# • opinion_statement: 'delivers some solid twists'
#   - subject: The movie
#   - sentiment: Positive
#   - key_phrase: solid twists
# • opinion_statement: 'stepping into the role of a leader and father figure for a struggling team'
#   - subject: Brad Pitt
#   - sentiment: Positive
#   - key_phrase: leader and father figure
# • audience_impact: 'best way to experience it's visually stunning and fully immersive'
#   - emotion_evoked: ['visually stunning', 'fully immersive']
#   - causal_element: Watching it in IMAX
#   - target_audience: the audience
# • opinion_statement: 'amazing cinematography, color grading, and infrastructure.'
#   - subject: cinematography, color grading, and infrastructure
#   - sentiment: Positive
#   - key_phrase: amazing
# • opinion_statement: 'You can tell they spent a lot of money on this movie.'
#   - subject: the movie
#   - sentiment: Positive
#   - key_phrase: spent a lot of money
# • opinion_statement: 'Some good humor here and there, too.'
#   - subject: humor
#   - sentiment: Positive
#   - key_phrase: good humor
# • opinion_statement: 'But it all quickly goes downhill.'
#   - subject: it
#   - sentiment: Negative
#   - key_phrase: goes downhill
# • opinion_statement: 'Absolutely no realism in terms of racing'
#   - subject: realism in terms of racing
#   - sentiment: Negative
#   - key_phrase: no realism
# • opinion_statement: 'physics just doesn't work, and penalties for rash driving don't exist.'
#   - subject: physics and penalties
#   - sentiment: Negative
#   - key_phrase: doesn't work
# • audience_impact: 'I left the theater disappointed.'
#   - emotion_evoked: ['disappointed']
#   - causal_element: the movie
#   - target_audience: the reviewer
# • opinion_statement: 'This seemed like more of a guide on how to crash your car than a movie worthy of its title.'
#   - subject: This
#   - sentiment: Negative
#   - key_phrase: more of a guide on how to crash your car than a movie worthy of its title
# • opinion_statement: 'Worst of all is the story itself.'
#   - subject: the story itself
#   - sentiment: Negative
#   - key_phrase: Worst of all
# • opinion_statement: 'By Hollywood standards, it's very, very average, maybe slightly above.'
#   - subject: it
#   - sentiment: Neutral
#   - key_phrase: very, very average, maybe slightly above
# • opinion_statement: 'The shallow attempt at actually creating a story... just no.'
#   - subject: The shallow attempt at actually creating a story
#   - sentiment: Negative
#   - key_phrase: just no
# • opinion_statement: 'It's a movie that lacks depth, character fibre, plot and, overall, newness.'
#   - subject: It's a movie
#   - sentiment: Negative
#   - key_phrase: lacks depth, character fibre, plot and, overall, newness
# • opinion_statement: 'it's very mundane.'
#   - subject: it
#   - sentiment: Negative
#   - key_phrase: very mundane
# • opinion_statement: 'It won't be remembered.'
#   - subject: It
#   - sentiment: Negative
#   - key_phrase: won't be remembered
# • opinion_statement: 'It doesn't give you the passion for F1.'
#   - subject: It
#   - sentiment: Negative
#   - key_phrase: doesn't give you the passion for F1
# • opinion_statement: 'You won't see this movie more than once.'
#   - subject: this movie
#   - sentiment: Negative
#   - key_phrase: won't see this movie more than once
# • opinion_statement: 'it would have been great'
#   - subject: it
#   - sentiment: Positive
#   - key_phrase: would have been great
# • opinion_statement: 'From the moment the movie started you knew how it's going to end so you think, "ok, maybe there's some cool stuff". Nope. It's as lame as it can be.'
#   - subject: It
#   - sentiment: Negative
#   - key_phrase: as lame as it can be
# • opinion_statement: 'I just find it mesmerising how people give 10/10 to this movie.'
#   - subject: people give 10/10 to this movie
#   - sentiment: Negative
#   - key_phrase: mesmerising
# • opinion_statement: 'Have we lost our minds?'
#   - subject: we
#   - sentiment: Negative
#   - key_phrase: lost our minds
# • opinion_statement: 'F1 racing movie with lazy writing, what could go wrong!'
#   - subject: F1 racing movie with lazy writing
#   - sentiment: Negative
#   - key_phrase: what could go wrong
# • opinion_statement: 'he was definitely flat in this one and didn't bring much to his character.'
#   - subject: he
#   - sentiment: Negative
#   - key_phrase: definitely flat and didn't bring much to his character
# • opinion_statement: 'The whole story was very lazy and nowhere close to racing movies such as Rush and Ford vs Ferrari.'
#   - subject: The whole story
#   - sentiment: Negative
#   - key_phrase: very lazy and nowhere close to racing movies
# • opinion_statement: 'everything was flat'
#   - subject: everything
#   - sentiment: Negative
#   - key_phrase: flat
# • opinion_statement: 'silly storylines'
#   - subject: storylines
#   - sentiment: Negative
#   - key_phrase: silly
# • opinion_statement: 'the thin story of combat can beat speed on the race track, not going to happen'
#   - subject: story
#   - sentiment: Negative
#   - key_phrase: thin story
# • opinion_statement: 'let Pitt smirk his way to a win'
#   - subject: Pitt
#   - sentiment: Negative
#   - key_phrase: smirk his way to a win
# • opinion_statement: 'Too bad'
#   - subject: it
#   - sentiment: Negative
#   - key_phrase: Too bad
# LangExtract: Saving to results\info_extractions\review_extraction.jsonl: 1 docs [00:00, 113.25 docs/s]
# ✓ Saved 1 documents to results\info_extractions\review_extraction.jsonl
# LangExtract: Loading results\info_extractions\review_extraction.jsonl: 100%|█████▉| 79.0k/79.0k [00:00<00:00, 3.91MB/s]
# ✓ Loaded 1 documents from results\info_extractions\review_extraction.jsonl
# ✓ Visualization saved to ./results/info_extractions/review_extraction_vis.html

# %%
html_content_1
# Out:
# <style>
# .lx-highlight { position: relative; border-radius:3px; padding:1px 2px;}
# .lx-highlight .lx-tooltip {
#   visibility: hidden;
#   opacity: 0;
#   transition: opacity 0.2s ease-in-out;
#   background: #333;
#   color: #fff;
#   text-align: left;
#   border-radius: 4px;
#   padding: 6px 8px;
#   position: absolute;
#   z-index: 1000;
#   bottom: 125%;
#   left: 50%;
#   transform: translateX(-50%);
#   font-size: 12px;
#   max-width: 240px;
#   white-space: normal;
#   box-shadow: 0 2px 6px rgba(0,0,0,0.3);
# }
# .lx-highlight:hover .lx-tooltip { visibility: visible; opacity:1; }
# .lx-animated-wrapper { max-width: 100%; font-family: Arial, sans-serif; }
# .lx-controls {
#   background: #fafafa; border: 1px solid #90caf9; border-radius: 8px;
#   padding: 12px; margin-bottom: 16px;
# }
# .lx-button-row {
#   display: flex; justify-content: center; gap: 8px; margin-bottom: 12px;
# }
# .lx-control-btn {
#   background: #4285f4; color: white; border: none; border-radius: 4px;
#   padding: 8px 16px; cursor: pointer; font-size: 13px; font-weight: 500;
#   transition: background-color 0.2s;
# }
# .lx-control-btn:hover { background: #3367d6; }
# .lx-progress-container {
#   margin-bottom: 8px;
# }
# .lx-progress-slider {
#   width: 100%; margin: 0; appearance: none; height: 6px;
#   background: #ddd; border-radius: 3px; outline: none;
# }
# .lx-progress-slider::-webkit-slider-thumb {
#   appearance: none; width: 18px; height: 18px; background: #4285f4;
#   border-radius: 50%; cursor: pointer;
# }
# .lx-progress-slider::-moz-range-thumb {
#   width: 18px; height: 18px; background: #4285f4; border-radius: 50%;
#   cursor: pointer; border: none;
# }
# .lx-status-text {
#   text-align: center; font-size: 12px; color: #666; margin-top: 4px;
# }
# .lx-text-window {
#   font-family: monospace; white-space: pre-wrap; border: 1px solid #90caf9;
#   padding: 12px; max-height: 260px; overflow-y: auto; margin-bottom: 12px;
#   line-height: 1.6;
# }
# .lx-attributes-panel {
#   background: #fafafa; border: 1px solid #90caf9; border-radius: 6px;
#   padding: 8px 10px; margin-top: 8px; font-size: 13px;
# }
# .lx-current-highlight {
#   border-bottom: 4px solid #ff4444;
#   font-weight: bold;
#   animation: lx-pulse 1s ease-in-out;
# }
# @keyframes lx-pulse {
#   0% { text-decoration-color: #ff4444; }
#   50% { text-decoration-color: #ff0000; }
#   100% { text-decoration-color: #ff4444; }
# }
# .lx-legend {
#   font-size: 12px; margin-bottom: 8px;
#   padding-bottom: 8px; border-bottom: 1px solid #e0e0e0;
# }
# .lx-label {
#   display: inline-block;
#   padding: 2px 4px;
#   border-radius: 3px;
#   margin-right: 4px;
#   color: #000;
# }
# .lx-attr-key {
#   font-weight: 600;
#   color: #1565c0;
#   letter-spacing: 0.3px;
# }
# .lx-attr-value {
#   font-weight: 400;
#   opacity: 0.85;
#   letter-spacing: 0.2px;
# }
#
# /* Add optimizations with larger fonts and better readability for GIFs */
# .lx-gif-optimized .lx-text-window { font-size: 16px; line-height: 1.8; }
# .lx-gif-optimized .lx-attributes-panel { font-size: 15px; }
# .lx-gif-optimized .lx-current-highlight { text-decoration-thickness: 4px; }
# </style>
#     <div class="lx-animated-wrapper lx-gif-optimized">
#       <div class="lx-attributes-panel">
#         <div class="lx-legend">Highlights Legend: <span class="lx-label" style="background-color:#D2E3FC;">audience_impact</span> <span class="lx-label" style="background-color:#C8E6C9;">opinion_statement</span></div>
#         <div id="attributesContainer"></div>
#       </div>
#       <div class="lx-text-window" id="textWindow">
#         **Page 1**
# &quot;&quot;&quot;
# 1,657 reviews
# Hide spoilers
# Ratings
# Sort by
# gary-szendzielarz-142-951616
# Jun 23, 2025
# Permalink
# Review
# Featured
# Show all
# Featured
# 8/10
# Been an F1 fan since the mid-80s
# ...and I went into this expecting a Hollywood movie and thrilling entertainment...<span class="lx-highlight lx-current-highlight" data-idx="0" style="background-color:#C8E6C9;">it
# delivered</span>.
# Look, even die-hard F1 fans have to admit that not every waking moment of a race is
# fun. This film took elements from race history and used it over the space of nine
# races. Whether it was Grosjean&#x27;s fireball, or the moment Senna grabbed the fire
# extinguisher from the marshal, they took and they used. <span class="lx-highlight" data-idx="1" style="background-color:#C8E6C9;">Yes there were some over the
# top elements</span>, but what would you prefer? Track limit arguments?
# Helpful
# 451
# 86
# •
# 9/10
# F1: The Movie - A Review That Overshot the Pit Stop (But in Style)
# Back
# F1電影
# User reviews
# Sign in
# Use app
# 2025/11/24 晚上10:44
# F1電影 (2025) - User reviews - IMDb
# https://www.imdb.com/title/tt16311594/reviews/
# 1/18
# &quot;&quot;&quot;
#
# **Page 2**
# &quot;&quot;&quot;
# chetanpr2003
# Jul 1, 2025
# Permalink
# colinsmith-63124
# Jun 26, 2025
# Permalink
# Firstly, the music. Oh boy!
# I came expecting engine roars... and instead got <span class="lx-highlight" data-idx="2" style="background-color:#C8E6C9;">Hans Zimmer blasting emotions at
# 300 km/h</span>. <span class="lx-highlight" data-idx="3" style="background-color:#D2E3FC;">I wasn&#x27;t prepared for this concert. I came to the theatre for Formula 1, not
# to feel my feelings in Dolby Atmos.</span> The guitars and drums were doing more laps than
# the cars.
# <span class="lx-highlight" data-idx="4" style="background-color:#C8E6C9;">Cinematography? A thing to Marvel at!</span>
# No, no - NOT that Marvel. This isn&#x27;t a multiverse; this is motorsport. But I&#x27;ll give it to
# Kosinski - <span class="lx-highlight" data-idx="5" style="background-color:#C8E6C9;">the man knows how to shoot speed.</span> The close-ups, the helmet cams, the pit
# lane drama - <span class="lx-highlight" data-idx="6" style="background-color:#C8E6C9;">it&#x27;s all smoother than Lewis on a soft compound.</span>
# <span class="lx-highlight" data-idx="7" style="background-color:#C8E6C9;">Kosinski pulls it off again</span> As expected, the Top Gun: Maverick director brings his
# Helpful
# 574
# 117
# •
# 7/10
# <span class="lx-highlight" data-idx="8" style="background-color:#C8E6C9;">Great action, silly story</span>
# <span class="lx-highlight" data-idx="9" style="background-color:#C8E6C9;">It&#x27;s sort of fun</span>,<span class="lx-highlight" data-idx="10" style="background-color:#C8E6C9;">Brad pitt is his usual charismatic self</span>, <span class="lx-highlight" data-idx="11" style="background-color:#C8E6C9;">Damon iris is solid in support</span>,
# <span class="lx-highlight" data-idx="12" style="background-color:#C8E6C9;">kerry condon is always great</span> and <span class="lx-highlight" data-idx="13" style="background-color:#C8E6C9;">a very underated actress</span>, but to.be honest if you are
# a fan of actual formula one the story is beyond ridiculous, not one part of it makes any
# sense, its all style and not much substance, the dialogue is very cheesy, nothing is in
# anyway surprising as a blind man could see what was going to happen All in all its a
# well shot film, the racing sequences are great, but again if you&#x27;ve ever watched actual
# formula 1, they are beyond ridiculous, the real team heads that are used for cameos
# Helpful
# 388
# 102
# •
# 8/10
# Decent Story, Great Cinematography
# 2025/11/24 晚上10:44
# F1電影 (2025) - User reviews - IMDb
# https://www.imdb.com/title/tt16311594/reviews/
# 2/18
# &quot;&quot;&quot;
#
# **Page 3**
# &quot;&quot;&quot;
# Hazadoors
# Jun 24, 2025
# Permalink
# daanceelen
# Jun 29, 2025
# Permalink
# Just got out of the theater. It was a full theater so I got my tickets weeks in advance.
# I&#x27;ve never watched anything F1 related in my life. I give it a 7.5/10. The <span class="lx-highlight" data-idx="14" style="background-color:#C8E6C9;">IMAX scenes
# were fantastic</span>. No shortage of those. <span class="lx-highlight" data-idx="15" style="background-color:#C8E6C9;">The story was a classic underdog story. Still
# pretty good in my opinion.</span> <span class="lx-highlight" data-idx="16" style="background-color:#C8E6C9;">There was some pretty good comedy mixed in.</span> <span class="lx-highlight" data-idx="17" style="background-color:#C8E6C9;">The amount
# of advertising from companies was INSANE.</span> There really was a lot.
# <span class="lx-highlight" data-idx="18

# %% [markdown]
# [**Observation**]
#
# There are many character names in the reviews that might interfere with the ability to analyze the data. So it may wrongly include some names and words it does not know in the opinion statement. The words are sometimes present in many kinds of meaning and would also interfere with the result the model finds. As there are many words I didn't explain and mark, and the multi-meaning words, the model marked many sentences among all reviews, which may not be sensitive and accurate enough.

# %% [markdown]
# ---
# ### <a id='toc1_5_8_'></a>[**2.4 Generating LLM Embeddings:**](#toc0_)
#
# LLM embeddings are dense numerical vectors that represent the semantic meaning of text. Generated by Large Language Models, they map words, phrases, or documents into a high-dimensional space where similar concepts are positioned closely together.
#
# Their key advantages are:
#
# *   **Contextual Understanding:** Unlike older methods, LLM embeddings are contextual. The vector for a word like **"bank"** will be different depending on whether it's used in the context of a "river bank" or a "money bank," providing a more nuanced representation of language.
#
# *   **Versatility from Pre-training:** They are pre-trained on vast amounts of text data. This allows them to generalize effectively across various tasks, such as classification, clustering, and similarity detection. They do not require extensive retraining.
#
# <span style="color:green">For the exercise in this section there is no need to re-run the cells, you can use the data that has been saved previously to the corresponding directory.</span>
#
# **Now let's generate some embeddings with Gemini for a sample of our dataset:**

# %%
from google import genai
import pandas as pd
import time
from google.api_core import exceptions

# Let's define our function to get the embeddings with Gemini
def get_gemini_embedding(text: str, model: str="gemini-embedding-001"):
    try:
        result = client.models.embed_content(model=model, contents=[text])
        # 100 requests per minute limit -> 60s / 100 = 0.6s per request
        # buffer time to avoid rate limits
        time.sleep(0.6)
        return result.embeddings
    except exceptions.ResourceExhausted as e:
        print(f"Rate limit exceeded. Waiting to retry... Error: {e}")
        time.sleep(5) # Wait for 5 seconds before the next attempt
        return get_gemini_embedding(text, model) # Retry the request
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
        return None

# %%
total_extractions = 200
train_ratio = 0.8
test_ratio = 0.2

n_train_to_sample = int(total_extractions * train_ratio)
n_test_to_sample = int(total_extractions * test_ratio)
column_name = 'text'

def stratified_sample(df: pd.DataFrame, n_samples: int, stratify_col: str = 'emotion') -> pd.DataFrame:
    if n_samples >= len(df):
        return df.copy() 
    sampled_df = df.groupby(stratify_col, group_keys=False).apply(
        lambda x: x.sample(n=max(0, int(round(len(x) / len(df) * n_samples))))
    )

    current_samples = len(sampled_df)
    if current_samples < n_samples:
        remaining_indices = df.index.difference(sampled_df.index)
        additional_samples = df.loc[remaining_indices].sample(n=n_samples - current_samples, random_state=42)
        sampled_df = pd.concat([sampled_df, additional_samples])
    elif current_samples > n_samples:
        sampled_df = sampled_df.sample(n=n_samples, random_state=42)
    return sampled_df

print(f"Sampling {n_train_to_sample} rows from the training set...")
train_df_new = stratified_sample(train_df, n_train_to_sample, 'emotion')

print(f"Sampling {n_test_to_sample} rows from the test set...")
test_df_new = stratified_sample(test_df, n_test_to_sample, 'emotion')
# Out:
# Sampling 160 rows from the training set...
# Sampling 40 rows from the test set...
# C:\Users\vivia\AppData\Local\Temp\ipykernel_11920\2000596105.py:14: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   sampled_df = df.groupby(stratify_col, group_keys=False).apply(
# C:\Users\vivia\AppData\Local\Temp\ipykernel_11920\2000596105.py:14: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   sampled_df = df.groupby(stratify_col, group_keys=False).apply(

# %%
train_df_new["emotion"].value_counts()
# Out:
# emotion
# fear       51
# anger      38
# joy        36
# sadness    35
# Name: count, dtype: int64

# %%
test_df_new["emotion"].value_counts()
# Out:
# emotion
# fear       13
# anger      10
# joy         9
# sadness     8
# Name: count, dtype: int64

# %%
# Apply the function to the specified column and store the result in a new column 'embeddings'
print("\nGenerating embeddings for the new training set...")
train_df_new['embeddings'] = train_df_new[column_name].apply(get_gemini_embedding)
# Out:
# Generating embeddings for the new training set...

# %%
print("\nGenerating embeddings for the new test set...")
test_df_new['embeddings'] = test_df_new[column_name].apply(get_gemini_embedding)
# Out:
# Generating embeddings for the new test set...

# %%
from google.genai import types

# After getting the embeddings we need to convert the Gemini type ContentDict of the embeddings into a simple list with them
train_df_new['embeddings_values'] = train_df_new["embeddings"].apply(lambda row: list(types.ContentDict(row[0]).values())[0])
test_df_new['embeddings_values'] = test_df_new["embeddings"].apply(lambda row: list(types.ContentDict(row[0]).values())[0])

# %%
train_df_new #We can see the new column with the embeddings
# Out:
#          id                                               text  emotion  \
# 775   10775  I wish the next madden has a story mode too. J...    anger
# 375   10375  @cc_yandian @HillaryClinton her team must draw...    anger
# 422   10422       Drop Snapchat names #bored #snap #swap #pics    anger
# 599   10599  As your own lives in order to complete our ama...    anger
# 299   10299  @johnaugust @clmazin I was so looking forward ...    anger
# ...     ...                                                ...      ...
# 3579  40752  Well i did hear once before that girls are att...  sadness
# 3378  40551  Like, 'loon attic'. Luckily it quickly sunk in...  sadness
# 3042  40215  @MxJackMonroe I couldn't get on with it either...  sadness
# 2976  40149  If you find me lost, will you stay as a passer...  sadness
# 3117  40290  Two blankets, a hoody, and still no Eternal Su...  sadness
#
#       intensity                                         embeddings  \
# 775       0.292  [values=[-0.013177777, -0.00353716, 0.00749771...
# 375       0.521  [values=[-0.018429024, 0.008782404, -0.0016314...
# 422       0.500  [values=[-0.023692748, 0.0140969185, -0.008076...
# 599       0.417  [values=[-0.009396469, -0.0024766147, 0.014487...
# 299       0.491  [values=[-0.009324027, -0.013910245, 0.0099156...
# ...         ...                                                ...
# 3579      0.188  [values=[-0.016785758, 0.00016087502, 0.006101...
# 3378      0.375  [values=[-0.0076745865, 0.0034149962, -0.02463...
# 3042      0.625  [values=[0.012172773, -0.011557417, -0.0158430...
# 2976      0.680  [values=[-0.018256757, 0.013580975, -0.0108445...
# 3117      0.562  [values=[-0.021652576, -0.012119704, -0.026361...
#
#                                       embeddings_values
# 775   [-0.013177777, -0.00353716, 0.0074977158, -0.0...
# 375   [-0.018429024, 0.008782404, -0.0016314974, -0....
# 422   [-0.023692748, 0.0140969185, -0.008076023, -0....
# 599   [-0.009396469, -0.0024766147, 0.014487161, -0....
# 299   [-0.009324027, -0.013910245, 0.00991563, -0.09...
# ...                                                 ...
# 3579  [-0.016785758, 0.00016087502, 0.006101796, -0....
# 3378  [-0.0076745865, 0.0034149962, -0.024630843, -0...
# 3042  [0.012172773, -0.011557417, -0.015843056, -0.0...
# 2976  [-0.018256757, 0.013580975, -0.010844502, -0.0...
# 3117  [-0.021652576, -0.012119704, -0.026361963, -0....
#
# [160 rows x 6 columns]

# %%
test_df_new #We can see the new column with the embeddings
# Out:
#         id                                               text  emotion  \
# 230  30859  incredible that anthony weiner has been caught...      joy
# 116  21179                 @spencer0415 awe, I love you kid!!     fear
# 29   10886  @isthataspider @dhodgs i will fight this guy! ...    anger
# 209  30838  i was so embarrassed when she saw us i was lik...      joy
# 41   10898  Realest ever, relentless ever, inevitable that...    anger
# 337  40850  aaahhhh! a little @OtisRedding to soothe the s...  sadness
# 92   21155  If my concerns &amp; anxiety don't matter to y...     fear
# 344  40857  If you #invest in my new #film I will stop ask...  sadness
# 196  30825  Nawaz Sharif is getting more funnier than @kap...      joy
# 10   10867  @Yoshi_OnoChin can you please not have Canadia...    anger
# 268  30897  It feels good to get outside for a minute and ...      joy
# 183  21246  @AaliyahLove69 I would be intimidated but I wo...     fear
# 178  21241       Tweeting from the sporadic wifi on the tube      fear
# 77   10934  @FluDino Event started! everyone is getting re...    anger
# 189  21252  Staff on @ryainair FR1005. Asked for info and ...     fear
# 326  40839  HATE that there's ads for #depression &amp; #m...  sadness
# 176  21239  @ReaganBattalion That's a terrible thing to ac...     fear
# 286  40799  @kayleighmcenany  @DonaldJTrumpJr Is that real...  sadness
# 341  40854  340:892 All with weary task fordone.\nNow the ...  sadness
# 30   10887  Everybody talking about 'the first day of fall...    anger
# 250  30879  @Bridget_Jones was joyous. Worried I would be ...      joy
# 75   10932                            @DJ_JeanFranko growl!!!    anger
# 121  21184  Nothing worse than an uber driver that can't d...     fear
# 6    10863  I think @Sam_Canaday &amp; @KYLEJDOWSON must a...    anger
# 231  30860  @len_snart Mick nods. 'I would like that.' He ...      joy
# 145  21208                    Rooney shocking attempted cross     fear
# 45   10902  S/O to the girl that just hit my car...not onl...    anger
# 238  30867  @DocBellsSwan *peers down at you, eyes crinkli...      joy
# 342  40855  Common app just randomly logged me out as I wa...  sadness
# 25   10882  It's the most magical time of the year......Xm...    anger
# 323  40836  im thoroughly in love w zen and jumin and i do...  sadness
# 222  30851  Heather that was #hilarious! @MsHeatherBates @...      joy
# 274  40787  A pessimist is someone who, when opportunity k...  sadness
# 130  21193  Came in to work today 1.5 hours late.1st thing...     fear
# 184  21247  it's horrible cos no one can relate,  everyone...     fear
# 87   21150  @1johndes ball watching &amp; Rojo'd header wa...     fear
# 175  21238  #twitter #users Tweeting on twitter is like pl...     fear
# 52   10909  I miss my gran singing Rawhide, in her deep ba...    anger
# 115  21178  Okay. Brace yourself. I will attempt my first ...     fear
# 228  30857  If you don't respond to an email within 7 fays...      joy
#
#      intensity                                         embeddings  \
# 230      0.380  [values=[-0.02280395, 0.02069193, -0.000340573...
# 116      0.060  [values=[-0.02007491, 0.02974427, -0.009964777...
# 29       0.708  [values=[-0.0165704, 0.014682377, 0.01964287, ...
# 209      0.250  [values=[-0.021463713, -0.0071487995, -0.01163...
# 41       0.415  [values=[-0.014525433, 0.01642175, 0.010939563...
# 337      0.197  [values=[-0.009578301, -0.006965374, -0.013988...
# 92       0.729  [values=[-0.02349053, -0.000944749, -0.0057726...
# 344      0.458  [values=[-0.012564192, -0.012203087, 0.0146256...
# 196      0.580  [values=[-0.03421193, 0.017039796, 0.028741952...
# 10       0.646  [values=[-0.009779071, -0.020864518, -0.024792...
# 268      0.580  [values=[-0.019597428, -0.012538523, -0.003372...
# 183      0.417  [values=[-0.0041318764, -0.040916465, 0.015833...
# 178      0.292  [values=[-0.0066989562, 0.0057921065, -0.01125...
# 77       0.521  [values=[0.00306014, -0.01875603, 0.016292607,...
# 189      0.312  [values=[-0.025618004, 0.0014453683, 0.0045416...
# 326      0.460  [values=[-0.008212951, -0.012283811, -0.005047...
# 176      0.438  [values=[-0.01019594, -0.029994544, 0.01090095...
# 286      0.375  [values=[-0.013754529, 0.012150785, 0.01298435...
# 341      0.458  [values=[-0.010497439, 0.005313204, -0.0098101...
# 30       0.417  [values=[-0.016532253, -0.018671215, 0.0024112...
# 250      0.680  [values=[-0.019118113, -0.017402798, -0.030459...
# 75       0.500  [values=[0.015252903, 0.0042496077, 0.02459122...
# 121      0.562  [values=[0.010763933, -0.003074528, -0.0115314...
# 6        0.250  [values=[-0.010546908, 0.021585377, 0.00737523...
# 231      0.620  [values=[0.007279358, -0.014534431, -0.0003606...
# 145      0.375  [values=[0.0127588855, -0.0021300393, -0.02128...
# 45       0.542  [values=[-0.021190451, -0.0024552303, -0.02645...
# 238      0.660  [values=[-0.01825409, -0.009553344, -0.0124245...
# 342      0.833  [values=[0.0018189758, 0.023590546, -0.0067852...
# 25       0.429  [values=[-0.032807905, 0.002414791, -0.0038823...
# 323      0.458  [values=[0.00336918, -0.03743703, -0.012332446...
# 222      0.812  [values=[-0.023940003, 0.0017229738, 0.0072910...
# 274      0.188  [values=[-0.0060030012, -0.030475287, 0.009684...
# 130      0.896  [values=[-0.014280062, 0.00909578, -0.02008236...
# 184      0.542  [values=[-0.031625725, -0.018231656, -0.013723...
# 87       0.475  [values=[0.005264606, 0.012534002, -0.01148543...
# 175      0.521  [values=[-0.024715586, -0.01256246, -0.0125413...
# 52       0.292  [values=[-0.005721748, 0.01401517, -0.00986495...
# 115      0.479  [values=[-0.008750161, -0.008474275, 0.0091263...
# 228      0.180  [values=[-0.009656984, 0.028854532, 0.00265956...
#
#                                      embeddings_values
# 230  [-0.02280395, 0.02069193, -0.00034057387, -0.0...
# 116  [-0.02007491, 0.02974427, -0.009964777, -0.065...
# 29   [-0.0165704, 0.014682377, 0.01964287, -0.05526...
# 209  [-0.021463713, -0.0071487995, -0.011631403, -0...
# 41   [-0.014525433, 0.01642175, 0.010939563, -0.071...
# 337  [-0.009578301, -0.006965374, -0.013988109, -0....
# 92   [-0.02349053, -0.000944749, -0.0057726167, -0....
# 344  [-0.012564192, -0.012203087, 0.014625612, -0.0...
# 196  [-0.03421193, 0.017039796, 0.028741952, -0.085...
# 10   [-0.009779071, -0.020864518, -0.024792155, -0....
# 268  [-0.019597428, -0.012538523, -0.0033721798, -0...
# 183  [-0.0041318764, -0.040916465, 0.015833594, -0....
# 178  [-0.0066989562, 0.0057921065, -0.011250335, -0...
# 77   [0.00306014, -0.01875603, 0.016292607, -0.0684...
# 189  [-0.025618004, 0.0014453683, 0.0045416863, -0....
# 326  [-0.008212951, -0.012283811, -0.005047617, -0....
# 176  [-0.01019594, -0.029994544, 0.010900953, -0.05...
# 286  [-0.013754529, 0.012150785, 0.012984351, -0.05...
# 341  [-0.010497439, 0.005313204, -0.009810179, -0.0...
# 30   [-0.016532253, -0.018671215, 0.0024112132, -0....
# 250  [-0.019118113, -0.017402798, -0.030459225, -0....
# 75   [0.015252903, 0.0042496077, 0.024591228, -0.08...
# 121  [0.010763933, -0.003074528, -0.011531402, -0.0...
# 6    [-0.010546908, 0.021585377, 0.0073752305, -0.0...
# 231  [0.007279358, -0.014534431, -0.00036064742, -0...
# 145  [0.0127588855, -0.0021300393, -0.021284327, -0...
# 45   [-0.021190451, -0.0024552303, -0.026451988, -0...
# 238  [-0.01825409, -0.009553344, -0.012424581, -0.0...
# 342  [0.0018189758, 0.023590546, -0.0067852526, -0....
# 25   [-0.032807905, 0.002414791, -0.0038823327, -0....
# 323  [0.00336918, -0.03743703, -0.012332446, -0.064...
# 222  [-0.023940003, 0.0017229738, 0.007291086, -0.0...
# 274  [-0.0060030012, -0.030475287, 0.009684023, -0....
# 130  [-0.014280062, 0.00909578, -0.020082366, -0.05...
# 184  [-0.031625725, -0.018231656, -0.013723901, -0....
# 87   [0.005264606, 0.012534002, -0.011485438, -0.05...
# 175  [-0.024715586, -0.01256246, -0.0125413975, -0....
# 52   [-0.005721748, 0.01401517, -0.009864955, -0.08...
# 115  [-0.008750161, -0.008474275, 0.009126337, -0.0...
# 228  [-0.009656984, 0.028854532, 0.0026595625, -0.0...

# %%
# save them to pickle files
train_df_new.to_pickle("./data/train_df_sample_embeddings.pkl") 
test_df_new.to_pickle("./data/test_df_sample_embeddings.pkl")

# %%
import pandas as pd
# load the pickle files
train_df_new = pd.read_pickle("./data/train_df_sample_embeddings.pkl")
test_df_new = pd.read_pickle("./data/test_df_sample_embeddings.pkl")

# %%
len(train_df_new.iloc[0]["embeddings_values"]) # Gemini embedding dimension is 3072
# Out:
# 3072

# %%
import pandas as pd
import numpy as np
import umap
import plotly.express as px

# Concatenate the training and test data
combined_df = pd.concat([train_df_new, test_df_new], ignore_index=True)

# Prepare the embeddings for UMAP
# Convert the list of embeddings into a 2D numpy array
X_embeddings = np.array(combined_df['embeddings_values'].tolist())

# Apply UMAP for dimensionality reduction
reducer = umap.UMAP(n_components=2, metric='cosine', random_state=28) 
embedding_2d = reducer.fit_transform(X_embeddings)

# Create a DataFrame for plotting
df_plot = pd.DataFrame(embedding_2d, columns=['UMAP1', 'UMAP2'])
df_plot['emotion'] = combined_df['emotion']
df_plot['intensity'] = combined_df['intensity']
df_plot['text'] = combined_df['text']


# Visualize the embeddings with Plotly
fig = px.scatter(
    df_plot,
    x='UMAP1',
    y='UMAP2',
    color='emotion',  # Color points by the 'emotion' column
    hover_data=['text', 'intensity'],  # Show text and intensity on hover
    title='2D UMAP Projection of Text Embeddings'
)

fig.show()
# Out:
# C:\Users\vivia\Documents\DM2025Labs\DM2025-Lab2-Exercise\.venv\Lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(

# %% [markdown]
# We can see that even with Gemini's embeddings there doesn't seem to be a clear 2D separation of clusters with our data classes. It could be because emotions are often not discrete. Texts can contain mixed feelings (e.g., "bittersweet") or use similar language to express different emotions, causing their embeddings to be naturally close in semantic space. And also the process of projecting high-dimensional embeddings down to a 2D visualization inevitably loses some information, which can make distinct clusters appear to overlap.

# %% [markdown]
# ---
# ##### <a id='toc1_5_8_1_1_'></a>[**>>> Exercise 4 (Take home):**](#toc0_)
#
# Apply UMAP to the same embeddings to reduce the dimensionality to 3D vectors and plot the 3D graph, discuss the differences and similarities with the 2D graph.

# %%
# Answer here
import umap
import plotly.express as px

reducer = umap.UMAP(n_components=3, metric='cosine', random_state=28)
embedding_3d = reducer.fit_transform(X_embeddings)

df_plot_3d = pd.DataFrame(embedding_3d, columns=['UMAP1', 'UMAP2', 'UMAP3'])
df_plot_3d['emotion'] = combined_df['emotion']
df_plot_3d['intensity'] = combined_df['intensity']
df_plot_3d['text'] = combined_df['text']

fig_3d = px.scatter_3d(
    df_plot_3d,
    x='UMAP1',
    y='UMAP2',
    z='UMAP3',
    color='emotion', 
    hover_data=['text', 'intensity'],
    title='3D UMAP Projection of Text Embeddings'
)
fig_3d.show()
# Out:
# C:\Users\vivia\Documents\DM2025Labs\DM2025-Lab2-Exercise\.venv\Lib\site-packages\umap\umap_.py:1952: UserWarning:
#
# n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.

# %% [markdown]
# ![picture](pics/3d_plot.png)

# %% [markdown]
# [**Observation**]
#
# Compare to 2d plot, the 3d plot improved the visualization a little. The 3d plot shows clearer structures, while the 2d plot does not reveal clear
# relationships. For instance, from the screenshot above, we could observe that the joy emotion forms a loose cluster on the upper left, and the anger
# emotion is gathering more at the bottom-right. However, the 3d plot is still not clear enough to show the cluster distributions of each emotion and
# which does not fully capture the four categories. In summary, the 3d plot indeed improved to observe a bit more about the possible cluster
# distribution and reserve more information than the 2d plot, but it still doesn't have enough ability to explain all texts with mixed feelings and so
# shows overall pattern as the 2d plot.

# %% [markdown]
# ---
# ### <a id='toc1_5_9_'></a>[**2.5 Retrieval-Augmented Generation (RAG)**](#toc0_)
#
# `NOTE: This whole section including the exercise is now considered a bonus section, not counted for the main grade.`
#
# RAG (Retrieval-Augmented Generation) is a technique where a language model combines document retrieval with text generation. In RAG, a retrieval system first finds relevant documents or text chunks, and then the language model uses this retrieved information to generate a more informed and accurate response. This method enhances the model's ability to answer questions by grounding its responses in real, external data.
#
# In the following code, we will load a webpage as a document, which allows us to retrieve text from a URL. After loading the content, we will split the document into smaller, manageable chunks, making it easier for our model to process. Then, we'll generate embeddings for these chunks with a specified LLM model (Gemini Embedding Model). These embeddings will be stored in a vector database, which enables us to perform similarity searches. By setting up this retrieval system, we can use a RAG chain to answer questions. The retriever finds relevant text chunks from the document based on a query, and the LLM generates a response by incorporating this retrieved information, making the answers more grounded and accurate.
#
# In this example we use the library langchain, for documentation on more functions of the library you can check the following link: [LangChain Tutorials](https://python.langchain.com/docs/tutorials/)

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.document_loaders import WebBaseLoader
from langchain_community.vectorstores import Chroma
from langchain_google_genai import GoogleGenerativeAIEmbeddings

# Function to load, split, and retrieve documents
def load_and_retrieve_docs(url):
    loader = WebBaseLoader(
        web_paths=(url,),
        bs_kwargs=dict() 
    ) 
    docs = loader.load() #We will load the URL that will serve as our data source
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=150) #We will divide the URL in chunks of text for easier comparison in the vector space
    splits = text_splitter.split_documents(docs)
    #print(splits) #You can print this to see how the chunks in the url where split
    embeddings = GoogleGenerativeAIEmbeddings(model="models/gemini-embedding-001")
    vectorstore = Chroma.from_documents(documents=splits, embedding=embeddings) #Our vector space for comparison
    return vectorstore.as_retriever()


def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs) #Format the retrieved docs in an orderly manner for prompting

# Define the Gemini LLM function
def gemini_llm(question, context):
    system_prompt = "You are a RAG Agent that needs to provide a well structured answer based on the provided question and context."
    formatted_prompt = f"Question: {question}\n\nContext: {context}"
    response, logs = prompt_gemini(input_prompt = formatted_prompt, system_instruction = system_prompt, with_tokens_info = True)
    print(f"logs: \n{logs}")
    # print(f"Retrieved context: \n{context}\n\n") # You can print this to observe the retrieved context
    return response


# Define the RAG chain
def rag_chain(question, retriever):
    retrieved_docs = retriever.invoke(question)
    formatted_context = format_docs(retrieved_docs)
    return gemini_llm(question, formatted_context)

# %%
url="https://qbotica.com/understanding-artificial-general-intelligence-agi-an-in-depth-overview/"
# Create the retriever
retriever = load_and_retrieve_docs(url)

# Use the RAG chain
result = rag_chain(question="What are the Key Challenges in Realizing AGI’s Full Potential", retriever=retriever)
display(Markdown(result))
# Out:
# logs:
# {'model': 'gemini-2.5-flash-lite', 'input_tokens': 730, 'output_tokens': 70}
# Based on the provided text, the key challenges in realizing AGI's full potential are:
#
# *   **Improvements in Machine Learning:** Continued advancements in machine learning algorithms are crucial.
# *   **Computational Power:** Significant increases in computational power are necessary.
# *   **Data Availability:** Greater availability of data is a key factor for progress.

# %% [markdown]
# ##### <a id='toc1_5_9_1_1_'></a>[**Actual answer in the URL:**](#toc0_)
#
# ![pic11.png](pics/pic11.png)
#
# ##### <a id='toc1_5_9_1_2_'></a>[**Content in the URL that might get into the generated answer because of similar semantic meaning:**](#toc0_)
#
# ![pic12.png](pics/pic12.png)
#
# source: https://qbotica.com/understanding-artificial-general-intelligence-agi-an-in-depth-overview/

# %% [markdown]
# ---
# ##### <a id='toc1_5_9_1_3_'></a>[**>>> Bonus Exercise 5 (Take home):**](#toc0_)
#
# `NOTE: This exercise is now considered a bonus one, not counted for the main grade, only as extra points.`
#
# Your task is to test the RAG system with your own chosen URL and analyze its performance.
#
# 1. Find a URL of a webpage with interesting text content to test the RAG pipeline.
# 2. Make a question about the content in the webpage you chose.
# 3. Discuss how good the question was answered by the model, if the model missed important information related to your question.
# 4. Display a screenshot of the real answer in the webpage.

# %%
# Answer here

# %% [markdown]
# ---
# ### <a id='toc1_5_10_'></a>[**2.6 Few-Shot Prompting Classification:**](#toc0_)
#
# Few-shot prompting is a technique where a Large Language Model (LLM) is given a small number of labeled examples within a prompt to guide its classification. This allows the model to perform a new task with minimal data, avoiding the need for extensive fine-tuning.
#
# In this lab, we will use the Gemini API to perform zero-shot, 1-shot, and 5-shot emotion classification:
#
# *   **Zero-shot:** The model classifies text without any prior examples.
# *   **1-shot:** The model is given one example for each emotion before classifying.
# *   **5-shot:** The model is given five examples per emotion for better context.
#
# To make our implementation robust and efficient, we are incorporating two key features:
#
# 1.  **Structured Output:** We provide the Gemini model with a specific output schema (`Emotions` class). This instructs the model to return *only* a valid emotion label (e.g., `joy`), which makes the output predictable and reliable, minimizing errors.
# 2.  **API Rate Handling:** The code includes a function to manage the requests-per-minute limit of the Gemini API.
#
# We will test the model's performance on a small sample of 20 texts per emotion to ensure the process runs quickly. If the model provides an invalid response, the code will automatically retry the request until a valid classification is received.
#
# **Prompt Structure:**
# `System Instruction -> Task Description -> Examples (if not zero-shot) -> Text to Classify`
#
#
# <span style="color:green">For the exercises in this section there is no need to re-run the cells, you can use the data that has been saved previously to the corresponding directory.</span>

# %%
# Funciton for visualizing confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import itertools

def plot_confusion_matrix(cm, classes, title='Confusion matrix',
                          cmap=sns.cubehelix_palette(as_cmap=True)):
    """
    This function is modified from: 
    http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html
    """
    classes.sort()
    tick_marks = np.arange(len(classes))    
    
    fig, ax = plt.subplots(figsize=(5,5))
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           xticklabels = classes,
           yticklabels = classes,
           title = title,
           xlabel = 'Predicted label',
           ylabel = 'True label')

    fmt = 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt), horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")
    ylim_top = len(classes) - 0.5
    plt.ylim([ylim_top, -.5])
    plt.tight_layout()
    plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import enum
import os
from tqdm import tqdm
import json
import time
# Define the emotion labels
emotions = ['anger', 'fear', 'joy', 'sadness']
# Define the model to use for few-shot prompting

# Schema for the output, the type enum can be used to make a pool of options if what we want is to classify our text selecting only one of them
class Emotions(enum.StrEnum):
    ANGER = 'anger'
    FEAR = 'fear'
    JOY = 'joy'
    SADNESS = 'sadness'


# Function to handle the rate limits of gemini models
def handle_rate_limit(request_count, first_request_time, max_calls_per_min):
    current_time = time.time()

    # Initialize timer on the first request of a new window
    if request_count == 0:
        first_request_time = current_time

    request_count += 1

    # If the rate limit is reached
    if request_count > max_calls_per_min:
        elapsed_time = current_time - first_request_time
        if elapsed_time < 60:
            wait_time = 60 - elapsed_time
            print(f"Rate limit of {max_calls_per_min} requests per minute reached. Waiting for {wait_time:.2f} seconds.")
            time.sleep(wait_time)

        # Reset for the new window
        request_count = 1
        first_request_time = time.time()
    
    return request_count, first_request_time, max_calls_per_min

# Function to sample examples per emotion category
def sample_few_shots(df, emotions, num_samples=5):
    few_shot_examples = {}
    for emotion in emotions:
        few_shot_examples[emotion] = df[df['emotion'] == emotion].sample(n=num_samples, random_state=42)
    return few_shot_examples

# Function to build the prompt based on the number of examples (few-shot, 1-shot, zero-shot)
def build_prompt(examples, emotions, num_shots=5):
    classification_instructions = """
You will be given a text extracted from social media and your task is to classify the text into one of the following emotion categories: 
"anger" | "fear" | "joy" | "sadness"
    """
    
    prompt = classification_instructions + "\n\n"
    
    if num_shots > 0:
        prompt += f"Examples: \n"
        for emotion in emotions:
            for _, row in examples[emotion].iterrows():
                prompt += f"Text: {row['text']}\nClass: {emotion}\n\n" #Show the examples in the same format it will be shown for the classification text
                if num_shots == 1:  # If 1-shot, break after the first example for each emotion
                    break
    return prompt

# Function to classify using the LLM with retry for incorrect responses
def classify_with_llm(test_text, prompt_base, system_prompt, classes, schema):
    response = None
    while not response or response not in classes:
        full_prompt = f"{prompt_base}\nClassification:\nText: {test_text}\nClass: " #The classification text will leave the emotion label to be filled in by the LLM
        try:
            result = prompt_gemini(input_prompt = [full_prompt], schema = schema, system_instruction = system_prompt)
            # print(f"result: {result} \n")
            # print(f"type: {type(result)}")
            if not result:
                # In case of giving empty responses with temperature 0.0, we set a higher temperature to seek for different responses
                result = prompt_gemini(input_prompt = [full_prompt], schema = schema, system_instruction = system_prompt, temperature=1.0)

            try:
                # If the result is in the correct format it can be parsed using json
                response = json.load(result)
            except:
                # In case it's not in a json friendly format
                # Deleting characters " and ' in case they appear in our response with the class of the text 
                response = result.replace('"', '')    
                response = response.replace("'", "")  

                
        # except exceptions.ResourceExhausted as e:
        except Exception as e:
            print(f"Waiting to retry... Error: {e}")
            time.sleep(15)
            print(f"test_text: {test_text}")
            return classify_with_llm(test_text, prompt_base, system_prompt, classes, schema) # Retry the request


        if response not in classes:  # Retry if not a valid response
            print(f"Invalid response: {response}. Asking for reclassification.")
    return response

# Main function to run the experiment with the option for zero-shot, 1-shot, or 5-shot prompting
def run_experiment(df_train, df_test, num_test_samples=5, num_shots=5):
    # Sample examples for few-shot prompting based on num_shots
    if num_shots > 0:
        few_shot_examples = sample_few_shots(df_train, emotions, num_samples=num_shots) 
        prompt_base = build_prompt(few_shot_examples, emotions, num_shots=num_shots)
    else:
        prompt_base = build_prompt(None, emotions, num_shots=0)  # Zero-shot has no examples

    # System prompt for our classification model:
    system_prompt = "You are an emotion classification model for text data. Do not give empty responses, classify according to the list of possible classes."

    # Prepare to classify the test set
    results_data = []

    print(prompt_base)
    # Sample 20 examples per emotion for the test set to classify
    test_samples = sample_few_shots(df_test, emotions, num_samples=num_test_samples)

    # Variables to handle rate limit of gemini
    request_count = 0
    max_calls_per_min = 15 # Gemini 2.5 Flash Lite has this maximum set in the documentation
    first_request_time = None

    # Classify 20 test examples (5 from each category) and save predictions
    for emotion in emotions:
        for _, test_row in tqdm(test_samples[emotion].iterrows(), desc=f"Processing samples for emotion: {emotion}...", total=num_test_samples):
            test_text = test_row['text']
            request_count, first_request_time, max_calls_per_min = handle_rate_limit(request_count, first_request_time, max_calls_per_min)  # Check and handle rate limit before each API call
            predicted_emotion = classify_with_llm(test_text = test_text, prompt_base = prompt_base, system_prompt = system_prompt, classes = emotions, schema = Emotions)
            # Append the results data:
            results_data.append({
                    'text': test_text,
                    'true_emotion': emotion,
                    'predicted_emotion': predicted_emotion
                })

    # Create dataframe to save the results data
    results_df = pd.DataFrame(results_data)
    
    # Extract just the true and predicted labels for metrics calculations
    true_labels = results_df['true_emotion']
    predictions = results_df['predicted_emotion']

    output_dir = "./results/llm_classification_results"
    os.makedirs(output_dir, exist_ok=True)
    # Save the results
    filename = f"{output_dir}/results_samples_{num_test_samples}_shots_{num_shots}.csv"
    
    # Save the DataFrame to CSV
    results_df.to_csv(filename, index=False)
    print(f"\nResults saved to {filename}")

    # Calculate accuracy
    accuracy = accuracy_score(true_labels, predictions)
    print(f"Accuracy: {accuracy * 100:.2f}%")
    
    # Classification report
    print(classification_report(y_true=true_labels, y_pred=predictions))
    
    # Plot confusion matrix
    cm = confusion_matrix(y_true=true_labels, y_pred=predictions) 
    my_tags = ['anger', 'fear', 'joy', 'sadness']
    plot_confusion_matrix(cm, classes=my_tags, title=f'Confusion matrix for classification with \n{num_shots}-shot prompting')

# %% [markdown]
# **Important: The next part should take around 16 minutes to finish running due to API Rate Limits**
#
# **Note:** You might see an `429 RESOURCE_EXHAUSTED` error when running the following code all at once, this is because the `current API Rate Limit handling cannot reliably find out how many requests we have left per minute` from cell to cell, there is no Gemini feature created for it to get the information from their servers. So, `if you don't want to see the error you can just wait 1 minute` after one cell finished processing. But `even if there is an error showing it is fine`, internally in the code `there is a retry that happens every 15 seconds` until we finish processing our sampled data. `The lab is designed to never reach the total rate limit per day quota.`

# %%
# If you see '429 RESOURCE_EXHAUSTED' errors it's fine, wait until the data gets processed, it will keep retrying until it finishes

# Example of running the experiment with zero-shot prompting
run_experiment(train_df, test_df, num_test_samples=20, num_shots=0)
# Out:
# You will be given a text extracted from social media and your task is to classify the text into one of the following emotion categories:
# "anger" | "fear" | "joy" | "sadness"
# Processing samples for emotion: anger...:  75%|███████▌  | 15/20 [00:08<00:02,  1.78it/s]
# Rate limit of 15 requests per minute reached. Waiting for 51.12 seconds.
# Processing samples for emotion: anger...: 100%|██████████| 20/20 [01:03<00:00,  3.16s/it]
# Processing samples for emotion: fear...:  50%|█████     | 10/20 [00:06<00:06,  1.50it/s]
# Rate limit of 15 requests per minute reached. Waiting for 49.89 seconds.
# Processing samples for emotion: fear...: 100%|██████████| 20/20 [01:03<00:00,  3.19s/it]
# Processing samples for emotion: joy...:  25%|██▌       | 5/20 [00:03<00:10,  1.44it/s]
# Rate limit of 15 requests per minute reached. Waiting for 49.56 seconds.
# Processing samples for emotion: joy...: 100%|██████████| 20/20 [01:03<00:00,  3.16s/it]
# Processing samples for emotion: sadness...:   0%|          | 0/20 [00:00<?, ?it/s]
# Rate limit of 15 requests per minute reached. Waiting for 49.77 seconds.
# Processing samples for emotion: sadness...:  75%|███████▌  | 15/20 [01:00<00:04,  1.22it/s]
# Rate limit of 15 requests per minute reached. Waiting for 49.32 seconds.
# Processing samples for emotion: sadness...: 100%|██████████| 20/20 [01:53<00:00,  5.66s/it]
# Results saved to ./llm_classification_results/results_samples_20_shots_0.csv
# Accuracy: 50.00%
#               precision    recall  f1-score   support
#
#        anger       0.50      0.60      0.55        20
#         fear       0.75      0.15      0.25        20
#          joy       0.44      0.85      0.58        20
#      sadness       0.62      0.40      0.48        20
#
#     accuracy                           0.50        80
#    macro avg       0.58      0.50      0.46        80
# weighted avg       0.58      0.50      0.46        80

# %%
# If you see '429 RESOURCE_EXHAUSTED' errors it's fine, wait until the data gets processed, it will keep retrying until it finishes

# Example of running the experiment with 1-shot prompting
run_experiment(train_df, test_df, num_test_samples=20, num_shots=1)
# Out:
# You will be given a text extracted from social media and your task is to classify the text into one of the following emotion categories:
# "anger" | "fear" | "joy" | "sadness"
#
#
# Examples:
# Text: Wont use using @mothercareuk @Mothercarehelp again!! These guys cant get nothing right!! #fuming
# Class: anger
#
# Text: Do you think humans have the sense for recognizing impending doom?
# Class: fear
#
# Text: My future must be bright af.
# Class: joy
#
# Text: @LazyBoiSam blues... blues? 🤔
# Class: sadness
# Processing samples for emotion: anger...:  75%|███████▌  | 15/20 [00:12<00:03,  1.33it/s]
# Rate limit of 15 requests per minute reached. Waiting for 47.89 seconds.
# Processing samples for emotion: anger...: 100%|██████████| 20/20 [01:03<00:00,  3.18s/it]
# Processing samples for emotion: fear...:  50%|█████     | 10/20 [00:07<00:07,  1.42it/s]
# Rate limit of 15 requests per minute reached. Waiting for 49.28 seconds.
# Processing samples for emotion: fear...: 100%|██████████| 20/20 [01:03<00:00,  3.18s/it]
# Processing samples for emotion: joy...:  25%|██▌       | 5/20 [00:03<00:08,  1.69it/s]
# Rate limit of 15 requests per minute reached. Waiting for 49.92 seconds.
# Processing samples for emotion: joy...: 100%|██████████| 20/20 [02:25<00:00,  7.27s/it]
# Processing samples for emotion: sadness...:  75%|███████▌  | 15/20 [00:11<00:03,  1.38it/s]
# Rate limit of 15 requests per minute reached. Waiting for 48.24 seconds.
# Processing samples for emotion: sadness...: 100%|██████████| 20/20 [01:03<00:00,  3.18s/it]
# Results saved to ./llm_classification_results/results_samples_20_shots_1.csv
# Accuracy: 55.00%
#               precision    recall  f1-score   support
#
#        anger       0.52      0.60      0.56        20
#         fear       0.71      0.25      0.37        20
#          joy       0.56      0.75      0.64        20
#      sadness       0.52      0.60      0.56        20
#
#     accuracy                           0.55        80
#    macro avg       0.58      0.55      0.53        80
# weighted avg       0.58      0.55      0.53        80

# %%
# If you see '429 RESOURCE_EXHAUSTED' errors it's fine, wait until the data gets processed, it will keep retrying until it finishes

# Example of running the experiment with 5-shot prompting
run_experiment(train_df, test_df, num_test_samples=20, num_shots=5)
# Out:
# You will be given a text extracted from social media and your task is to classify the text into one of the following emotion categories:
# "anger" | "fear" | "joy" | "sadness"
#
#
# Examples:
# Text: Wont use using @mothercareuk @Mothercarehelp again!! These guys cant get nothing right!! #fuming
# Class: anger
#
# Text: If you be #angry, which may be the case, &amp; which may be unavoidable, see that the sudden excitement does not become sin. #AlbertBarnes
# Class: anger
#
# Text: @cc_yandian @HillaryClinton her team must draw from a hat for daily personality #drugged  #yeller #quiet #screamer #😂😂
# Class: anger
#
# Text: I believe women are more fiery because once a month they go through struggle and struggle is what develops a strong character.
# Class: anger
#
# Text: I don't mean to offend anyone, but 93.7 literally blames everything on white people. In some cases it's true, but a lot of times, it's not
# Class: anger
#
# Text: Do you think humans have the sense for recognizing impending doom?
# Class: fear
#
# Text: So they #threaten to kill #kapernick for KNEELING. I say every athlete just stop playing until social justice and equality comes forth.
# Class: fear
#
# Text: New play through tonight! Pretty much a blind run. Only played the game once and maybe got 2 levels it. #Rage #horror
# Class: fear
#
# Text: Oh I get i see it's #TexasTech playing tonight not the #Texans #TNF #texansarebad
# Class: fear
#
# Text: If you get called #shy this means you are #considered.Turn those #negatives to #positives Quote #MarnieMcCormack from @jpmorgan #womenintech
# Class: fear
#
# Text: My future must be bright af.
# Class: joy
#
# Text: •Days!'\nHe was itching for a fight..itching for the exhilaration of battle, of almost getting defeated, the adrenaline pumping•\n@RojinHitto
# Class: joy
#
# Text: @BertGatti not had much to cheer about you see 😜😂😂
# Class: joy
#
# Text: I truly believe in my heart right now that Satan is rejoicing because we are all against one another
# Class: joy
#
# Text: Watch this amazing live.ly broadcast by @evanhufferd #lively #musically
# Class: joy
#
# Text: @LazyBoiSam blues... blues? 🤔
# Class: sadness
#
# Text: “We can easily #forgive a #child who is #afraid of the #dark; the real #tragedy of #life is when #men are #afraid of the #light.”–Plato
# Class: sadness
#
# Text: i wonder how a guy can broke his penis while having sex? #serious
# Class: sadness
#
# Text: 5am blues while riding a cab home:\n- my belly is much bigger than the rest of my body\n- but i couldnt be preggy\n- how to lose it in a day
# Class: sadness
#
# Text: Damn gud #premiere #LethalWeapon...#funny and
# Class: sadness
# Processing samples for emotion: anger...:  75%|███████▌  | 15/20 [00:11<00:03,  1.28it/s]
# Rate limit of 15 requests per minute reached. Waiting for 48.21 seconds.
# Processing samples for emotion: anger...: 100%|██████████| 20/20 [01:03<00:00,  3.20s/it]
# Processing samples for emotion: fear...:  50%|█████     | 10/20 [00:07<00:07,  1.31it/s]
# Rate limit of 15 requests per minute reached. Waiting for 48.51 seconds.
# Processing samples for emotion: fear...: 100%|██████████| 20/20 [01:03<00:00,  3.18s/it]
# Processing samples for emotion: joy...:  25%|██▌       | 5/20 [00:03<00:11,  1.35it/s]
# Rate limit of 15 requests per minute reached. Waiting for 48.74 seconds.
# Processing samples for emotion: joy...: 100%|██████████| 20/20 [01:04<00:00,  3.21s/it]
# Processing samples for emotion: sadness...:   0%|          | 0/20 [00:00<?, ?it/s]
# Rate limit of 15 requests per minute reached. Waiting for 48.22 seconds.
# Processing samples for emotion: sadness...:  75%|███████▌  | 15/20 [01:00<00:04,  1.09it/s]
# Rate limit of 15 requests per minute reached. Waiting for 47.81 seconds.
# Processing samples for emotion: sadness...: 100%|██████████| 20/20 [01:51<00:00,  5.59s/it]
# Results saved to ./llm_classification_results/results_samples_20_shots_5.csv
# Accuracy: 56.25%
#               precision    recall  f1-score   support
#
#        anger       0.56      0.70      0.62        20
#         fear       0.67      0.20      0.31        20
#          joy       0.62      0.65      0.63        20
#      sadness       0.50      0.70      0.58        20
#
#     accuracy                           0.56        80
#    macro avg       0.59      0.56      0.54        80
# weighted avg       0.59      0.56      0.54        80

# %% [markdown]
# ---
# ##### <a id='toc1_5_10_1_1_'></a>[**>>> Exercise 6 (Take home):**](#toc0_)
#
# Compare and discuss the overall results of the zero-shot, 1-shot and 5-shot classification.

# %% [markdown]
# [**Answer here**]
#
# The accuracy scores above the three classifications have been improved as the number of shots gets higher. Also, we can see from the confusion matrices that among all emotions, the model predicts joy the most, except for the correct predictions. It can be explained that the model tend to guess joy when it does not know the correct answer. The recall of joy is the highest and the precision is the least when it's 0 shot. However, after we add more shots to the model, the recall of joy has decreased, and the precision is higher. It might be because as the shots get higher, the model knows more examples to avoid guessing joy randomly and do the prediction more conservatively to get the correct prediction, and finally the overall f1 score subsequently rises.
# However, the scores of fear emotion have not increased clearly above all experiments. It might be due to the text features similar to anger emotion (negative) and the examples of fear is less than others, so the prediction is often hard to differentiate from these two emotions. In summary, the model indeed improved a lot as the number of shots gets higher, but there are still chances to add more shots to optimize the model and the prediction results.

# %% [markdown]
# ---
# ##### <a id='toc1_5_10_1_2_'></a>[**>>> Exercise 7 (Take home):**](#toc0_)
#
# **Case Study:** Check the results' files inside the `results/llm_classification_results` directory and find cases where the **text classification improves with more examples** (pred emotion is right with examples), **cases where it does not improve** (pred emotion always wrong) and **cases where the classification got worse with more examples** (pred emotion goes from right to wrong with examples). For this you need to load the results with pandas and handle the data using its dataframe functions. Discuss about the findings.

# %%
# Answer here
shot0 = pd.read_csv('results/llm_classification_results/results_samples_20_shots_0.csv')
shot1 = pd.read_csv('results/llm_classification_results/results_samples_20_shots_1.csv')
shot5 = pd.read_csv('results/llm_classification_results/results_samples_20_shots_5.csv')

shot0 = shot0.rename(columns={'predicted_emotion':'pred_0'})
shot1 = shot1.rename(columns={'predicted_emotion':'pred_1'})
shot5 = shot5.rename(columns={'predicted_emotion':'pred_5'})

result_merged = pd.merge(shot0, shot1, on=['text', 'true_emotion'])
result_merged = pd.merge(result_merged, shot5, on=['text', 'true_emotion'])
result_merged
# Out:
#                                                  text true_emotion   pred_0  \
# 0   @CozanGaming that's what lisa asked before she...        anger      joy
# 1   @isthataspider @dhodgs i will fight this guy! ...        anger    anger
# 2   [ @HedgehogDylan ] *she would frown a bit, fol...        anger    anger
# 3   @TrueAggieFan oh so that's where Brian was! Wh...        anger    anger
# 4   Just joined #pottermore and was sorted into HU...        anger    anger
# ..                                                ...          ...      ...
# 75  watching this uni reveal is so depressing i mi...      sadness  sadness
# 76  and for inconsolable Oxford academics - 'Bruss...      sadness    anger
# 77  “Dyslexia is the affliction of a frozen genius...      sadness  sadness
# 78  amateur author Twitter might be the most depre...      sadness  sadness
# 79  @FFBren @CDCarter13 included for maximum #sadness      sadness  sadness
#
#      pred_1   pred_5
# 0   sadness    anger
# 1     anger    anger
# 2   sadness  sadness
# 3     anger    anger
# 4     anger    anger
# ..      ...      ...
# 75  sadness  sadness
# 76    anger    anger
# 77  sadness  sadness
# 78  sadness  sadness
# 79  sadness  sadness
#
# [80 rows x 5 columns]

# %%
improved = result_merged[(result_merged['pred_0'] != result_merged['true_emotion']) & (result_merged['pred_5'] == result_merged['true_emotion'])]
print(f"improved cases: {len(improved)} cases")
display(improved)
not_improved = result_merged[
    (result_merged['pred_0'] != result_merged['true_emotion'])&
    (result_merged['pred_1'] != result_merged['true_emotion'])&
    (result_merged['pred_5'] != result_merged['true_emotion'])]
print(f"does not improve cases: {len(not_improved)} cases")
display(not_improved)
worse = result_merged[
    (result_merged['pred_0'] == result_merged['true_emotion'])&
    (result_merged['pred_5'] != result_merged['true_emotion'])]
print(f"worse cases: {len(worse)} cases")
display(worse)
# Out:
# improved cases: 10 cases
#                                                  text true_emotion pred_0  \
# 0   @CozanGaming that's what lisa asked before she...        anger    joy
# 5              @TrussElise Obama must be fuming.. lol        anger    joy
# 8   @Jen_ny69 People will always get offended ever...        anger    joy
# 26  Trying to book holiday flights on @britishairw...         fear  anger
# 62  Folk Band 'Thistle Down' will be replaced by '...      sadness    joy
# 64  @OHSOVICTORIOUS_ @FaZeAdapt We all seen it com...      sadness    joy
# 67  @CovinoandRich just heard back2back,  guess th...      sadness    joy
# 69  @LeePorter94 @DomMcGovern_ hi Dom I saw u at N...      sadness    joy
# 71  Remembering those day when u still did'nt know...      sadness    joy
# 73  you are on an endless journey of figuring your...      sadness    joy
#
#      pred_1   pred_5
# 0   sadness    anger
# 5     anger    anger
# 8       joy    anger
# 26     fear     fear
# 62  sadness  sadness
# 64  sadness  sadness
# 67  sadness  sadness
# 69      joy  sadness
# 71      joy  sadness
# 73  sadness  sadness
# does not improve cases: 29 cases
#                                                  text true_emotion   pred_0  \
# 7   Me being on my dean really saving a lot of ppl...        anger  sadness
# 10  Kik to trade, have fun or a conversation  (kik...        anger      joy
# 11                 Might just leave and aggravate bae        anger  sadness
# 16  @MaddenFreestyle i turn the game on wanting to...        anger  sadness
# 17  Having a baby born too soon is #lifechanging 6...        anger      joy
# 20  @stephenfhayes Mustard gas = hostile work envi...         fear    anger
# 21                    Rooney shocking attempted cross         fear      joy
# 22  @AttentiAlGatto LOL! Why would it scare me? It...         fear      joy
# 23  It really is amazing the money they give to so...         fear      joy
# 25  Really.....#Jumanji 2....w/ The Rock, Jack Bla...         fear    anger
# 27  An adviser to the #European #Union’s top #cour...         fear      joy
# 28  It really is amazing the money they give to so...         fear    anger
# 29       @RyanAbe awe yay thank god I was so worried.         fear      joy
# 31                Southend players always haunt Man U         fear    anger
# 33  He called me fat, so I pushed him into the loc...         fear    anger
# 34  But I was so intrigued by your style, boy.Alwa...         fear      joy
# 35  And I cried in front of my guy last night. And...         fear  sadness
# 36  @ChrissyCostanza and have social anxiety. Ther...         fear      joy
# 38  #Awareness seek #shelter .#Letgo Old #habit of...         fear    anger
# 39  @CNNPolitics I can't wait to hear what he had ...         fear    anger
# 41  If yiu don't respond .o an email within 7 days...          joy     fear
# 42  @Casper10666 I assure you there is no laughter...          joy    anger
# 59  The smell of freshly cut grass didn't even che...          joy  sadness
# 60  SOBRIETY®   trying to make being sober fashion...      sadness      joy
# 65  Rooney is 5 yards off the pace in a League Cup...      sadness    anger
# 66  yesterday i finished watching penny dreadful a...      sadness      joy
# 70  Before the year ends I'll probably get master ...      sadness      joy
# 72  @Eeevah14 don't I know it, try not to fret my ...      sadness      joy
# 76  and for inconsolable Oxford academics - 'Bruss...      sadness    anger
#
#      pred_1   pred_5
# 7   sadness  sadness
# 10      joy      joy
# 11  sadness  sadness
# 16  sadness  sadness
# 17  sadness  sadness
# 20    anger    anger
# 21  sadness  sadness
# 22      joy      joy
# 23      joy      joy
# 25    anger    anger
# 27      joy  sadness
# 28    anger    anger
# 29      joy      joy
# 31    anger    anger
# 33    anger    anger
# 34      joy      joy
# 35  sadness  sadness
# 36  sadness  sadness
# 38    anger    anger
# 39    anger    anger
# 41     fear     fear
# 42    anger    anger
# 59  sadness  sadness
# 60      joy      joy
# 65    anger    anger
# 66      joy      joy
# 70      joy      joy
# 72     fear     fear
# 76    anger    anger
# worse cases: 5 cases
#                                                  text true_emotion pred_0  \
# 2   [ @HedgehogDylan ] *she would frown a bit, fol...        anger  anger
# 47  Dolores.' A thin lipped smile graced glossed l...          joy    joy
# 48  @theclobra lol I thought maybe, couldn't decid...          joy    joy
# 50  @diehimbeertonis She developed her 'forced smi...          joy    joy
# 57  @airtelindia have some issues with my broadban...          joy    joy
#
#      pred_1   pred_5
# 2   sadness  sadness
# 47      joy  sadness
# 48      joy  sadness
# 50  sadness  sadness
# 57    anger    anger

# %% [markdown]
# [**observation**]
#
# From the findings above, we could observe that among the 80 cases predicted, the shot provided might not be enough. There are 29 cases that don't improve at all, and 5 cases are even worse. The cases not improved mainly belong to the fear emotion. It might be due to the difficulty of differentiating fear from other emotions, and also the shots provided might not have offered much information about fear's features. As a result, there are many negative emotions not improve at all. However, there are still 10 cases that have improved, and we can see that the cases are mostly those who guessed joy at the first try. The model has improved its sensitivity to other emotions than joy. At the same time, due to this kind of increased strength, some cases were predicted worse as the shots increased. As a result, we need find a balance between increasing the sensitivity and at the same time not to lose accuracy. Moreover, we should find how many shots does the model need to predict more negative emotions correctly.

# %% [markdown]
# ---
# ### <a id='toc1_5_11_'></a>[**2.7 Extra LLM Related Materials:**](#toc0_)
# So this will be it for the lab, but here are some extra materials if you would like to explore:
#
# - **How to use OpenAI ChatGPT model's API (Not Free API):** [Basics Video](https://www.youtube.com/watch?v=e9P7FLi5Zy8), [Basics GitHub](https://github.com/gkamradt/langchain-tutorials/blob/main/chatapi/ChatAPI%20%2B%20LangChain%20Basics.ipynb), [RAG's Basics Video](https://www.youtube.com/watch?v=9AXP7tCI9PI&t=300s), [RAG's Basics GitHub](https://github.com/techleadhd/chatgpt-retrieval)
#
# - **Advanced topic - QLoRA (Quantized Low-Rank Adapter):** QLoRA is a method used to make fine-tuning large language models more efficient. It works by adding a small, trainable part (LoRA) to a pre-trained model, while keeping the rest of the model frozen. At the same time, it reduces the size of the model’s data using a process called quantization, which makes the model require less memory. This allows you to fine-tune large models without needing as much computational power, making it easier to adapt models for specific tasks. Materials: [Paper GitHub](https://github.com/artidoro/qlora?tab=readme-ov-file), [Llama 3 Application Video](https://www.youtube.com/watch?v=YJNbgusTSF0&t=512s),[Llama 3 Application GitHub](https://github.com/adidror005/youtube-videos/blob/main/LLAMA_3_Fine_Tuning_for_Sequence_Classification_Actual_Video.ipynb)
#
# - **How to Fine-tune and run local LLMs with the `unsloth` library:** [unsloth tutorials](https://docs.unsloth.ai/models/tutorials-how-to-fine-tune-and-run-llms)
#
# - **Google's Agent Development Kit Documentation:** [ADK](https://google.github.io/adk-docs/)
#
# - **Build AI agents with LangGraph:** [LangGraph Documentation](https://langchain-ai.github.io/langgraph/concepts/why-langgraph/)

# %% [markdown]
# ---
